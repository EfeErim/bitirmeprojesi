# %% [markdown]
# # Notebook 6: Batch Train All Continual SD-LoRA Adapters
#
# Bu notebook, Notebook 2 akisini baz alir ve tanimli adapterleri sirayla egitir.
#
# Akis:
# 1. Repo bootstrap ve Notebook 2 helper'larini yukle.
# 2. Adapter matrisi ve sirayi tanimla.
# 3. Her adapter icin Notebook 2 parametre, dataset validation, training, OOD calibration, export ve final evaluation hucrelerini calistir.
# 4. Her run icin ozet yazdir; runtime auto-disconnect batch bitene kadar kapali kalir.

# %%
from pathlib import Path
import os
import subprocess
import sys
from urllib.parse import urlsplit, urlunsplit

CLONE_TARGET = Path('/content/bitirmeprojesi')
REPO_URL = os.environ.get('AADS_REPO_URL', 'https://github.com/EfeErim/bitirmeprojesi.git')
NOTEBOOK6_SPARSE_PATHS = (
    'README.md',
    'docs',
    'src',
    'scripts',
    'config',
    'colab_notebooks',
    'requirements.txt',
    'requirements_colab.txt',
    'pyproject.toml',
)

def _build_repo_access_url(repo_url, token):
    token = str(token or '').strip()
    if not token:
        return repo_url
    parsed = urlsplit(str(repo_url or '').strip())
    if parsed.scheme != 'https' or not parsed.netloc:
        return repo_url
    netloc = parsed.netloc.split('@', 1)[-1]
    return urlunsplit((parsed.scheme, f'{token}@{netloc}', parsed.path, parsed.query, parsed.fragment))

def _ensure_aads_repo_on_path():
    candidates = [Path.cwd(), Path.cwd().parent, CLONE_TARGET, Path('/content/bitirmeprojesi'), Path('/content/bitirme projesi')]
    for candidate in candidates:
        marker = candidate / 'scripts' / 'notebook_helpers' / 'cell_script_runner.py'
        if marker.is_file():
            repo_root = candidate.resolve()
            if str(repo_root) not in sys.path:
                sys.path.insert(0, str(repo_root))
            return repo_root
    clone_url = _build_repo_access_url(REPO_URL, os.environ.get('GH_TOKEN') or os.environ.get('GITHUB_TOKEN'))
    if not CLONE_TARGET.exists():
        subprocess.run(['git', 'clone', '--depth', '1', '--filter=blob:none', '--sparse', clone_url, str(CLONE_TARGET)], check=True)
        subprocess.run(['git', 'sparse-checkout', 'set', *NOTEBOOK6_SPARSE_PATHS], cwd=str(CLONE_TARGET), check=True)
    if str(CLONE_TARGET) not in sys.path:
        sys.path.insert(0, str(CLONE_TARGET))
    return CLONE_TARGET

_ensure_aads_repo_on_path()

from scripts.notebook_helpers.cell_script_runner import run_cell_script
run_cell_script('nb2_cell01_bootstrap_access.py', globals())
# Out:
# [BOOTSTRAP] GitHub token found.
# [BOOTSTRAP] HuggingFace token found.
# [BOOTSTRAP] Repo root: /content/bitirmeprojesi
# [BOOTSTRAP] Installing requirements_colab.txt...
# [BOOTSTRAP] Notebook 2: Continual Adapter Training bootstrap complete.
#
# ======================================================================
# BOOTSTRAP STATUS
# ======================================================================
# Status: ok
# Repo Root: /content/bitirmeprojesi
# In Colab: True
# GitHub Token: ✓
# HuggingFace Token: ✓
# ======================================================================
#
# [SONRAKI] Parametre ve adapter secimi hucresine gecin; model erisimi ayrica access-check hucresinde dogrulanacak.

# %%
NOTEBOOK_NAME = "6_train_all_continual_sd_lora_adapters.ipynb"
NOTEBOOK_FILENAME = "6_train_all_continual_sd_lora_adapters.executed.ipynb"
AUTO_DISCONNECT_RUNTIME = False
AUTO_PUSH_TO_GITHUB = True
NB6_AUTO_DISCONNECT_RUNTIME = True
NB6_AUTO_DISCONNECT_GRACE_SECONDS = 20
ENABLE_BAYESIAN_OPTIMIZATION = True
MANUAL_PARAM_OVERRIDES = {}
DEFAULT_RUNTIME_PARAMS = {
    "AUTO_DISCONNECT_RUNTIME": False,
    "AUTO_PUSH_TO_GITHUB": True,
}
NB6_MANUAL_PARAM_OVERRIDES = {}

from scripts.notebook_helpers.adapter_recommendations import get_adapter_recs
ADAPTER_RECS = get_adapter_recs()

NB6_ADAPTER_SEQUENCE = [
    "apricot__leaf",
    "apricot__fruit",
    "strawberry__leaf",
    "strawberry__fruit",
    "grape__leaf",
    "grape__fruit",
    "tomato__leaf",
    "tomato__fruit",
]

# %%
import json

NB6_RESULTS = {}

for index, adapter_key in enumerate(NB6_ADAPTER_SEQUENCE, start=1):
    print(f"\n[NB6] Starting {index}/{len(NB6_ADAPTER_SEQUENCE)}: {adapter_key}")
    adapter_rec = ADAPTER_RECS[adapter_key]
    CROP_NAME = adapter_rec["crop"]
    PART_NAME = adapter_rec["part"]
    DATASET_NAME = adapter_key
    ADAPTER_KEY = adapter_key
    MANUAL_PARAM_OVERRIDES = dict(NB6_MANUAL_PARAM_OVERRIDES.get(adapter_key, {}))
    try:
        run_cell_script('nb2_cell03_runtime_setup.py', globals())
        run_cell_script('nb2_cell04_parameter_resolution.py', globals())
        run_cell_script('nb2_cell05_access_check.py', globals())
        run_cell_script('nb2_cell06_dataset_validation.py', globals())
        run_cell_script('nb2_cell07_engine_init.py', globals())
        run_cell_script('nb2_cell08_ood_config_verify.py', globals())
        run_cell_script('nb2_cell09_training.py', globals())
        run_cell_script('nb2_cell10_ood_calibration.py', globals())
        run_cell_script('nb2_cell11_adapter_save.py', globals())
        run_cell_script('nb2_cell12_final_evaluation.py', globals())
        NB6_RESULTS[adapter_key] = {
            "status": "ok",
            "run_id": str(globals().get("RUN_ID", "")),
            "crop": str(globals().get("CROP_NAME", "")),
            "part": str(globals().get("PART_NAME", "")),
        }
    except Exception as exc:
        NB6_RESULTS[adapter_key] = {
            "status": "failed",
            "error": str(exc),
            "run_id": str(globals().get("RUN_ID", "")),
            "crop": str(globals().get("CROP_NAME", "")),
            "part": str(globals().get("PART_NAME", "")),
        }
        print(f"[NB6] FAILED {adapter_key}: {exc}")
        continue

print('\n[NB6] SUMMARY')
print(json.dumps(NB6_RESULTS, indent=2, ensure_ascii=False))

from scripts.colab_notebook_helpers import maybe_auto_disconnect_colab_runtime

NB6_COMPLETION_REPORT = {
    "ready": True,
    "checks": {
        "batch_loop_completed": True,
        "all_adapters_attempted": len(NB6_RESULTS) == len(NB6_ADAPTER_SEQUENCE),
    },
    "missing": [],
    "soft_missing": [],
    "adapter_results": NB6_RESULTS,
}
maybe_auto_disconnect_colab_runtime(
    enabled=bool(NB6_AUTO_DISCONNECT_RUNTIME),
    grace_period_sec=float(NB6_AUTO_DISCONNECT_GRACE_SECONDS),
    telemetry=globals().get("TELEMETRY"),
    completion_report=NB6_COMPLETION_REPORT,
)
# Out:
# [NB6] Starting 1/8: apricot__leaf
# [BOOTSTRAP] run_id=apricot_leaf_2026-05-26_09-59-07 crop=apricot part=leaf
# [ADAPTER_SELECTED] key=apricot__leaf crop=apricot part=leaf dataset=apricot__leaf ood=data/ood_dataset/final/apricot__leaf_ood_final oe_enabled=True oe=data/oe_dataset/apricot_leaf_oe_unsupported_leaf_candidates run_id=apricot_leaf_2026-05-26_09-59-07
# [TRAINING_PLAN] epochs=38 batch=52 lr=0.00012 lora_r=26 allow_under_min=False validation_every=1
# [SONRAKI] Erisim kontrolu -> dataset validation -> engine init -> training -> calibration -> save/eval hucresini sirayla calistirin.
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# [HF] Kimlik dogrulandi: Grizzmann
# [GIT] Auto-push on kontrolu gecti: GitHub token cozuldu.
# [CONFIG] source=notebook_cell crop=apricot epochs=12 bs=96 lr=0.0002 resume=fresh ber=False loss=logitnorm tau=1.0 auto_disconnect=True auto_push=True bayes_opt=True
# [DATASET] runtime_root=data/prepared_runtime_datasets dataset_name=apricot__leaf
# [OOD] ood_root=data/ood_dataset/final/apricot__leaf_ood_final ask_for_ood_root=False
# [OE] oe_root=data/oe_dataset/apricot_leaf_oe_unsupported_leaf_candidates ask_for_oe_root=False enabled=True loss_weight=0.3
# [RUNTIME] defaults=notebook_cell mp=bf16 workers=12 prefetch=8 sched=cosine wd=0.01 accum=1 grad_clip=1.0 label_smooth=0.0 warmup=0.1 early_stop=5/0.0 val_every=1 cache_train=True aug=randaugment randaug=2/7
# [OOD] factor=3.0 sure=90.0/97.0 conformal=raps alpha=0.05 raps_lambda=0.2 raps_k=1
# [KONTROL] Repo icin guncelleme var. Branch=master
# [KONTROL] GitHub okuma erisimi public; clone/pull icin ekstra token gerekmiyor.
# [KONTROL] GitHub push icin kimlik bilgisi hazir.
# [KONTROL] Gerekli Hugging Face modelleri anonim erisimle aciliyor.
# [BOOTSTRAP] Fetching selected Notebook 2 dataset paths: ['data/prepared_runtime_datasets/apricot__leaf', 'data/ood_dataset/final/apricot__leaf_ood_final', 'data/oe_dataset/apricot_leaf_oe_unsupported_leaf_candidates']
# [OOD] explicit ood root=/content/bitirmeprojesi/data/ood_dataset/final/apricot__leaf_ood_final
# [OE] explicit oe root=/content/bitirmeprojesi/data/oe_dataset/apricot_leaf_oe_unsupported_leaf_candidates
# [DATASET] runtime root=/content/bitirmeprojesi/data/prepared_runtime_datasets/apricot__leaf classes=3: ['kayısı_sağlıklı_yaprak_302', 'kayısı_şarka_virüsü_yaprak_206', 'kayısı_yaprak_delen_çil_hastalığı_yaprak_300']
# [DATASET][CHECK] scale=small continual=508 val=150 test=150 ood=195 classes=3
# [PARAMS] Manual overrides uygulandi: {'EPOCHS': 38, 'BATCH_SIZE': 52, 'LEARNING_RATE': 0.00012, 'LORA_R': 26, 'LORA_ALPHA': 24, 'LORA_DROPOUT': 0.125, 'OOD_FACTOR': 4.5, 'LABEL_SMOOTHING': 0.1, 'OE_LOSS_WEIGHT': 0.3, 'REACT_ENABLED': True, 'REACT_PERCENTILE': 0.985, 'FUSION_DROPOUT': 0.1, 'CLASSIFIER_REBALANCE_ENABLED': True, 'CLASSIFIER_REBALANCE_LOGIT_ADJUSTMENT_TAU': 1.1, 'AUTO_DISCONNECT_RUNTIME': False, 'AUTO_PUSH_TO_GITHUB': True, 'WEIGHT_DECAY': 0.01, 'LOSS_NAME': 'logitnorm', 'LOGITNORM_TAU': 1.0, 'MIXED_PRECISION': 'bf16', 'GRAD_ACCUM_STEPS': 1, 'VALIDATION_EVERY_N_EPOCHS': 1, 'EARLY_STOPPING_PATIENCE': 6, 'RANDAUGMENT_NUM_OPS': 2, 'RANDAUGMENT_MAGNITUDE': 7, 'NUM_WORKERS': 12, 'PREFETCH': 8, 'CACHE_TRAIN_SPLIT': True, 'ENABLE_BAYESIAN_OPTIMIZATION': True}
# [PARAMS][FINAL] epochs=38 bs=52 lr=0.00012 lora=26/24 dropout=0.125 accum=1 workers=12 prefetch=8
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
# [OPT] No prior comparable run yet. Bootstrap run will use the visible notebook parameters.
# [OOD] selected ood root=/content/bitirmeprojesi/data/ood_dataset/final/apricot__leaf_ood_final
# [OE] selected oe root=/content/bitirmeprojesi/data/oe_dataset/apricot_leaf_oe_unsupported_leaf_candidates
# [CLASSES] ['kayısı_şarka_virüsü_yaprak_206', 'kayısı_sağlıklı_yaprak_302', 'kayısı_yaprak_delen_çil_hastalığı_yaprak_300']
# [CLASSES] mode=dataset_fallback reason=partial_taxonomy_alignment_fallback matched=0 unmatched=3
# [CLASSES] taxonomy-unmatched classes kept: ['kayısı_s_arka_viru_su_yaprak_206', 'kayısı_sag_lıklı_yaprak_302', 'kayısı_yaprak_delen_c_il_hastalıg_ı_yaprak_300']
# [ENGINE][OOD_CFG] {"ber_enabled": false, "ber_lambda_new": 0.1, "ber_lambda_old": 0.1, "ber_warmup_steps": 50, "conformal_alpha": 0.05, "conformal_enabled": true, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "energy_temperature": 1.0, "energy_temperature_mode": "auto", "energy_temperature_range": [0.5, 3.0], "energy_temperature_steps": 16, "enforce_oe_disjoint": true, "knn_backend": "auto", "knn_chunk_size": 2048, "oe_enabled": true, "oe_loss_weight": 0.3, "oe_root": "/content/bitirmeprojesi/data/oe_dataset/apricot_leaf_oe_unsupported_leaf_candidates", "oe_target": "uniform", "primary_score_method": "auto", "radial_beta_range": [0.5, 2.0], "radial_beta_steps": 16, "radial_l2_enabled": true, "react_apply_during_calibration": true, "react_apply_during_inference": true, "react_enabled": true, "react_percentile": 0.985, "real_dev_selection_enabled": true, "real_dev_target_fpr": 0.05, "real_split_dev_fraction": 0.4, "real_split_enabled": true, "real_split_manifest_name": "ood_split_manifest.json", "real_split_min_per_slice": 2, "real_split_min_total": 30, "sure_confidence_percentile": 97.0, "sure_enabled": true, "sure_semantic_percentile": 90.0, "threshold_factor": 4.5}
# [ENGINE][OPT_CFG] loss=logitnorm tau=1.0 label_smoothing=0.1 mixed_precision=bf16
# [ENGINE] Initializing adapter (may download backbone)...
# config.json:   0%|          | 0.00/745 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.21G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/415 [00:00<?, ?it/s]
# [NB6] FAILED apricot__leaf: Exact image overlap between real OOD evidence and OE training pool is not allowed: same_crop_unsupported_unknowns/takviye_20260514_100_25715e4add34.jpg == unsupported_leaf_disease_candidates/apricot_blight_leaf_disease/100.jpg; same_crop_unsupported_unknowns/takviye_20260514_108_f3b27c5c7944.jpeg == unsupported_leaf_disease_candidates/apricot_blight_leaf_disease/108.jpeg; same_crop_unsupported_unknowns/takviye_20260514_108_1d9ec3f940ae.jpg == unsupported_leaf_disease_candidates/apricot_blight_leaf_disease/108.jpg; same_crop_unsupported_unknowns/takviye_20260514_112_d06994f7e0f0.jpeg == unsupported_leaf_disease_candidates/apricot_blight_leaf_disease/112.jpeg; same_crop_unsupported_unknowns/takviye_20260514_114_2a1a9791d361.jpg == unsupported_leaf_disease_candidates/apricot_blight_leaf_disease/114.jpg; +40 more
#
# [NB6] Starting 2/8: apricot__fruit
# [BOOTSTRAP] run_id=apricot_fruit_2026-05-26_09-59-51 crop=apricot part=fruit
# [ADAPTER_SELECTED] key=apricot__fruit crop=apricot part=fruit dataset=apricot__fruit ood=data/prepared_runtime_datasets/apricot__fruit/ood oe_enabled=True oe=data/prepared_runtime_datasets/apricot__fruit/oe run_id=apricot_fruit_2026-05-26_09-59-51
# [TRAINING_PLAN] epochs=36 batch=40 lr=0.0001 lora_r=20 allow_under_min=False validation_every=1
# [SONRAKI] Erisim kontrolu -> dataset validation -> engine init -> training -> calibration -> save/eval hucresini sirayla calistirin.
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# [HF] Kimlik dogrulandi: Grizzmann
# [GIT] Auto-push on kontrolu gecti: GitHub token cozuldu.
# [CONFIG] source=notebook_cell crop=apricot epochs=12 bs=96 lr=0.0002 resume=fresh ber=False loss=logitnorm tau=1.0 auto_disconnect=True auto_push=True bayes_opt=True
# [DATASET] runtime_root=data/prepared_runtime_datasets dataset_name=apricot__fruit
# [OOD] ood_root=data/prepared_runtime_datasets/apricot__fruit/ood ask_for_ood_root=False
# [OE] oe_root=data/prepared_runtime_datasets/apricot__fruit/oe ask_for_oe_root=False enabled=True loss_weight=0.3
# [RUNTIME] defaults=notebook_cell mp=bf16 workers=12 prefetch=8 sched=cosine wd=0.01 accum=1 grad_clip=1.0 label_smooth=0.0 warmup=0.1 early_stop=5/0.0 val_every=1 cache_train=True aug=randaugment randaug=2/7
# [OOD] factor=3.0 sure=90.0/97.0 conformal=raps alpha=0.05 raps_lambda=0.2 raps_k=1
# [KONTROL] Repo icin guncelleme var. Branch=master
# [KONTROL] GitHub okuma erisimi public; clone/pull icin ekstra token gerekmiyor.
# [KONTROL] GitHub push icin kimlik bilgisi hazir.
# [KONTROL] Gerekli Hugging Face modelleri anonim erisimle aciliyor.
# [BOOTSTRAP] Fetching selected Notebook 2 dataset paths: ['data/prepared_runtime_datasets/apricot__fruit', 'data/ood_dataset/final/apricot__fruit_ood_final', 'data/prepared_runtime_datasets/apricot__fruit/ood', 'data/prepared_runtime_datasets/apricot__fruit/oe']
# [OOD] explicit ood root=/content/bitirmeprojesi/data/prepared_runtime_datasets/apricot__fruit/ood
# [OE] explicit oe root=/content/bitirmeprojesi/data/prepared_runtime_datasets/apricot__fruit/oe
# [DATASET] runtime root=/content/bitirmeprojesi/data/prepared_runtime_datasets/apricot__fruit classes=5: ['kayısı_sağlıklı_meyve_800', 'kayısıda_çiçek_monilyası_meyve_40', 'kayısıda_şarka_virüsü_meyve_230', 'kayısıda_şeftali_karalekesi_meyve_232', 'kayısıda_yaprak_delen_çil_hastalığı_meyve_128']
# [DATASET][CHECK] scale=small continual=871 val=280 test=280 ood=103 classes=5
# [DATASET][WARN] Manifest rows include 2 eval-quality-risk item(s); prefer cautious regularization.
# [DATASET][BLOCK] Supported classes remain below the production minimum of 100 images/class: kayısıda_çiçek_monilyası_meyve_40=40. Enable ALLOW_UNDER_MIN_TRAINING manually only for a research-only run.
# [PARAMS] Manual overrides uygulandi: {'EPOCHS': 36, 'BATCH_SIZE': 40, 'LEARNING_RATE': 0.0001, 'LORA_R': 20, 'LORA_ALPHA': 20, 'LORA_DROPOUT': 0.2, 'OOD_FACTOR': 4.5, 'LABEL_SMOOTHING': 0.12, 'OE_LOSS_WEIGHT': 0.3, 'REACT_ENABLED': True, 'REACT_PERCENTILE': 0.985, 'FUSION_DROPOUT': 0.12, 'CLASSIFIER_REBALANCE_ENABLED': True, 'CLASSIFIER_REBALANCE_LOGIT_ADJUSTMENT_TAU': 1.1, 'AUTO_DISCONNECT_RUNTIME': False, 'AUTO_PUSH_TO_GITHUB': True, 'WEIGHT_DECAY': 0.01, 'LOSS_NAME': 'logitnorm', 'LOGITNORM_TAU': 1.0, 'MIXED_PRECISION': 'bf16', 'GRAD_ACCUM_STEPS': 1, 'VALIDATION_EVERY_N_EPOCHS': 1, 'EARLY_STOPPING_PATIENCE': 6, 'RANDAUGMENT_NUM_OPS': 2, 'RANDAUGMENT_MAGNITUDE': 7, 'NUM_WORKERS': 12, 'PREFETCH': 8, 'CACHE_TRAIN_SPLIT': True, 'ENABLE_BAYESIAN_OPTIMIZATION': True}
# [PARAMS][FINAL] epochs=36 bs=40 lr=0.0001 lora=20/20 dropout=0.2 accum=1 workers=12 prefetch=8
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
# [OPT] No prior comparable run yet. Bootstrap run will use the visible notebook parameters.
# [OOD] selected ood root=/content/bitirmeprojesi/data/prepared_runtime_datasets/apricot__fruit/ood
# [OE] selected oe root=/content/bitirmeprojesi/data/prepared_runtime_datasets/apricot__fruit/oe
# [CLASSES] ['kayısı_sağlıklı_meyve_800', 'kayısıda_çiçek_monilyası_meyve_40', 'kayısıda_şarka_virüsü_meyve_230', 'kayısıda_şeftali_karalekesi_meyve_232', 'kayısıda_yaprak_delen_çil_hastalığı_meyve_128']
# [CLASSES] mode=dataset_fallback reason=partial_taxonomy_alignment_fallback matched=0 unmatched=5
# [CLASSES] taxonomy-unmatched classes kept: ['kayısı_sag_lıklı_meyve_800', 'kayısıda_c_ic_ek_monilyası_meyve_40', 'kayısıda_s_arka_viru_su_meyve_230', 'kayısıda_s_eftali_karalekesi_meyve_232', 'kayısıda_yaprak_delen_c_il_hastalıg_ı_meyve_128']
# [ENGINE][OOD_CFG] {"ber_enabled": false, "ber_lambda_new": 0.1, "ber_lambda_old": 0.1, "ber_warmup_steps": 50, "conformal_alpha": 0.05, "conformal_enabled": true, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "energy_temperature": 1.0, "energy_temperature_mode": "auto", "energy_temperature_range": [0.5, 3.0], "energy_temperature_steps": 16, "enforce_oe_disjoint": true, "knn_backend": "auto", "knn_chunk_size": 2048, "oe_enabled": true, "oe_loss_weight": 0.3, "oe_root": "/content/bitirmeprojesi/data/prepared_runtime_datasets/apricot__fruit/oe", "oe_target": "uniform", "primary_score_method": "auto", "radial_beta_range": [0.5, 2.0], "radial_beta_steps": 16, "radial_l2_enabled": true, "react_apply_during_calibration": true, "react_apply_during_inference": true, "react_enabled": true, "react_percentile": 0.985, "real_dev_selection_enabled": true, "real_dev_target_fpr": 0.05, "real_split_dev_fraction": 0.4, "real_split_enabled": true, "real_split_manifest_name": "ood_split_manifest.json", "real_split_min_per_slice": 2, "real_split_min_total": 30, "sure_confidence_percentile": 97.0, "sure_enabled": true, "sure_semantic_percentile": 90.0, "threshold_factor": 4.5}
# [ENGINE][OPT_CFG] loss=logitnorm tau=1.0 label_smoothing=0.12 mixed_precision=bf16
# [ENGINE] Initializing adapter (may download backbone)...
# Loading weights:   0%|          | 0/415 [00:00<?, ?it/s]
# [ENGINE] Hazir. trainable_params=12,001,545  classes=5
# [VERIFY][OOD][expected] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 4.5}
# [VERIFY][OOD][resolved] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 4.5}
# [VERIFY][OOD] OK: cozulmus OOD ayari istenen parametrelerle eslesiyor.
# [TRAIN] epochs=36 device=cuda batch_interval=12
# [TRAIN] epoch=1 batch=12/21 loss=0.0000 lr=0.000100 speed=230.5s/s elapsed=5s eta=321s
# [CKPT] epoch_end epoch=1 step=21
# [EPOCH] 1/36: train_loss=1.6255 val_loss=1.5153 val_acc=0.1571 macro_f1=0.0543 * BEST
# [TRAIN] epoch=2 batch=12/21 loss=0.0000 lr=0.000100 speed=231.5s/s elapsed=15s eta=329s
# [EPOCH] 2/36: train_loss=1.6084 val_loss=1.6746 val_acc=0.1643 macro_f1=0.0711
# [TRAIN] epoch=3 batch=12/21 loss=0.0000 lr=0.000099 speed=232.4s/s elapsed=21s eta=268s
# [CKPT] epoch_end epoch=3 step=63
# [EPOCH] 3/36: train_loss=1.5950 val_loss=1.4851 val_acc=0.2214 macro_f1=0.2141 * BEST
# [TRAIN] epoch=4 batch=12/21 loss=0.0000 lr=0.000098 speed=230.6s/s elapsed=32s eta=288s
# [CKPT] epoch_end epoch=4 step=84
# [EPOCH] 4/36: train_loss=1.4937 val_loss=0.9847 val_acc=0.6857 macro_f1=0.4911 * BEST
# [TRAIN] epoch=5 batch=12/21 loss=0.0000 lr=0.000096 speed=228.1s/s elapsed=40s eta=274s
# [CKPT] epoch_end epoch=5 step=105
# [EPOCH] 5/36: train_loss=1.2902 val_loss=0.6029 val_acc=0.8214 macro_f1=0.6288 * BEST
# [TRAIN] epoch=6 batch=12/21 loss=0.0000 lr=0.000094 speed=231.3s/s elapsed=48s eta=262s
# [CKPT] epoch_end epoch=6 step=126
# [EPOCH] 6/36: train_loss=1.1944 val_loss=0.4176 val_acc=0.8607 macro_f1=0.6658 * BEST
# [TRAIN] epoch=7 batch=12/21 loss=0.0000 lr=0.000092 speed=229.5s/s elapsed=57s eta=254s
# [EPOCH] 7/36: train_loss=1.1387 val_loss=0.4278 val_acc=0.8714 macro_f1=0.6991
# [TRAIN] epoch=20 batch=12/21 loss=0.0000 lr=0.000044 speed=230.6s/s elapsed=146s eta=122s
# [EPOCH] 20/36: train_loss=0.9944 val_loss=0.2280 val_acc=0.9500 macro_f1=0.9262
# [TRAIN] epoch=21 batch=12/21 loss=0.0000 lr=0.000039 speed=232.0s/s elapsed=152s eta=114s
# [EPOCH] 21/36: train_loss=0.9863 val_loss=0.2278 val_acc=0.9429 macro_f1=0.9090
# [TRAIN] epoch=22 batch=12/21 loss=0.0000 lr=0.000035 speed=230.7s/s elapsed=157s eta=105s
# [CKPT] epoch_end epoch=22 step=462
# [EPOCH] 22/36: train_loss=1.0021 val_loss=0.2174 val_acc=0.9536 macro_f1=0.9224 * BEST
# [TRAIN] epoch=23 batch=12/21 loss=0.0000 lr=0.000031 speed=231.6s/s elapsed=166s eta=99s
# [EPOCH] 23/36: train_loss=0.9991 val_loss=0.2299 val_acc=0.9393 macro_f1=0.9044
# [TRAIN] epoch=24 batch=12/21 loss=0.0000 lr=0.000027 speed=229.6s/s elapsed=171s eta=90s
# [CKPT] batch_250 epoch=24 step=500
# [EPOCH] 24/36: train_loss=0.9899 val_loss=0.2270 val_acc=0.9429 macro_f1=0.9070
# [TRAIN] epoch=25 batch=12/21 loss=0.0000 lr=0.000024 speed=225.2s/s elapsed=178s eta=83s
# [EPOCH] 25/36: train_loss=0.9882 val_loss=0.2406 val_acc=0.9393 macro_f1=0.9009
# [TRAIN] epoch=26 batch=12/21 loss=0.0000 lr=0.000020 speed=231.9s/s elapsed=185s eta=75s
# [EPOCH] 26/36: train_loss=0.9873 val_loss=0.2322 val_acc=0.9393 macro_f1=0.9009
# [TRAIN] epoch=27 batch=12/21 loss=0.0000 lr=0.000017 speed=231.8s/s elapsed=190s eta=67s
# [EPOCH] 27/36: train_loss=0.9814 val_loss=0.2375 val_acc=0.9429 macro_f1=0.9076
# [TRAIN] epoch=28 batch=12/21 loss=0.0000 lr=0.000014 speed=230.1s/s elapsed=196s eta=60s
# [EPOCH] 28/36: train_loss=0.9778 val_loss=0.2309 val_acc=0.9464 macro_f1=0.9138
# [TRAIN] Complete. elapsed=198.4s stopped_early=True stopped_by_user=False cycles=1
# [OOD] Kalibrasyon tamamlandi. classes=5 version=1
# Cell 8: adapter save started
# Kaydedilen adapter klasoru: /content/bitirmeprojesi/outputs/colab_notebook_training/apricot/fruit/continual_sd_lora_adapter
#  - outputs/colab_notebook_training/apricot/fruit/continual_sd_lora_adapter/README.md
#  - outputs/colab_notebook_training/apricot/fruit/continual_sd_lora_adapter/adapter_config.json
#  - outputs/colab_notebook_training/apricot/fruit/continual_sd_lora_adapter/adapter_meta.json
#  - outputs/colab_notebook_training/apricot/fruit/continual_sd_lora_adapter/adapter_model.safetensors
#  - outputs/colab_notebook_training/apricot/fruit/continual_sd_lora_adapter/classifier.pth
#  - outputs/colab_notebook_training/apricot/fruit/continual_sd_lora_adapter/fusion.pth
# Telemetry adapter klasoru: /content/bitirmeprojesi/outputs/colab_notebook_training/telemetry_runtime/telemetry/apricot_fruit_2026-05-26_09-59-51/artifacts/adapter_export/apricot/fruit/continual_sd_lora_adapter
# Cell 8: adapter save completed
# [DOGRULAMA (referans)] ornek=280 sinif=5 accuracy=0.9464 ood_auroc=0.9210 sure_ds_f1=0.4539 conformal_cov=0.9536
# [TEST (ayrilmis)] ornek=280 sinif=5 accuracy=0.9500 ood_auroc=0.9180 sure_ds_f1=0.4153 conformal_cov=0.9643
# [OOD] kanit=real_ood_split durum=failed gecti=False
# [DONE] Dogrulama ve held-out test artefaktlari kaydedildi.
# /usr/local/lib/python3.12/dist-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k1__constant_value is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
# [RUNS] checkpoint_state -> /content/bitirmeprojesi/runs/apricot/fruit/apricot_fruit_2026-05-26_09-59-51/checkpoint_state
# [RUNS] outputs -> /content/bitirmeprojesi/runs/apricot/fruit/apricot_fruit_2026-05-26_09-59-51/outputs/colab_notebook_training
# [RUNS] telemetry -> /content/bitirmeprojesi/runs/apricot/fruit/apricot_fruit_2026-05-26_09-59-51/telemetry
# [RUNS] notebook -> /content/bitirmeprojesi/runs/apricot/fruit/apricot_fruit_2026-05-26_09-59-51/notebooks/6_train_all_continual_sd_lora_adapters.executed.ipynb
# [GIT] Local branch realigned to origin/master before secure run push.
# [SECURITY] scanned=145 redacted_files=62
# [GIT] Stage prepared for runs/apricot/fruit/apricot_fruit_2026-05-26_09-59-51: staged=351 skipped=3
# [GIT] Pushed 351 file(s) from runs/apricot/fruit/apricot_fruit_2026-05-26_09-59-51 to origin/master.
# [COLAB] completion checks -> {'evaluation_artifacts': True, 'production_readiness': True, 'telemetry_summary': True, 'repo_exports': True, 'executed_notebook_export': True}
# [COLAB] Auto-disconnect disabled.
#
# [NB6] Starting 3/8: strawberry__leaf
# [BOOTSTRAP] run_id=strawberry_leaf_2026-05-26_10-04-06 crop=strawberry part=leaf
# [ADAPTER_SELECTED] key=strawberry__leaf crop=strawberry part=leaf dataset=strawberry__leaf ood=data/prepared_runtime_datasets/strawberry__leaf/ood oe_enabled=True oe=data/prepared_runtime_datasets/strawberry__leaf/oe run_id=strawberry_leaf_2026-05-26_10-04-06
# [TRAINING_PLAN] epochs=24 batch=88 lr=0.00012 lora_r=24 allow_under_min=False validation_every=1
# [SONRAKI] Erisim kontrolu -> dataset validation -> engine init -> training -> calibration -> save/eval hucresini sirayla calistirin.
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# [HF] Kimlik dogrulandi: Grizzmann
# [GIT] Auto-push on kontrolu gecti: GitHub token cozuldu.
# [CONFIG] source=notebook_cell crop=strawberry epochs=12 bs=96 lr=0.0002 resume=fresh ber=False loss=logitnorm tau=1.0 auto_disconnect=True auto_push=True bayes_opt=True
# [DATASET] runtime_root=data/prepared_runtime_datasets dataset_name=strawberry__leaf
# [OOD] ood_root=data/prepared_runtime_datasets/strawberry__leaf/ood ask_for_ood_root=False
# [OE] oe_root=data/prepared_runtime_datasets/strawberry__leaf/oe ask_for_oe_root=False enabled=True loss_weight=0.3
# [RUNTIME] defaults=notebook_cell mp=bf16 workers=12 prefetch=8 sched=cosine wd=0.01 accum=1 grad_clip=1.0 label_smooth=0.0 warmup=0.1 early_stop=5/0.0 val_every=1 cache_train=True aug=randaugment randaug=2/7
# [OOD] factor=3.0 sure=90.0/97.0 conformal=raps alpha=0.05 raps_lambda=0.2 raps_k=1
# [KONTROL] Repo guncel gorunuyor.
# [KONTROL] GitHub okuma erisimi public; clone/pull icin ekstra token gerekmiyor.
# [KONTROL] GitHub push icin kimlik bilgisi hazir.
# [KONTROL] Gerekli Hugging Face modelleri anonim erisimle aciliyor.
# [BOOTSTRAP] Fetching selected Notebook 2 dataset paths: ['data/prepared_runtime_datasets/strawberry__leaf', 'data/ood_dataset/final/strawberry__leaf_ood_final', 'data/oe_dataset/strawberry_leaf_oe_from_blossom_candidates', 'data/prepared_runtime_datasets/strawberry__leaf/ood', 'data/prepared_runtime_datasets/strawberry__leaf/oe']
# [OOD] explicit ood root=/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__leaf/ood
# [OE] explicit oe root=/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__leaf/oe
# [DATASET] runtime root=/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__leaf classes=4: ['healthy', 'strawberry_leaf_scorch_leaf', 'strawberry_leaf_spot_leaf', 'strawberry_powdery_mildew_leaf']
# [DATASET][CHECK] scale=small continual=1606 val=491 test=491 ood=60 classes=4
# [PARAMS] Manual overrides uygulandi: {'EPOCHS': 24, 'BATCH_SIZE': 88, 'LEARNING_RATE': 0.00012, 'LORA_R': 24, 'LORA_ALPHA': 24, 'LORA_DROPOUT': 0.125, 'OOD_FACTOR': 4.0, 'LABEL_SMOOTHING': 0.1, 'EARLY_STOPPING_PATIENCE': 5, 'OE_LOSS_WEIGHT': 0.3, 'REACT_ENABLED': True, 'REACT_PERCENTILE': 0.99, 'FUSION_DROPOUT': 0.1, 'CLASSIFIER_REBALANCE_ENABLED': False, 'AUTO_DISCONNECT_RUNTIME': False, 'AUTO_PUSH_TO_GITHUB': True, 'WEIGHT_DECAY': 0.01, 'LOSS_NAME': 'logitnorm', 'LOGITNORM_TAU': 1.0, 'MIXED_PRECISION': 'bf16', 'GRAD_ACCUM_STEPS': 1, 'VALIDATION_EVERY_N_EPOCHS': 1, 'RANDAUGMENT_NUM_OPS': 2, 'RANDAUGMENT_MAGNITUDE': 7, 'NUM_WORKERS': 12, 'PREFETCH': 8, 'CACHE_TRAIN_SPLIT': True, 'ENABLE_BAYESIAN_OPTIMIZATION': True}
# [PARAMS][FINAL] epochs=24 bs=88 lr=0.00012 lora=24/24 dropout=0.125 accum=1 workers=12 prefetch=8
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
# [OPT] No prior comparable run yet. Bootstrap run will use the visible notebook parameters.
# [OOD] selected ood root=/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__leaf/ood
# [OE] selected oe root=/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__leaf/oe
# [CLASSES] ['healthy', 'strawberry_leaf_scorch_leaf', 'strawberry_leaf_spot_leaf', 'strawberry_powdery_mildew_leaf']
# [CLASSES] mode=dataset_fallback reason=partial_taxonomy_alignment_fallback matched=1 unmatched=3
# [CLASSES] taxonomy-unmatched classes kept: ['strawberry_leaf_scorch_leaf', 'strawberry_leaf_spot_leaf', 'strawberry_powdery_mildew_leaf']
# [ENGINE][OOD_CFG] {"ber_enabled": false, "ber_lambda_new": 0.1, "ber_lambda_old": 0.1, "ber_warmup_steps": 50, "conformal_alpha": 0.05, "conformal_enabled": true, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "energy_temperature": 1.0, "energy_temperature_mode": "auto", "energy_temperature_range": [0.5, 3.0], "energy_temperature_steps": 16, "enforce_oe_disjoint": true, "knn_backend": "auto", "knn_chunk_size": 2048, "oe_enabled": true, "oe_loss_weight": 0.3, "oe_root": "/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__leaf/oe", "oe_target": "uniform", "primary_score_method": "auto", "radial_beta_range": [0.5, 2.0], "radial_beta_steps": 16, "radial_l2_enabled": true, "react_apply_during_calibration": true, "react_apply_during_inference": true, "react_enabled": true, "react_percentile": 0.99, "real_dev_selection_enabled": true, "real_dev_target_fpr": 0.05, "real_split_dev_fraction": 0.4, "real_split_enabled": true, "real_split_manifest_name": "ood_split_manifest.json", "real_split_min_per_slice": 2, "real_split_min_total": 30, "sure_confidence_percentile": 97.0, "sure_enabled": true, "sure_semantic_percentile": 90.0, "threshold_factor": 4.0}
# [ENGINE][OPT_CFG] loss=logitnorm tau=1.0 label_smoothing=0.1 mixed_precision=bf16
# [ENGINE] Initializing adapter (may download backbone)...
# Loading weights:   0%|          | 0/415 [00:00<?, ?it/s]
# [ENGINE] Hazir. trainable_params=13,770,248  classes=4
# [VERIFY][OOD][expected] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 4.0}
# [VERIFY][OOD][resolved] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 4.0}
# [VERIFY][OOD] OK: cozulmus OOD ayari istenen parametrelerle eslesiyor.
# [TRAIN] epochs=24 device=cuda batch_interval=12
# [TRAIN] epoch=1 batch=12/18 loss=0.0000 lr=0.000120 speed=262.3s/s elapsed=7s eta=246s
# [CKPT] epoch_end epoch=1 step=18
# [EPOCH] 1/24: train_loss=1.3857 val_loss=1.2506 val_acc=0.7312 macro_f1=0.5958 * BEST
# [TRAIN] epoch=2 batch=12/18 loss=0.0000 lr=0.000119 speed=261.8s/s elapsed=21s eta=283s
# [CKPT] epoch_end epoch=2 step=36
# [EPOCH] 2/24: train_loss=1.2664 val_loss=0.9867 val_acc=0.7251 macro_f1=0.6264 * BEST
# [TRAIN] epoch=3 batch=12/18 loss=0.0000 lr=0.000116 speed=262.3s/s elapsed=34s eta=272s
# [CKPT] epoch_end epoch=3 step=54
# [EPOCH] 3/24: train_loss=1.0531 val_loss=0.5603 val_acc=0.9613 macro_f1=0.9577 * BEST
# [TRAIN] epoch=4 batch=12/18 loss=0.0000 lr=0.000113 speed=261.4s/s elapsed=46s eta=256s
# [CKPT] epoch_end epoch=4 step=72
# [EPOCH] 4/24: train_loss=0.9083 val_loss=0.2169 val_acc=0.9532 macro_f1=0.9485 * BEST
# [TRAIN] epoch=5 batch=12/18 loss=0.0000 lr=0.000109 speed=262.1s/s elapsed=58s eta=240s
# [CKPT] epoch_end epoch=5 step=90
# [EPOCH] 5/24: train_loss=0.8026 val_loss=0.0485 val_acc=0.9959 macro_f1=0.9951 * BEST
# [TRAIN] epoch=6 batch=12/18 loss=0.0000 lr=0.000104 speed=262.5s/s elapsed=71s eta=229s
# [CKPT] epoch_end epoch=6 step=108
# [EPOCH] 6/24: train_loss=0.7728 val_loss=0.0314 val_acc=0.9939 macro_f1=0.9924 * BEST
# [TRAIN] epoch=7 batch=12/18 loss=0.0000 lr=0.000099 speed=261.5s/s elapsed=83s eta=215s
# [CKPT] epoch_end epoch=7 step=126
# [EPOCH] 7/24: train_loss=0.7673 val_loss=0.0208 val_acc=0.9939 macro_f1=0.9924 * BEST
# [TRAIN] epoch=8 batch=12/18 loss=0.0000 lr=0.000092 speed=262.5s/s elapsed=95s eta=202s
# [CKPT] epoch_end epoch=8 step=144
# [EPOCH] 8/24: train_loss=0.7611 val_loss=0.0179 val_acc=0.9939 macro_f1=0.9924 * BEST
# [TRAIN] epoch=9 batch=12/18 loss=0.0000 lr=0.000086 speed=261.4s/s elapsed=107s eta=189s
# [CKPT] epoch_end epoch=9 step=162
# [EPOCH] 9/24: train_loss=0.7602 val_loss=0.0122 val_acc=0.9959 macro_f1=0.9951 * BEST
# [TRAIN] epoch=10 batch=12/18 loss=0.0000 lr=0.000078 speed=261.7s/s elapsed=119s eta=176s
# [EPOCH] 10/24: train_loss=0.7578 val_loss=0.0204 val_acc=0.9959 macro_f1=0.9951
# [TRAIN] epoch=11 batch=12/18 loss=0.0000 lr=0.000071 speed=261.7s/s elapsed=129s eta=162s
# [CKPT] epoch_end epoch=11 step=198
# [EPOCH] 11/24: train_loss=0.7565 val_loss=0.0084 val_acc=0.9959 macro_f1=0.9951 * BEST
# [TRAIN] epoch=12 batch=12/18 loss=0.0000 lr=0.000063 speed=261.5s/s elapsed=141s eta=149s
# [CKPT] epoch_end epoch=12 step=216
# [EPOCH] 12/24: train_loss=0.7558 val_loss=0.0053 val_acc=0.9959 macro_f1=0.9951 * BEST
# [TRAIN] epoch=13 batch=12/18 loss=0.0000 lr=0.000055 speed=261.4s/s elapsed=153s eta=137s
# [EPOCH] 13/24: train_loss=0.7562 val_loss=0.0139 val_acc=0.9959 macro_f1=0.9951
# [TRAIN] epoch=14 batch=12/18 loss=0.0000 lr=0.000048 speed=262.3s/s elapsed=162s eta=122s
# [CKPT] batch_250 epoch=14 step=250
# [EPOCH] 14/24: train_loss=0.7554 val_loss=0.0082 val_acc=0.9959 macro_f1=0.9951
# [TRAIN] epoch=15 batch=12/18 loss=0.0000 lr=0.000040 speed=262.2s/s elapsed=173s eta=110s
# [EPOCH] 15/24: train_loss=0.7566 val_loss=0.0133 val_acc=0.9959 macro_f1=0.9951
# [TRAIN] epoch=16 batch=12/18 loss=0.0000 lr=0.000033 speed=261.7s/s elapsed=183s eta=97s
# [EPOCH] 16/24: train_loss=0.7556 val_loss=0.0228 val_acc=0.9939 macro_f1=0.9924
# [TRAIN] epoch=17 batch=12/18 loss=0.0000 lr=0.000026 speed=261.9s/s elapsed=192s eta=84s
# [EPOCH] 17/24: train_loss=0.7552 val_loss=0.0221 val_acc=0.9959 macro_f1=0.9951
# [TRAIN] Complete. elapsed=195.9s stopped_early=True stopped_by_user=False cycles=1
# [OOD] Kalibrasyon tamamlandi. classes=4 version=1
# Cell 8: adapter save started
# Kaydedilen adapter klasoru: /content/bitirmeprojesi/outputs/colab_notebook_training/strawberry/leaf/continual_sd_lora_adapter
#  - outputs/colab_notebook_training/strawberry/leaf/continual_sd_lora_adapter/README.md
#  - outputs/colab_notebook_training/strawberry/leaf/continual_sd_lora_adapter/adapter_config.json
#  - outputs/colab_notebook_training/strawberry/leaf/continual_sd_lora_adapter/adapter_meta.json
#  - outputs/colab_notebook_training/strawberry/leaf/continual_sd_lora_adapter/adapter_model.safetensors
#  - outputs/colab_notebook_training/strawberry/leaf/continual_sd_lora_adapter/classifier.pth
#  - outputs/colab_notebook_training/strawberry/leaf/continual_sd_lora_adapter/fusion.pth
# Telemetry adapter klasoru: /content/bitirmeprojesi/outputs/colab_notebook_training/telemetry_runtime/telemetry/strawberry_leaf_2026-05-26_10-04-06/artifacts/adapter_export/strawberry/leaf/continual_sd_lora_adapter
# Cell 8: adapter save completed
# [DOGRULAMA (referans)] ornek=491 sinif=4 accuracy=0.9959 ood_auroc=0.9672 sure_ds_f1=0.6253 conformal_cov=0.9959
# [TEST (ayrilmis)] ornek=491 sinif=4 accuracy=0.9980 ood_auroc=0.9619 sure_ds_f1=0.6181 conformal_cov=0.9980
# [OOD] kanit=real_ood_split durum=failed gecti=False
# [DONE] Dogrulama ve held-out test artefaktlari kaydedildi.
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
# [RUNS] checkpoint_state -> /content/bitirmeprojesi/runs/strawberry/leaf/strawberry_leaf_2026-05-26_10-04-06/checkpoint_state
# [RUNS] outputs -> /content/bitirmeprojesi/runs/strawberry/leaf/strawberry_leaf_2026-05-26_10-04-06/outputs/colab_notebook_training
# [RUNS] telemetry -> /content/bitirmeprojesi/runs/strawberry/leaf/strawberry_leaf_2026-05-26_10-04-06/telemetry
# [RUNS] notebook -> /content/bitirmeprojesi/runs/strawberry/leaf/strawberry_leaf_2026-05-26_10-04-06/notebooks/6_train_all_continual_sd_lora_adapters.executed.ipynb
# [GIT] Local branch realigned to origin/master before secure run push.
# [SECURITY] scanned=148 redacted_files=64
# [GIT] Stage prepared for runs/strawberry/leaf/strawberry_leaf_2026-05-26_10-04-06: staged=401 skipped=3
# [GIT] Pushed 401 file(s) from runs/strawberry/leaf/strawberry_leaf_2026-05-26_10-04-06 to origin/master.
# [COLAB] completion checks -> {'evaluation_artifacts': True, 'production_readiness': True, 'telemetry_summary': True, 'repo_exports': True, 'executed_notebook_export': True}
# [COLAB] Auto-disconnect disabled.
#
# [NB6] Starting 4/8: strawberry__fruit
# [BOOTSTRAP] run_id=strawberry_fruit_2026-05-26_10-08-42 crop=strawberry part=fruit
# [ADAPTER_SELECTED] key=strawberry__fruit crop=strawberry part=fruit dataset=strawberry__fruit ood=data/ood_dataset/final/strawberry__fruit_ood_final oe_enabled=True oe=data/oe_dataset/strawberry_fruit_oe_candidates run_id=strawberry_fruit_2026-05-26_10-08-42
# [TRAINING_PLAN] epochs=38 batch=40 lr=5e-05 lora_r=20 allow_under_min=True validation_every=1
# [SONRAKI] Erisim kontrolu -> dataset validation -> engine init -> training -> calibration -> save/eval hucresini sirayla calistirin.
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# [HF] Kimlik dogrulandi: Grizzmann
# [GIT] Auto-push on kontrolu gecti: GitHub token cozuldu.
# [CONFIG] source=notebook_cell crop=strawberry epochs=12 bs=96 lr=0.0002 resume=fresh ber=False loss=logitnorm tau=1.0 auto_disconnect=True auto_push=True bayes_opt=True
# [DATASET] runtime_root=data/prepared_runtime_datasets dataset_name=strawberry__fruit
# [OOD] ood_root=data/ood_dataset/final/strawberry__fruit_ood_final ask_for_ood_root=False
# [OE] oe_root=data/oe_dataset/strawberry_fruit_oe_candidates ask_for_oe_root=False enabled=True loss_weight=0.12
# [RUNTIME] defaults=notebook_cell mp=bf16 workers=12 prefetch=8 sched=cosine wd=0.01 accum=1 grad_clip=1.0 label_smooth=0.0 warmup=0.1 early_stop=5/0.0 val_every=1 cache_train=True aug=randaugment randaug=2/7
# [OOD] factor=3.0 sure=90.0/97.0 conformal=raps alpha=0.05 raps_lambda=0.2 raps_k=1
# [KONTROL] Repo guncel gorunuyor.
# [KONTROL] GitHub okuma erisimi public; clone/pull icin ekstra token gerekmiyor.
# [KONTROL] GitHub push icin kimlik bilgisi hazir.
# [KONTROL] Gerekli Hugging Face modelleri anonim erisimle aciliyor.
# [BOOTSTRAP] Fetching selected Notebook 2 dataset paths: ['data/prepared_runtime_datasets/strawberry__fruit', 'data/ood_dataset/final/strawberry__fruit_ood_final', 'data/oe_dataset/strawberry_fruit_oe_candidates']
# [OOD] explicit ood root=/content/bitirmeprojesi/data/ood_dataset/final/strawberry__fruit_ood_final
# [OE] explicit oe root=/content/bitirmeprojesi/data/oe_dataset/strawberry_fruit_oe_candidates
# [DATASET] runtime root=/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__fruit classes=4: ['strawberry_anthracnose_fruit', 'strawberry_gray_mold_fruit', 'strawberry_healthy_fruit', 'strawberry_powdery_mildew_fruit']
# [DATASET][CHECK] scale=small continual=721 val=204 test=204 ood=95 classes=4
# [DATASET][BLOCK] Supported classes remain below the production minimum of 100 images/class: strawberry_anthracnose_fruit=85. Enable ALLOW_UNDER_MIN_TRAINING manually only for a research-only run.
# [PARAMS] Manual overrides uygulandi: {'EPOCHS': 38, 'BATCH_SIZE': 40, 'LEARNING_RATE': 5e-05, 'LORA_R': 20, 'LORA_ALPHA': 26, 'LORA_DROPOUT': 0.13, 'OOD_FACTOR': 2.0, 'LABEL_SMOOTHING': 0.05, 'OE_LOSS_WEIGHT': 0.12, 'REACT_ENABLED': True, 'REACT_PERCENTILE': 0.99, 'FUSION_DROPOUT': 0.12, 'CLASSIFIER_REBALANCE_ENABLED': True, 'CLASSIFIER_REBALANCE_LOGIT_ADJUSTMENT_TAU': 1.1, 'AUTO_DISCONNECT_RUNTIME': False, 'AUTO_PUSH_TO_GITHUB': True, 'WEIGHT_DECAY': 0.01, 'LOSS_NAME': 'logitnorm', 'LOGITNORM_TAU': 1.0, 'MIXED_PRECISION': 'bf16', 'GRAD_ACCUM_STEPS': 1, 'VALIDATION_EVERY_N_EPOCHS': 1, 'EARLY_STOPPING_PATIENCE': 6, 'RANDAUGMENT_NUM_OPS': 2, 'RANDAUGMENT_MAGNITUDE': 7, 'NUM_WORKERS': 12, 'PREFETCH': 8, 'CACHE_TRAIN_SPLIT': True, 'ENABLE_BAYESIAN_OPTIMIZATION': True}
# [PARAMS][FINAL] epochs=38 bs=40 lr=5e-05 lora=20/26 dropout=0.13 accum=1 workers=12 prefetch=8
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
# [OPT] No prior comparable run yet. Bootstrap run will use the visible notebook parameters.
# [OOD] selected ood root=/content/bitirmeprojesi/data/ood_dataset/final/strawberry__fruit_ood_final
# [OE] selected oe root=/content/bitirmeprojesi/data/oe_dataset/strawberry_fruit_oe_candidates
# [CLASSES] ['strawberry_anthracnose_fruit', 'strawberry_gray_mold_fruit', 'strawberry_healthy_fruit', 'strawberry_powdery_mildew_fruit']
# [CLASSES] mode=dataset_fallback reason=partial_taxonomy_alignment_fallback matched=0 unmatched=4
# [CLASSES] taxonomy-unmatched classes kept: ['strawberry_anthracnose_fruit', 'strawberry_gray_mold_fruit', 'strawberry_healthy_fruit', 'strawberry_powdery_mildew_fruit']
# [ENGINE][OOD_CFG] {"ber_enabled": false, "ber_lambda_new": 0.1, "ber_lambda_old": 0.1, "ber_warmup_steps": 50, "conformal_alpha": 0.05, "conformal_enabled": true, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "energy_temperature": 1.0, "energy_temperature_mode": "auto", "energy_temperature_range": [0.5, 3.0], "energy_temperature_steps": 16, "enforce_oe_disjoint": true, "knn_backend": "auto", "knn_chunk_size": 2048, "oe_enabled": true, "oe_loss_weight": 0.12, "oe_root": "/content/bitirmeprojesi/data/oe_dataset/strawberry_fruit_oe_candidates", "oe_target": "uniform", "primary_score_method": "auto", "radial_beta_range": [0.5, 2.0], "radial_beta_steps": 16, "radial_l2_enabled": true, "react_apply_during_calibration": true, "react_apply_during_inference": true, "react_enabled": true, "react_percentile": 0.99, "real_dev_selection_enabled": true, "real_dev_target_fpr": 0.05, "real_split_dev_fraction": 0.4, "real_split_enabled": true, "real_split_manifest_name": "ood_split_manifest.json", "real_split_min_per_slice": 2, "real_split_min_total": 30, "sure_confidence_percentile": 97.0, "sure_enabled": true, "sure_semantic_percentile": 90.0, "threshold_factor": 2.0}
# [ENGINE][OPT_CFG] loss=logitnorm tau=1.0 label_smoothing=0.05 mixed_precision=bf16
# [ENGINE] Initializing adapter (may download backbone)...
# Loading weights:   0%|          | 0/415 [00:00<?, ?it/s]
# [NB6] FAILED strawberry__fruit: Exact image overlap between real OOD evidence and OE training pool is not allowed: same_crop_unsupported_unknowns/rebalanced_20260510_oe_to_ood_strawberry_unknown_angular_leafspot_384.jpg == unsupported_same_crop_non_fruit_or_unknown/angular_leafspot/ilek_Outlier-20260503T132606Z-3-001/angular_leafspot_384.jpg; same_crop_unsupported_unknowns/rebalanced_20260510_oe_to_ood_strawberry_unknown_angular_leafspot_385.jpg == unsupported_same_crop_non_fruit_or_unknown/angular_leafspot/ilek_Outlier-20260503T132606Z-3-001/angular_leafspot_385.jpg
#
# [NB6] Starting 5/8: grape__leaf
# [BOOTSTRAP] run_id=grape_leaf_2026-05-26_10-09-10 crop=grape part=leaf
# [ADAPTER_SELECTED] key=grape__leaf crop=grape part=leaf dataset=grape__leaf ood=data/prepared_runtime_datasets/grape__leaf/ood oe_enabled=True oe=data/prepared_runtime_datasets/grape__leaf/oe run_id=grape_leaf_2026-05-26_10-09-10
# [TRAINING_PLAN] epochs=30 batch=56 lr=0.0001 lora_r=24 allow_under_min=False validation_every=1
# [SONRAKI] Erisim kontrolu -> dataset validation -> engine init -> training -> calibration -> save/eval hucresini sirayla calistirin.
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# [HF] Kimlik dogrulandi: Grizzmann
# [GIT] Auto-push on kontrolu gecti: GitHub token cozuldu.
# [CONFIG] source=notebook_cell crop=grape epochs=12 bs=96 lr=0.0002 resume=fresh ber=False loss=logitnorm tau=1.0 auto_disconnect=True auto_push=True bayes_opt=True
# [DATASET] runtime_root=data/prepared_runtime_datasets dataset_name=grape__leaf
# [OOD] ood_root=data/prepared_runtime_datasets/grape__leaf/ood ask_for_ood_root=False
# [OE] oe_root=data/prepared_runtime_datasets/grape__leaf/oe ask_for_oe_root=False enabled=True loss_weight=0.24
# [RUNTIME] defaults=notebook_cell mp=bf16 workers=12 prefetch=8 sched=cosine wd=0.01 accum=1 grad_clip=1.0 label_smooth=0.0 warmup=0.1 early_stop=5/0.0 val_every=1 cache_train=True aug=randaugment randaug=2/7
# [OOD] factor=3.0 sure=90.0/97.0 conformal=raps alpha=0.05 raps_lambda=0.2 raps_k=1
# [KONTROL] Repo guncel gorunuyor.
# [KONTROL] GitHub okuma erisimi public; clone/pull icin ekstra token gerekmiyor.
# [KONTROL] GitHub push icin kimlik bilgisi hazir.
# [KONTROL] Gerekli Hugging Face modelleri anonim erisimle aciliyor.
# [BOOTSTRAP] Fetching selected Notebook 2 dataset paths: ['data/prepared_runtime_datasets/grape__leaf', 'data/ood_dataset/final/grape__leaf_ood_final', 'data/oe_dataset/grape_leaf_oe_unsupported_leaf_candidates', 'data/prepared_runtime_datasets/grape__leaf/ood', 'data/prepared_runtime_datasets/grape__leaf/oe']
# [OOD] explicit ood root=/content/bitirmeprojesi/data/prepared_runtime_datasets/grape__leaf/ood
# [OE] explicit oe root=/content/bitirmeprojesi/data/prepared_runtime_datasets/grape__leaf/oe
# [DATASET] runtime root=/content/bitirmeprojesi/data/prepared_runtime_datasets/grape__leaf classes=7: ['üzüm_antraknoz_yaprak', 'üzüm_kav_esca_yaprak', 'üzüm_külleme_yaprak', 'üzüm_leafroll_virüs_yaprak', 'üzüm_mildiyö_yaprak', 'üzüm_sağlıklı_yaprak', 'üzüm_yelpaze_virüsü_yaprak']
# [DATASET][CHECK] scale=small continual=1207 val=324 test=324 ood=430 classes=7
# [DATASET][WARN] Manifest rows include 182 eval-quality-risk item(s); prefer cautious regularization.
# [PARAMS] Manual overrides uygulandi: {'EPOCHS': 30, 'BATCH_SIZE': 56, 'LEARNING_RATE': 0.0001, 'LORA_R': 24, 'LORA_ALPHA': 24, 'LORA_DROPOUT': 0.14, 'OOD_FACTOR': 3.5, 'LABEL_SMOOTHING': 0.1, 'OE_LOSS_WEIGHT': 0.24, 'REACT_ENABLED': True, 'REACT_PERCENTILE': 0.985, 'FUSION_DROPOUT': 0.12, 'CLASSIFIER_REBALANCE_ENABLED': True, 'CLASSIFIER_REBALANCE_LOGIT_ADJUSTMENT_TAU': 1.15, 'AUTO_DISCONNECT_RUNTIME': False, 'AUTO_PUSH_TO_GITHUB': True, 'WEIGHT_DECAY': 0.01, 'LOSS_NAME': 'logitnorm', 'LOGITNORM_TAU': 1.0, 'MIXED_PRECISION': 'bf16', 'GRAD_ACCUM_STEPS': 1, 'VALIDATION_EVERY_N_EPOCHS': 1, 'EARLY_STOPPING_PATIENCE': 6, 'RANDAUGMENT_NUM_OPS': 2, 'RANDAUGMENT_MAGNITUDE': 7, 'NUM_WORKERS': 12, 'PREFETCH': 8, 'CACHE_TRAIN_SPLIT': True, 'ENABLE_BAYESIAN_OPTIMIZATION': True}
# [PARAMS][FINAL] epochs=30 bs=56 lr=0.0001 lora=24/24 dropout=0.14 accum=1 workers=12 prefetch=8
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
# [OPT] No prior comparable run yet. Bootstrap run will use the visible notebook parameters.
# [OOD] selected ood root=/content/bitirmeprojesi/data/prepared_runtime_datasets/grape__leaf/ood
# [OE] selected oe root=/content/bitirmeprojesi/data/prepared_runtime_datasets/grape__leaf/oe
# [CLASSES] ['üzüm_antraknoz_yaprak', 'üzüm_kav_esca_yaprak', 'üzüm_külleme_yaprak', 'üzüm_leafroll_virüs_yaprak', 'üzüm_mildiyö_yaprak', 'üzüm_sağlıklı_yaprak', 'üzüm_yelpaze_virüsü_yaprak']
# [CLASSES] mode=dataset_fallback reason=partial_taxonomy_alignment_fallback matched=0 unmatched=7
# [CLASSES] taxonomy-unmatched classes kept: ['u_zu_m_antraknoz_yaprak', 'u_zu_m_kav_esca_yaprak', 'u_zu_m_ku_lleme_yaprak', 'u_zu_m_leafroll_viru_s_yaprak', 'u_zu_m_mildiyo_yaprak', 'u_zu_m_sag_lıklı_yaprak', 'u_zu_m_yelpaze_viru_su_yaprak']
# [ENGINE][OOD_CFG] {"ber_enabled": false, "ber_lambda_new": 0.1, "ber_lambda_old": 0.1, "ber_warmup_steps": 50, "conformal_alpha": 0.05, "conformal_enabled": true, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "energy_temperature": 1.0, "energy_temperature_mode": "auto", "energy_temperature_range": [0.5, 3.0], "energy_temperature_steps": 16, "enforce_oe_disjoint": true, "knn_backend": "auto", "knn_chunk_size": 2048, "oe_enabled": true, "oe_loss_weight": 0.24, "oe_root": "/content/bitirmeprojesi/data/prepared_runtime_datasets/grape__leaf/oe", "oe_target": "uniform", "primary_score_method": "auto", "radial_beta_range": [0.5, 2.0], "radial_beta_steps": 16, "radial_l2_enabled": true, "react_apply_during_calibration": true, "react_apply_during_inference": true, "react_enabled": true, "react_percentile": 0.985, "real_dev_selection_enabled": true, "real_dev_target_fpr": 0.05, "real_split_dev_fraction": 0.4, "real_split_enabled": true, "real_split_manifest_name": "ood_split_manifest.json", "real_split_min_per_slice": 2, "real_split_min_total": 30, "sure_confidence_percentile": 97.0, "sure_enabled": true, "sure_semantic_percentile": 90.0, "threshold_factor": 3.5}
# [ENGINE][OPT_CFG] loss=logitnorm tau=1.0 label_smoothing=0.1 mixed_precision=bf16
# [ENGINE] Initializing adapter (may download backbone)...
# Loading weights:   0%|          | 0/415 [00:00<?, ?it/s]
# [ENGINE] Hazir. trainable_params=13,772,555  classes=7
# [VERIFY][OOD][expected] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 3.5}
# [VERIFY][OOD][resolved] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 3.5}
# [VERIFY][OOD] OK: cozulmus OOD ayari istenen parametrelerle eslesiyor.
# [TRAIN] epochs=30 device=cuda batch_interval=12
# [TRAIN] epoch=1 batch=12/21 loss=0.0000 lr=0.000100 speed=248.8s/s elapsed=5s eta=267s
# [CKPT] epoch_end epoch=1 step=21
# [EPOCH] 1/30: train_loss=1.9856 val_loss=1.8863 val_acc=0.1759 macro_f1=0.0642 * BEST
# [TRAIN] epoch=2 batch=12/21 loss=0.0000 lr=0.000099 speed=249.3s/s elapsed=18s eta=326s
# [EPOCH] 2/30: train_loss=1.9371 val_loss=1.9288 val_acc=0.1080 macro_f1=0.0681
# [TRAIN] epoch=3 batch=12/21 loss=0.0000 lr=0.000098 speed=248.9s/s elapsed=26s eta=274s
# [CKPT] epoch_end epoch=3 step=63
# ...
# [TRAINING_PLAN] epochs=30 batch=64 lr=6e-05 lora_r=24 allow_under_min=False validation_every=1
# [SONRAKI] Erisim kontrolu -> dataset validation -> engine init -> training -> calibration -> save/eval hucresini sirayla calistirin.
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# [HF] Kimlik dogrulandi: Grizzmann
# [GIT] Auto-push on kontrolu gecti: GitHub token cozuldu.
# [CONFIG] source=notebook_cell crop=tomato epochs=12 bs=96 lr=0.0002 resume=fresh ber=False loss=logitnorm tau=1.0 auto_disconnect=True auto_push=True bayes_opt=True
# [DATASET] runtime_root=data/prepared_runtime_datasets dataset_name=tomato__fruit
# [OOD] ood_root=data/prepared_runtime_datasets/tomato__fruit/ood ask_for_ood_root=False
# [OE] oe_root=data/prepared_runtime_datasets/tomato__fruit/oe ask_for_oe_root=False enabled=True loss_weight=0.25
# [RUNTIME] defaults=notebook_cell mp=bf16 workers=12 prefetch=8 sched=cosine wd=0.01 accum=1 grad_clip=1.0 label_smooth=0.0 warmup=0.1 early_stop=5/0.0 val_every=1 cache_train=True aug=randaugment randaug=2/7
# [OOD] factor=3.0 sure=90.0/97.0 conformal=raps alpha=0.05 raps_lambda=0.2 raps_k=1
# [KONTROL] Repo guncel gorunuyor.
# [KONTROL] GitHub okuma erisimi public; clone/pull icin ekstra token gerekmiyor.
# [KONTROL] GitHub push icin kimlik bilgisi hazir.
# [KONTROL] Gerekli Hugging Face modelleri anonim erisimle aciliyor.
# [BOOTSTRAP] Fetching selected Notebook 2 dataset paths: ['data/prepared_runtime_datasets/tomato__fruit', 'data/ood_dataset/final/tomato__fruit_ood_final', 'data/oe_dataset/tomato_fruit_oe_from_leaf', 'data/prepared_runtime_datasets/tomato__fruit/ood', 'data/prepared_runtime_datasets/tomato__fruit/oe']
# [OOD] explicit ood root=/content/bitirmeprojesi/data/prepared_runtime_datasets/tomato__fruit/ood
# [OE] explicit oe root=/content/bitirmeprojesi/data/prepared_runtime_datasets/tomato__fruit/oe
# [DATASET] runtime root=/content/bitirmeprojesi/data/prepared_runtime_datasets/tomato__fruit classes=7: ['domates_antraknoz_meyve', 'domates_bacterial_spot_and_speck_meyve', 'domates_blossom_end_rot_meyve', 'domates_gray_mold_meyve', 'domates_late_blight_meyve', 'domates_sağlıklı_meyve', 'domates_spotted_wilt_meyve']
# [DATASET][CHECK] scale=medium continual=2245 val=119 test=119 ood=184 classes=7
# [DATASET][WARN] Manifest rows include 1859 synthetic-hint item(s); keep main benchmark claims conservative.
# [DATASET][WARN] Manifest rows include 8 eval-quality-risk item(s); prefer cautious regularization.
# [DATASET][BLOCK] Supported classes remain below the production minimum of 100 images/class: domates_antraknoz_meyve=62, domates_bacterial_spot_and_speck_meyve=15, domates_blossom_end_rot_meyve=55, domates_sağlıklı_meyve=47, domates_spotted_wilt_meyve=26. Enable ALLOW_UNDER_MIN_TRAINING manually only for a research-only run.
# [PARAMS] Manual overrides uygulandi: {'EPOCHS': 30, 'BATCH_SIZE': 64, 'LEARNING_RATE': 6e-05, 'LORA_R': 24, 'LORA_ALPHA': 24, 'LORA_DROPOUT': 0.125, 'OOD_FACTOR': 3.0, 'LABEL_SMOOTHING': 0.1, 'OE_LOSS_WEIGHT': 0.25, 'REACT_ENABLED': True, 'REACT_PERCENTILE': 0.985, 'FUSION_DROPOUT': 0.12, 'CLASSIFIER_REBALANCE_ENABLED': True, 'CLASSIFIER_REBALANCE_LOGIT_ADJUSTMENT_TAU': 1.15, 'AUTO_DISCONNECT_RUNTIME': False, 'AUTO_PUSH_TO_GITHUB': True, 'WEIGHT_DECAY': 0.01, 'LOSS_NAME': 'logitnorm', 'LOGITNORM_TAU': 1.0, 'MIXED_PRECISION': 'bf16', 'GRAD_ACCUM_STEPS': 1, 'VALIDATION_EVERY_N_EPOCHS': 1, 'EARLY_STOPPING_PATIENCE': 6, 'RANDAUGMENT_NUM_OPS': 2, 'RANDAUGMENT_MAGNITUDE': 7, 'NUM_WORKERS': 12, 'PREFETCH': 8, 'CACHE_TRAIN_SPLIT': True, 'ENABLE_BAYESIAN_OPTIMIZATION': True}
# [PARAMS][FINAL] epochs=30 bs=64 lr=6e-05 lora=24/24 dropout=0.125 accum=1 workers=12 prefetch=8
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
# [OPT] No prior comparable run yet. Bootstrap run will use the visible notebook parameters.
# [OOD] selected ood root=/content/bitirmeprojesi/data/prepared_runtime_datasets/tomato__fruit/ood
# [OE] selected oe root=/content/bitirmeprojesi/data/prepared_runtime_datasets/tomato__fruit/oe
# [CLASSES] ['domates_antraknoz_meyve', 'domates_bacterial_spot_and_speck_meyve', 'domates_blossom_end_rot_meyve', 'domates_gray_mold_meyve', 'domates_late_blight_meyve', 'domates_sağlıklı_meyve', 'domates_spotted_wilt_meyve']
# [CLASSES] mode=dataset_fallback reason=partial_taxonomy_alignment_fallback matched=0 unmatched=7
# [CLASSES] taxonomy-unmatched classes kept: ['domates_antraknoz_meyve', 'domates_bacterial_spot_and_speck_meyve', 'domates_blossom_end_rot_meyve', 'domates_gray_mold_meyve', 'domates_late_blight_meyve', 'domates_sag_lıklı_meyve', 'domates_spotted_wilt_meyve']
# [ENGINE][OOD_CFG] {"ber_enabled": false, "ber_lambda_new": 0.1, "ber_lambda_old": 0.1, "ber_warmup_steps": 50, "conformal_alpha": 0.05, "conformal_enabled": true, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "energy_temperature": 1.0, "energy_temperature_mode": "auto", "energy_temperature_range": [0.5, 3.0], "energy_temperature_steps": 16, "enforce_oe_disjoint": true, "knn_backend": "auto", "knn_chunk_size": 2048, "oe_enabled": true, "oe_loss_weight": 0.25, "oe_root": "/content/bitirmeprojesi/data/prepared_runtime_datasets/tomato__fruit/oe", "oe_target": "uniform", "primary_score_method": "auto", "radial_beta_range": [0.5, 2.0], "radial_beta_steps": 16, "radial_l2_enabled": true, "react_apply_during_calibration": true, "react_apply_during_inference": true, "react_enabled": true, "react_percentile": 0.985, "real_dev_selection_enabled": true, "real_dev_target_fpr": 0.05, "real_split_dev_fraction": 0.4, "real_split_enabled": true, "real_split_manifest_name": "ood_split_manifest.json", "real_split_min_per_slice": 2, "real_split_min_total": 30, "sure_confidence_percentile": 97.0, "sure_enabled": true, "sure_semantic_percentile": 90.0, "threshold_factor": 3.0}
# [ENGINE][OPT_CFG] loss=logitnorm tau=1.0 label_smoothing=0.1 mixed_precision=bf16
# [ENGINE] Initializing adapter (may download backbone)...
# Loading weights:   0%|          | 0/415 [00:00<?, ?it/s]
# [ENGINE] Hazir. trainable_params=13,772,555  classes=7
# [VERIFY][OOD][expected] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 3.0}
# [VERIFY][OOD][resolved] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 3.0}
# [VERIFY][OOD] OK: cozulmus OOD ayari istenen parametrelerle eslesiyor.
# [TRAIN] epochs=30 device=cuda batch_interval=12
# [TRAIN] epoch=1 batch=12/35 loss=0.0000 lr=0.000060 speed=255.7s/s elapsed=7s eta=647s
# [TRAIN] epoch=1 batch=24/35 loss=0.0000 lr=0.000060 speed=255.6s/s elapsed=11s eta=452s
# [CKPT] epoch_end epoch=1 step=35
# [EPOCH] 1/30: train_loss=1.9639 val_loss=1.9145 val_acc=0.2773 macro_f1=0.0709 * BEST
# [TRAIN] epoch=2 batch=12/35 loss=0.0000 lr=0.000060 speed=255.7s/s elapsed=26s eta=557s
# [TRAIN] epoch=2 batch=24/35 loss=0.0000 lr=0.000060 speed=254.9s/s elapsed=29s eta=491s
# [CKPT] epoch_end epoch=2 step=70
# [EPOCH] 2/30: train_loss=1.9167 val_loss=1.8480 val_acc=0.2857 macro_f1=0.1495 * BEST
# [TRAIN] epoch=3 batch=12/35 loss=0.0000 lr=0.000059 speed=255.2s/s elapsed=43s eta=504s
# [TRAIN] epoch=3 batch=24/35 loss=0.0000 lr=0.000059 speed=254.4s/s elapsed=46s eta=466s
# [CKPT] epoch_end epoch=3 step=105
# [EPOCH] 3/30: train_loss=1.8386 val_loss=1.7200 val_acc=0.3866 macro_f1=0.2384 * BEST
# [TRAIN] epoch=4 batch=12/35 loss=0.0000 lr=0.000058 speed=254.9s/s elapsed=58s eta=466s
# [EPOCH] 19/30: train_loss=1.3129 val_loss=0.3619 val_acc=0.9076 macro_f1=0.8661 * BEST
# [TRAIN] epoch=20 batch=12/35 loss=0.0000 lr=0.000018 speed=255.6s/s elapsed=300s eta=165s
# [TRAIN] epoch=20 batch=24/35 loss=0.0000 lr=0.000017 speed=254.9s/s elapsed=303s eta=159s
# [CKPT] epoch_end epoch=20 step=700
# [EPOCH] 20/30: train_loss=1.3192 val_loss=0.3470 val_acc=0.9076 macro_f1=0.8661 * BEST
# [TRAIN] epoch=21 batch=12/35 loss=0.0000 lr=0.000015 speed=254.4s/s elapsed=315s eta=150s
# [TRAIN] epoch=21 batch=24/35 loss=0.0000 lr=0.000014 speed=255.7s/s elapsed=318s eta=143s
# [EPOCH] 21/30: train_loss=1.3103 val_loss=0.3568 val_acc=0.9076 macro_f1=0.8661
# [TRAIN] epoch=22 batch=12/35 loss=0.0000 lr=0.000012 speed=254.8s/s elapsed=328s eta=133s
# [CKPT] batch_250 epoch=22 step=750
# [TRAIN] epoch=22 batch=24/35 loss=0.0000 lr=0.000011 speed=254.3s/s elapsed=333s eta=127s
# [EPOCH] 22/30: train_loss=1.3165 val_loss=0.3630 val_acc=0.8908 macro_f1=0.8413
# [TRAIN] epoch=23 batch=12/35 loss=0.0000 lr=0.000010 speed=255.9s/s elapsed=342s eta=117s
# [TRAIN] epoch=23 batch=24/35 loss=0.0000 lr=0.000009 speed=255.4s/s elapsed=345s eta=111s
# [EPOCH] 23/30: train_loss=1.3065 val_loss=0.3884 val_acc=0.8908 macro_f1=0.8357
# [TRAIN] epoch=24 batch=12/35 loss=0.0000 lr=0.000008 speed=254.9s/s elapsed=354s eta=101s
# [TRAIN] epoch=24 batch=24/35 loss=0.0000 lr=0.000007 speed=255.9s/s elapsed=357s eta=95s
# [EPOCH] 24/30: train_loss=1.3120 val_loss=0.3580 val_acc=0.9076 macro_f1=0.8661
# [TRAIN] epoch=25 batch=12/35 loss=0.0000 lr=0.000006 speed=253.9s/s elapsed=366s eta=85s
# [TRAIN] epoch=25 batch=24/35 loss=0.0000 lr=0.000005 speed=256.0s/s elapsed=369s eta=80s
# [EPOCH] 25/30: train_loss=1.3061 val_loss=0.3572 val_acc=0.9076 macro_f1=0.8661
# [TRAIN] epoch=26 batch=12/35 loss=0.0000 lr=0.000004 speed=254.4s/s elapsed=380s eta=70s
# [TRAIN] epoch=26 batch=24/35 loss=0.0000 lr=0.000004 speed=255.4s/s elapsed=383s eta=64s
# [EPOCH] 26/30: train_loss=1.3120 val_loss=0.3752 val_acc=0.9076 macro_f1=0.8661
# [TRAIN] Complete. elapsed=388.6s stopped_early=True stopped_by_user=False cycles=1
# [OOD] Kalibrasyon tamamlandi. classes=7 version=1
# Cell 8: adapter save started
# Kaydedilen adapter klasoru: /content/bitirmeprojesi/outputs/colab_notebook_training/tomato/fruit/continual_sd_lora_adapter
#  - outputs/colab_notebook_training/tomato/fruit/continual_sd_lora_adapter/README.md
#  - outputs/colab_notebook_training/tomato/fruit/continual_sd_lora_adapter/adapter_config.json
#  - outputs/colab_notebook_training/tomato/fruit/continual_sd_lora_adapter/adapter_meta.json
#  - outputs/colab_notebook_training/tomato/fruit/continual_sd_lora_adapter/adapter_model.safetensors
#  - outputs/colab_notebook_training/tomato/fruit/continual_sd_lora_adapter/classifier.pth
#  - outputs/colab_notebook_training/tomato/fruit/continual_sd_lora_adapter/fusion.pth
# Telemetry adapter klasoru: /content/bitirmeprojesi/outputs/colab_notebook_training/telemetry_runtime/telemetry/tomato_fruit_2026-05-26_10-34-27/artifacts/adapter_export/tomato/fruit/continual_sd_lora_adapter
# Cell 8: adapter save completed
# [DOGRULAMA (referans)] ornek=119 sinif=7 accuracy=0.9076 ood_auroc=0.8916 sure_ds_f1=0.6004 conformal_cov=0.9580
# [TEST (ayrilmis)] ornek=119 sinif=7 accuracy=0.8992 ood_auroc=0.8208 sure_ds_f1=0.5699 conformal_cov=0.9496
# [OOD] kanit=real_ood_split durum=failed gecti=False
# [DONE] Dogrulama ve held-out test artefaktlari kaydedildi.
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
