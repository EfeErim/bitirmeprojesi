# %% [markdown]
# # Notebook 6: Batch Train All Continual SD-LoRA Adapters
#
# Bu notebook, Notebook 2 akisini baz alir ve tanimli adapterleri sirayla egitir.
#
# Akis:
# 1. Repo bootstrap ve Notebook 2 helper'larini yukle.
# 2. Adapter matrisi ve sirayi tanimla.
# 3. Her adapter icin Notebook 2 parametre, dataset validation, training, OOD calibration, export ve final evaluation hucrelerini calistir.
# 4. Her run icin ozet yazdir; runtime auto-disconnect batch bitene kadar kapali kalir.

# %%
from pathlib import Path
import os
import subprocess
import sys
from urllib.parse import urlsplit, urlunsplit

CLONE_TARGET = Path('/content/bitirmeprojesi')
REPO_URL = os.environ.get('AADS_REPO_URL', 'https://github.com/EfeErim/bitirmeprojesi.git')
NOTEBOOK6_SPARSE_PATHS = (
    'README.md',
    'docs',
    'src',
    'scripts',
    'config',
    'colab_notebooks',
    'requirements.txt',
    'requirements_colab.txt',
    'pyproject.toml',
)

def _build_repo_access_url(repo_url, token):
    token = str(token or '').strip()
    if not token:
        return repo_url
    parsed = urlsplit(str(repo_url or '').strip())
    if parsed.scheme != 'https' or not parsed.netloc:
        return repo_url
    netloc = parsed.netloc.split('@', 1)[-1]
    return urlunsplit((parsed.scheme, f'{token}@{netloc}', parsed.path, parsed.query, parsed.fragment))

def _ensure_aads_repo_on_path():
    candidates = [Path.cwd(), Path.cwd().parent, CLONE_TARGET, Path('/content/bitirmeprojesi'), Path('/content/bitirme projesi')]
    for candidate in candidates:
        marker = candidate / 'scripts' / 'notebook_helpers' / 'cell_script_runner.py'
        if marker.is_file():
            repo_root = candidate.resolve()
            if str(repo_root) not in sys.path:
                sys.path.insert(0, str(repo_root))
            return repo_root
    clone_url = _build_repo_access_url(REPO_URL, os.environ.get('GH_TOKEN') or os.environ.get('GITHUB_TOKEN'))
    if not CLONE_TARGET.exists():
        subprocess.run(['git', 'clone', '--depth', '1', '--filter=blob:none', '--sparse', clone_url, str(CLONE_TARGET)], check=True)
        subprocess.run(['git', 'sparse-checkout', 'set', *NOTEBOOK6_SPARSE_PATHS], cwd=str(CLONE_TARGET), check=True)
    if str(CLONE_TARGET) not in sys.path:
        sys.path.insert(0, str(CLONE_TARGET))
    return CLONE_TARGET

_ensure_aads_repo_on_path()

from scripts.notebook_helpers.cell_script_runner import run_cell_script
run_cell_script('nb2_cell01_bootstrap_access.py', globals())
# Out:
# [BOOTSTRAP] GitHub token found.
# [BOOTSTRAP] HuggingFace token found.
# [BOOTSTRAP] Repo root: /content/bitirmeprojesi
# [BOOTSTRAP] Installing requirements_colab.txt...
# [BOOTSTRAP] Notebook 2: Continual Adapter Training bootstrap complete.
#
# ======================================================================
# BOOTSTRAP STATUS
# ======================================================================
# Status: ok
# Repo Root: /content/bitirmeprojesi
# In Colab: True
# GitHub Token: ✓
# HuggingFace Token: ✓
# ======================================================================
#
# [SONRAKI] Parametre ve adapter secimi hucresine gecin; model erisimi ayrica access-check hucresinde dogrulanacak.

# %%
NOTEBOOK_NAME = "6_train_all_continual_sd_lora_adapters.ipynb"
NOTEBOOK_FILENAME = "6_train_all_continual_sd_lora_adapters.executed.ipynb"
AUTO_DISCONNECT_RUNTIME = False
AUTO_PUSH_TO_GITHUB = True
NB6_AUTO_DISCONNECT_RUNTIME = True
NB6_AUTO_DISCONNECT_GRACE_SECONDS = 20
ENABLE_BAYESIAN_OPTIMIZATION = True
MANUAL_PARAM_OVERRIDES = {}
DEFAULT_RUNTIME_PARAMS = {
    "AUTO_DISCONNECT_RUNTIME": False,
    "AUTO_PUSH_TO_GITHUB": True,
}
NB6_MANUAL_PARAM_OVERRIDES = {}

from scripts.notebook_helpers.adapter_recommendations import get_adapter_recs
ADAPTER_RECS = get_adapter_recs()

NB6_ADAPTER_SEQUENCE = [
    "apricot__leaf",
    "apricot__fruit",
    "strawberry__leaf",
    "strawberry__fruit",
    "grape__leaf",
    "grape__fruit",
    "tomato__leaf",
    "tomato__fruit",
]

# %%
import json

NB6_RESULTS = {}

for index, adapter_key in enumerate(NB6_ADAPTER_SEQUENCE, start=1):
    print(f"\n[NB6] Starting {index}/{len(NB6_ADAPTER_SEQUENCE)}: {adapter_key}")
    adapter_rec = ADAPTER_RECS[adapter_key]
    CROP_NAME = adapter_rec["crop"]
    PART_NAME = adapter_rec["part"]
    DATASET_NAME = adapter_key
    ADAPTER_KEY = adapter_key
    MANUAL_PARAM_OVERRIDES = dict(NB6_MANUAL_PARAM_OVERRIDES.get(adapter_key, {}))
    try:
        run_cell_script('nb2_cell03_runtime_setup.py', globals())
        run_cell_script('nb2_cell04_parameter_resolution.py', globals())
        run_cell_script('nb2_cell05_access_check.py', globals())
        run_cell_script('nb2_cell06_dataset_validation.py', globals())
        run_cell_script('nb2_cell07_engine_init.py', globals())
        run_cell_script('nb2_cell08_ood_config_verify.py', globals())
        run_cell_script('nb2_cell09_training.py', globals())
        run_cell_script('nb2_cell10_ood_calibration.py', globals())
        run_cell_script('nb2_cell11_adapter_save.py', globals())
        run_cell_script('nb2_cell12_final_evaluation.py', globals())
        NB6_RESULTS[adapter_key] = {
            "status": "ok",
            "run_id": str(globals().get("RUN_ID", "")),
            "crop": str(globals().get("CROP_NAME", "")),
            "part": str(globals().get("PART_NAME", "")),
        }
    except Exception as exc:
        NB6_RESULTS[adapter_key] = {
            "status": "failed",
            "error": str(exc),
            "run_id": str(globals().get("RUN_ID", "")),
            "crop": str(globals().get("CROP_NAME", "")),
            "part": str(globals().get("PART_NAME", "")),
        }
        print(f"[NB6] FAILED {adapter_key}: {exc}")
        continue

print('\n[NB6] SUMMARY')
print(json.dumps(NB6_RESULTS, indent=2, ensure_ascii=False))

from scripts.colab_notebook_helpers import maybe_auto_disconnect_colab_runtime

NB6_COMPLETION_REPORT = {
    "ready": True,
    "checks": {
        "batch_loop_completed": True,
        "all_adapters_attempted": len(NB6_RESULTS) == len(NB6_ADAPTER_SEQUENCE),
    },
    "missing": [],
    "soft_missing": [],
    "adapter_results": NB6_RESULTS,
}
maybe_auto_disconnect_colab_runtime(
    enabled=bool(NB6_AUTO_DISCONNECT_RUNTIME),
    grace_period_sec=float(NB6_AUTO_DISCONNECT_GRACE_SECONDS),
    telemetry=globals().get("TELEMETRY"),
    completion_report=NB6_COMPLETION_REPORT,
)
# Out:
# [NB6] Starting 1/8: apricot__leaf
# [BOOTSTRAP] run_id=apricot_leaf_2026-05-25_16-51-40 crop=apricot part=leaf
# [ADAPTER_SELECTED] key=apricot__leaf crop=apricot part=leaf dataset=apricot__leaf ood=data/prepared_runtime_datasets/apricot__leaf/ood oe_enabled=True oe=data/prepared_runtime_datasets/apricot__leaf/oe run_id=apricot_leaf_2026-05-25_16-51-40
# [TRAINING_PLAN] epochs=24 batch=52 lr=0.00012 lora_r=20 allow_under_min=False validation_every=1
# [SONRAKI] Erisim kontrolu -> dataset validation -> engine init -> training -> calibration -> save/eval hucresini sirayla calistirin.
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# [HF] Kimlik dogrulandi: Grizzmann
# [GIT] Auto-push on kontrolu gecti: GitHub token cozuldu.
# [CONFIG] source=notebook_cell crop=apricot epochs=12 bs=96 lr=0.0002 resume=fresh ber=False loss=logitnorm tau=1.0 auto_disconnect=True auto_push=True bayes_opt=True
# [DATASET] runtime_root=data/prepared_runtime_datasets dataset_name=apricot__leaf
# [OOD] ood_root=data/prepared_runtime_datasets/apricot__leaf/ood ask_for_ood_root=False
# [OE] oe_root=data/prepared_runtime_datasets/apricot__leaf/oe ask_for_oe_root=False enabled=True loss_weight=0.3
# [RUNTIME] defaults=notebook_cell mp=bf16 workers=12 prefetch=8 sched=cosine wd=0.01 accum=1 grad_clip=1.0 label_smooth=0.0 warmup=0.1 early_stop=5/0.0 val_every=1 cache_train=True aug=randaugment randaug=2/7
# [OOD] factor=3.0 sure=90.0/97.0 conformal=raps alpha=0.05 raps_lambda=0.2 raps_k=1
# [KONTROL] Repo guncel gorunuyor.
# [KONTROL] GitHub okuma erisimi public; clone/pull icin ekstra token gerekmiyor.
# [KONTROL] GitHub push icin kimlik bilgisi hazir.
# [KONTROL] Gerekli Hugging Face modelleri anonim erisimle aciliyor.
# [BOOTSTRAP] Fetching selected Notebook 2 dataset paths: ['data/prepared_runtime_datasets/apricot__leaf', 'data/ood_dataset/final/apricot__leaf_ood_final', 'data/oe_dataset/apricot_leaf_oe_unsupported_leaf_candidates', 'data/prepared_runtime_datasets/apricot__leaf/ood', 'data/prepared_runtime_datasets/apricot__leaf/oe']
# [OOD] explicit ood root=/content/bitirmeprojesi/data/prepared_runtime_datasets/apricot__leaf/ood
# [OE] explicit oe root=/content/bitirmeprojesi/data/prepared_runtime_datasets/apricot__leaf/oe
# [DATASET] runtime root=/content/bitirmeprojesi/data/prepared_runtime_datasets/apricot__leaf classes=3: ['kayısı_sağlıklı_yaprak_302', 'kayısı_şarka_virüsü_yaprak_206', 'kayısı_yaprak_delen_çil_hastalığı_yaprak_300']
# [DATASET][CHECK] scale=small continual=508 val=150 test=150 ood=104 classes=3
# [PARAMS] Manual overrides uygulandi: {'EPOCHS': 24, 'BATCH_SIZE': 52, 'LEARNING_RATE': 0.00012, 'LORA_R': 20, 'LORA_ALPHA': 24, 'LORA_DROPOUT': 0.1, 'OOD_FACTOR': 4.0, 'LABEL_SMOOTHING': 0.1, 'OE_LOSS_WEIGHT': 0.3, 'REACT_ENABLED': True, 'REACT_PERCENTILE': 0.985, 'FUSION_DROPOUT': 0.1, 'CLASSIFIER_REBALANCE_ENABLED': True, 'CLASSIFIER_REBALANCE_LOGIT_ADJUSTMENT_TAU': 1.1, 'AUTO_DISCONNECT_RUNTIME': False, 'AUTO_PUSH_TO_GITHUB': True, 'WEIGHT_DECAY': 0.01, 'LOSS_NAME': 'logitnorm', 'LOGITNORM_TAU': 1.0, 'MIXED_PRECISION': 'bf16', 'GRAD_ACCUM_STEPS': 1, 'VALIDATION_EVERY_N_EPOCHS': 1, 'EARLY_STOPPING_PATIENCE': 6, 'RANDAUGMENT_NUM_OPS': 2, 'RANDAUGMENT_MAGNITUDE': 7, 'NUM_WORKERS': 12, 'PREFETCH': 8, 'CACHE_TRAIN_SPLIT': True, 'ENABLE_BAYESIAN_OPTIMIZATION': True}
# [PARAMS][FINAL] epochs=24 bs=52 lr=0.00012 lora=20/24 dropout=0.1 accum=1 workers=12 prefetch=8
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
# [OPT] No prior comparable run yet. Bootstrap run will use the visible notebook parameters.
# [OOD] selected ood root=/content/bitirmeprojesi/data/prepared_runtime_datasets/apricot__leaf/ood
# [OE] selected oe root=/content/bitirmeprojesi/data/prepared_runtime_datasets/apricot__leaf/oe
# [CLASSES] ['kayısı_şarka_virüsü_yaprak_206', 'kayısı_sağlıklı_yaprak_302', 'kayısı_yaprak_delen_çil_hastalığı_yaprak_300']
# [CLASSES] mode=dataset_fallback reason=partial_taxonomy_alignment_fallback matched=0 unmatched=3
# [CLASSES] taxonomy-unmatched classes kept: ['kayısı_s_arka_viru_su_yaprak_206', 'kayısı_sag_lıklı_yaprak_302', 'kayısı_yaprak_delen_c_il_hastalıg_ı_yaprak_300']
# [ENGINE][OOD_CFG] {"ber_enabled": false, "ber_lambda_new": 0.1, "ber_lambda_old": 0.1, "ber_warmup_steps": 50, "conformal_alpha": 0.05, "conformal_enabled": true, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "energy_temperature": 1.0, "energy_temperature_mode": "auto", "energy_temperature_range": [0.5, 3.0], "energy_temperature_steps": 16, "enforce_oe_disjoint": true, "knn_backend": "auto", "knn_chunk_size": 2048, "oe_enabled": true, "oe_loss_weight": 0.3, "oe_root": "/content/bitirmeprojesi/data/prepared_runtime_datasets/apricot__leaf/oe", "oe_target": "uniform", "primary_score_method": "auto", "radial_beta_range": [0.5, 2.0], "radial_beta_steps": 16, "radial_l2_enabled": true, "react_apply_during_calibration": true, "react_apply_during_inference": true, "react_enabled": true, "react_percentile": 0.985, "real_dev_selection_enabled": true, "real_dev_target_fpr": 0.05, "real_split_dev_fraction": 0.4, "real_split_enabled": true, "real_split_manifest_name": "ood_split_manifest.json", "real_split_min_per_slice": 2, "real_split_min_total": 30, "sure_confidence_percentile": 97.0, "sure_enabled": true, "sure_semantic_percentile": 90.0, "threshold_factor": 4.0}
# [ENGINE][OPT_CFG] loss=logitnorm tau=1.0 label_smoothing=0.1 mixed_precision=bf16
# [ENGINE] Initializing adapter (may download backbone)...
# config.json:   0%|          | 0.00/745 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.21G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/415 [00:00<?, ?it/s]
# [ENGINE] Hazir. trainable_params=12,000,007  classes=3
# [VERIFY][OOD][expected] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 4.0}
# [VERIFY][OOD][resolved] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 4.0}
# [VERIFY][OOD] OK: cozulmus OOD ayari istenen parametrelerle eslesiyor.
# [TRAIN] epochs=24 device=cuda batch_interval=12
# [CKPT] epoch_end epoch=1 step=9
# [EPOCH] 1/24: train_loss=1.1124 val_loss=1.0895 val_acc=0.3933 macro_f1=0.1891 * BEST
# [CKPT] epoch_end epoch=2 step=18
# [EPOCH] 2/24: train_loss=1.0874 val_loss=1.0362 val_acc=0.4400 macro_f1=0.3389 * BEST
# [CKPT] epoch_end epoch=3 step=27
# [EPOCH] 3/24: train_loss=1.0773 val_loss=1.0359 val_acc=0.4533 macro_f1=0.4049 * BEST
# [CKPT] epoch_end epoch=4 step=36
# [EPOCH] 4/24: train_loss=1.0499 val_loss=0.9854 val_acc=0.4800 macro_f1=0.4315 * BEST
# [CKPT] epoch_end epoch=5 step=45
# [EPOCH] 5/24: train_loss=0.9480 val_loss=0.9714 val_acc=0.5000 macro_f1=0.4235 * BEST
# [CKPT] epoch_end epoch=6 step=54
# [EPOCH] 6/24: train_loss=0.8934 val_loss=0.8394 val_acc=0.5600 macro_f1=0.5315 * BEST
# [EPOCH] 7/24: train_loss=0.8427 val_loss=0.8847 val_acc=0.5600 macro_f1=0.5329
# [CKPT] epoch_end epoch=8 step=72
# [EPOCH] 8/24: train_loss=0.7978 val_loss=0.8165 val_acc=0.6400 macro_f1=0.6351 * BEST
# [CKPT] epoch_end epoch=9 step=81
# [EPOCH] 9/24: train_loss=0.7566 val_loss=0.7694 val_acc=0.6933 macro_f1=0.6922 * BEST
# [EPOCH] 10/24: train_loss=0.7348 val_loss=0.8438 val_acc=0.6467 macro_f1=0.6440
# [CKPT] epoch_end epoch=11 step=99
# [EPOCH] 11/24: train_loss=0.7154 val_loss=0.7271 val_acc=0.7267 macro_f1=0.7251 * BEST
# [CKPT] epoch_end epoch=12 step=108
# [EPOCH] 12/24: train_loss=0.7021 val_loss=0.6972 val_acc=0.7467 macro_f1=0.7466 * BEST
# [CKPT] epoch_end epoch=13 step=117
# [EPOCH] 13/24: train_loss=0.6973 val_loss=0.6359 val_acc=0.7600 macro_f1=0.7600 * BEST
# [EPOCH] 14/24: train_loss=0.6646 val_loss=0.7160 val_acc=0.7333 macro_f1=0.7334
# [EPOCH] 15/24: train_loss=0.6453 val_loss=0.6404 val_acc=0.7800 macro_f1=0.7786
# [EPOCH] 16/24: train_loss=0.6645 val_loss=0.6750 val_acc=0.7933 macro_f1=0.7918
# [CKPT] epoch_end epoch=17 step=153
# [EPOCH] 17/24: train_loss=0.6644 val_loss=0.6168 val_acc=0.7600 macro_f1=0.7601 * BEST
# [CKPT] epoch_end epoch=18 step=162
# [EPOCH] 18/24: train_loss=0.6491 val_loss=0.6086 val_acc=0.8133 macro_f1=0.8110 * BEST
# [EPOCH] 19/24: train_loss=0.6257 val_loss=0.6180 val_acc=0.7933 macro_f1=0.7924
# [EPOCH] 20/24: train_loss=0.6368 val_loss=0.6117 val_acc=0.7800 macro_f1=0.7795
# [CKPT] epoch_end epoch=21 step=189
# [EPOCH] 21/24: train_loss=0.6312 val_loss=0.5936 val_acc=0.8000 macro_f1=0.7988 * BEST
# [CKPT] epoch_end epoch=22 step=198
# [EPOCH] 22/24: train_loss=0.6317 val_loss=0.5910 val_acc=0.8000 macro_f1=0.7988 * BEST
# [EPOCH] 23/24: train_loss=0.6318 val_loss=0.5951 val_acc=0.8067 macro_f1=0.8051
# [CKPT] epoch_end epoch=24 step=216
# [EPOCH] 24/24: train_loss=0.6233 val_loss=0.5953 val_acc=0.8133 macro_f1=0.8114
# [TRAIN] Complete. elapsed=140.5s stopped_early=False stopped_by_user=False cycles=1
# [OOD] Kalibrasyon tamamlandi. classes=3 version=1
# Cell 8: adapter save started
# Kaydedilen adapter klasoru: /content/bitirmeprojesi/outputs/colab_notebook_training/apricot/leaf/continual_sd_lora_adapter
#  - outputs/colab_notebook_training/apricot/leaf/continual_sd_lora_adapter/README.md
#  - outputs/colab_notebook_training/apricot/leaf/continual_sd_lora_adapter/adapter_config.json
#  - outputs/colab_notebook_training/apricot/leaf/continual_sd_lora_adapter/adapter_meta.json
#  - outputs/colab_notebook_training/apricot/leaf/continual_sd_lora_adapter/adapter_model.safetensors
#  - outputs/colab_notebook_training/apricot/leaf/continual_sd_lora_adapter/classifier.pth
#  - outputs/colab_notebook_training/apricot/leaf/continual_sd_lora_adapter/fusion.pth
# Telemetry adapter klasoru: /content/bitirmeprojesi/outputs/colab_notebook_training/telemetry_runtime/telemetry/apricot_leaf_2026-05-25_16-51-40/artifacts/adapter_export/apricot/leaf/continual_sd_lora_adapter
# Cell 8: adapter save completed
# [DOGRULAMA (referans)] ornek=150 sinif=3 accuracy=0.8200 ood_auroc=0.6341 sure_ds_f1=0.1971 conformal_cov=0.9200
# [TEST (ayrilmis)] ornek=150 sinif=3 accuracy=0.8133 ood_auroc=0.6354 sure_ds_f1=0.1992 conformal_cov=0.9067
# [OOD] kanit=real_ood_split durum=failed gecti=False
# [DONE] Dogrulama ve held-out test artefaktlari kaydedildi.
# /usr/local/lib/python3.12/dist-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k1__constant_value is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
# [RUNS] checkpoint_state -> /content/bitirmeprojesi/runs/apricot/leaf/apricot_leaf_2026-05-25_16-51-40/checkpoint_state
# [RUNS] outputs -> /content/bitirmeprojesi/runs/apricot/leaf/apricot_leaf_2026-05-25_16-51-40/outputs/colab_notebook_training
# [RUNS] telemetry -> /content/bitirmeprojesi/runs/apricot/leaf/apricot_leaf_2026-05-25_16-51-40/telemetry
# [RUNS] notebook -> /content/bitirmeprojesi/runs/apricot/leaf/apricot_leaf_2026-05-25_16-51-40/notebooks/6_train_all_continual_sd_lora_adapters.executed.ipynb
# [GIT] Local branch realigned to origin/master before secure run push.
# [SECURITY] scanned=145 redacted_files=62
# [GIT] Stage prepared for runs/apricot/leaf/apricot_leaf_2026-05-25_16-51-40: staged=369 skipped=3
# [GIT] Pushed 369 file(s) from runs/apricot/leaf/apricot_leaf_2026-05-25_16-51-40 to origin/master.
# [COLAB] completion checks -> {'evaluation_artifacts': True, 'production_readiness': True, 'telemetry_summary': True, 'repo_exports': True, 'executed_notebook_export': True}
# [COLAB] Auto-disconnect disabled.
#
# [NB6] Starting 2/8: apricot__fruit
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# [BOOTSTRAP] run_id=apricot_fruit_2026-05-25_16-55-03 crop=apricot part=fruit
# [ADAPTER_SELECTED] key=apricot__fruit crop=apricot part=fruit dataset=apricot__fruit ood=data/prepared_runtime_datasets/apricot__fruit/ood oe_enabled=True oe=data/prepared_runtime_datasets/apricot__fruit/oe run_id=apricot_fruit_2026-05-25_16-55-03
# [TRAINING_PLAN] epochs=36 batch=40 lr=0.0001 lora_r=20 allow_under_min=False validation_every=1
# [SONRAKI] Erisim kontrolu -> dataset validation -> engine init -> training -> calibration -> save/eval hucresini sirayla calistirin.
# [HF] Kimlik dogrulandi: Grizzmann
# [GIT] Auto-push on kontrolu gecti: GitHub token cozuldu.
# [CONFIG] source=notebook_cell crop=apricot epochs=12 bs=96 lr=0.0002 resume=fresh ber=False loss=logitnorm tau=1.0 auto_disconnect=True auto_push=True bayes_opt=True
# [DATASET] runtime_root=data/prepared_runtime_datasets dataset_name=apricot__fruit
# [OOD] ood_root=data/prepared_runtime_datasets/apricot__fruit/ood ask_for_ood_root=False
# [OE] oe_root=data/prepared_runtime_datasets/apricot__fruit/oe ask_for_oe_root=False enabled=True loss_weight=0.3
# [RUNTIME] defaults=notebook_cell mp=bf16 workers=12 prefetch=8 sched=cosine wd=0.01 accum=1 grad_clip=1.0 label_smooth=0.0 warmup=0.1 early_stop=5/0.0 val_every=1 cache_train=True aug=randaugment randaug=2/7
# [OOD] factor=3.0 sure=90.0/97.0 conformal=raps alpha=0.05 raps_lambda=0.2 raps_k=1
# [KONTROL] Repo guncel gorunuyor.
# [KONTROL] GitHub okuma erisimi public; clone/pull icin ekstra token gerekmiyor.
# [KONTROL] GitHub push icin kimlik bilgisi hazir.
# [KONTROL] Gerekli Hugging Face modelleri anonim erisimle aciliyor.
# [BOOTSTRAP] Fetching selected Notebook 2 dataset paths: ['data/prepared_runtime_datasets/apricot__fruit', 'data/ood_dataset/final/apricot__fruit_ood_final', 'data/prepared_runtime_datasets/apricot__fruit/ood', 'data/prepared_runtime_datasets/apricot__fruit/oe']
# [OOD] explicit ood root=/content/bitirmeprojesi/data/prepared_runtime_datasets/apricot__fruit/ood
# [OE] explicit oe root=/content/bitirmeprojesi/data/prepared_runtime_datasets/apricot__fruit/oe
# [DATASET] runtime root=/content/bitirmeprojesi/data/prepared_runtime_datasets/apricot__fruit classes=5: ['kayısı_sağlıklı_meyve_800', 'kayısıda_çiçek_monilyası_meyve_40', 'kayısıda_şarka_virüsü_meyve_230', 'kayısıda_şeftali_karalekesi_meyve_232', 'kayısıda_yaprak_delen_çil_hastalığı_meyve_128']
# [DATASET][CHECK] scale=small continual=871 val=280 test=280 ood=103 classes=5
# [DATASET][WARN] Manifest rows include 2 eval-quality-risk item(s); prefer cautious regularization.
# [DATASET][BLOCK] Supported classes remain below the production minimum of 100 images/class: kayısıda_çiçek_monilyası_meyve_40=40. Enable ALLOW_UNDER_MIN_TRAINING manually only for a research-only run.
# [PARAMS] Manual overrides uygulandi: {'EPOCHS': 36, 'BATCH_SIZE': 40, 'LEARNING_RATE': 0.0001, 'LORA_R': 20, 'LORA_ALPHA': 20, 'LORA_DROPOUT': 0.2, 'OOD_FACTOR': 2.25, 'LABEL_SMOOTHING': 0.12, 'OE_LOSS_WEIGHT': 0.3, 'REACT_ENABLED': True, 'REACT_PERCENTILE': 0.985, 'FUSION_DROPOUT': 0.12, 'CLASSIFIER_REBALANCE_ENABLED': True, 'CLASSIFIER_REBALANCE_LOGIT_ADJUSTMENT_TAU': 1.1, 'AUTO_DISCONNECT_RUNTIME': False, 'AUTO_PUSH_TO_GITHUB': True, 'WEIGHT_DECAY': 0.01, 'LOSS_NAME': 'logitnorm', 'LOGITNORM_TAU': 1.0, 'MIXED_PRECISION': 'bf16', 'GRAD_ACCUM_STEPS': 1, 'VALIDATION_EVERY_N_EPOCHS': 1, 'EARLY_STOPPING_PATIENCE': 6, 'RANDAUGMENT_NUM_OPS': 2, 'RANDAUGMENT_MAGNITUDE': 7, 'NUM_WORKERS': 12, 'PREFETCH': 8, 'CACHE_TRAIN_SPLIT': True, 'ENABLE_BAYESIAN_OPTIMIZATION': True}
# [PARAMS][FINAL] epochs=36 bs=40 lr=0.0001 lora=20/20 dropout=0.2 accum=1 workers=12 prefetch=8
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
# [OPT] No prior comparable run yet. Bootstrap run will use the visible notebook parameters.
# [OOD] selected ood root=/content/bitirmeprojesi/data/prepared_runtime_datasets/apricot__fruit/ood
# [OE] selected oe root=/content/bitirmeprojesi/data/prepared_runtime_datasets/apricot__fruit/oe
# [CLASSES] ['kayısı_sağlıklı_meyve_800', 'kayısıda_çiçek_monilyası_meyve_40', 'kayısıda_şarka_virüsü_meyve_230', 'kayısıda_şeftali_karalekesi_meyve_232', 'kayısıda_yaprak_delen_çil_hastalığı_meyve_128']
# [CLASSES] mode=dataset_fallback reason=partial_taxonomy_alignment_fallback matched=0 unmatched=5
# [CLASSES] taxonomy-unmatched classes kept: ['kayısı_sag_lıklı_meyve_800', 'kayısıda_c_ic_ek_monilyası_meyve_40', 'kayısıda_s_arka_viru_su_meyve_230', 'kayısıda_s_eftali_karalekesi_meyve_232', 'kayısıda_yaprak_delen_c_il_hastalıg_ı_meyve_128']
# [ENGINE][OOD_CFG] {"ber_enabled": false, "ber_lambda_new": 0.1, "ber_lambda_old": 0.1, "ber_warmup_steps": 50, "conformal_alpha": 0.05, "conformal_enabled": true, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "energy_temperature": 1.0, "energy_temperature_mode": "auto", "energy_temperature_range": [0.5, 3.0], "energy_temperature_steps": 16, "enforce_oe_disjoint": true, "knn_backend": "auto", "knn_chunk_size": 2048, "oe_enabled": true, "oe_loss_weight": 0.3, "oe_root": "/content/bitirmeprojesi/data/prepared_runtime_datasets/apricot__fruit/oe", "oe_target": "uniform", "primary_score_method": "auto", "radial_beta_range": [0.5, 2.0], "radial_beta_steps": 16, "radial_l2_enabled": true, "react_apply_during_calibration": true, "react_apply_during_inference": true, "react_enabled": true, "react_percentile": 0.985, "real_dev_selection_enabled": true, "real_dev_target_fpr": 0.05, "real_split_dev_fraction": 0.4, "real_split_enabled": true, "real_split_manifest_name": "ood_split_manifest.json", "real_split_min_per_slice": 2, "real_split_min_total": 30, "sure_confidence_percentile": 97.0, "sure_enabled": true, "sure_semantic_percentile": 90.0, "threshold_factor": 2.25}
# [ENGINE][OPT_CFG] loss=logitnorm tau=1.0 label_smoothing=0.12 mixed_precision=bf16
# [ENGINE] Initializing adapter (may download backbone)...
# Loading weights:   0%|          | 0/415 [00:00<?, ?it/s]
# [ENGINE] Hazir. trainable_params=12,001,545  classes=5
# [VERIFY][OOD][expected] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 2.25}
# [VERIFY][OOD][resolved] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 2.25}
# [VERIFY][OOD] OK: cozulmus OOD ayari istenen parametrelerle eslesiyor.
# [TRAIN] epochs=36 device=cuda batch_interval=12
# [TRAIN] epoch=1 batch=12/21 loss=0.0000 lr=0.000100 speed=231.4s/s elapsed=4s eta=253s
# [CKPT] epoch_end epoch=1 step=21
# [EPOCH] 1/36: train_loss=1.6255 val_loss=1.5153 val_acc=0.1571 macro_f1=0.0543 * BEST
# [TRAIN] epoch=2 batch=12/21 loss=0.0000 lr=0.000100 speed=231.6s/s elapsed=15s eta=319s
# [EPOCH] 2/36: train_loss=1.6084 val_loss=1.6746 val_acc=0.1643 macro_f1=0.0711
# [TRAIN] epoch=3 batch=12/21 loss=0.0000 lr=0.000099 speed=231.2s/s elapsed=21s eta=274s
# [CKPT] epoch_end epoch=3 step=63
# [EPOCH] 3/36: train_loss=1.5950 val_loss=1.4851 val_acc=0.2214 macro_f1=0.2141 * BEST
# [TRAIN] epoch=4 batch=12/21 loss=0.0000 lr=0.000098 speed=231.3s/s elapsed=30s eta=276s
# [CKPT] epoch_end epoch=4 step=84
# [EPOCH] 4/36: train_loss=1.4937 val_loss=0.9847 val_acc=0.6857 macro_f1=0.4911 * BEST
# [TRAIN] epoch=5 batch=12/21 loss=0.0000 lr=0.000096 speed=228.8s/s elapsed=39s eta=270s
# [CKPT] epoch_end epoch=5 step=105
# [EPOCH] 5/36: train_loss=1.2902 val_loss=0.6029 val_acc=0.8214 macro_f1=0.6288 * BEST
# [TRAIN] epoch=6 batch=12/21 loss=0.0000 lr=0.000094 speed=228.5s/s elapsed=48s eta=260s
# [CKPT] epoch_end epoch=6 step=126
# [EPOCH] 6/36: train_loss=1.1944 val_loss=0.4176 val_acc=0.8607 macro_f1=0.6658 * BEST
# [TRAIN] epoch=7 batch=12/21 loss=0.0000 lr=0.000092 speed=227.6s/s elapsed=56s eta=252s
# [EPOCH] 7/36: train_loss=1.1387 val_loss=0.4278 val_acc=0.8714 macro_f1=0.6991
# [TRAIN] epoch=8 batch=12/21 loss=0.0000 lr=0.000090 speed=230.5s/s elapsed=64s eta=242s
# [CKPT] epoch_end epoch=8 step=168
# [EPOCH] 8/36: train_loss=1.1243 val_loss=0.2899 val_acc=0.8893 macro_f1=0.7665 * BEST
# [TRAIN] epoch=9 batch=12/21 loss=0.0000 lr=0.000087 speed=230.7s/s elapsed=73s eta=233s
# [EPOCH] 9/36: train_loss=1.1097 val_loss=0.3052 val_acc=0.8714 macro_f1=0.7463
# [TRAIN] epoch=10 batch=12/21 loss=0.0000 lr=0.000084 speed=231.4s/s elapsed=79s eta=217s
# [CKPT] epoch_end epoch=10 step=210
# [EPOCH] 10/36: train_loss=1.0894 val_loss=0.2615 val_acc=0.8893 macro_f1=0.7851 * BEST
# [TRAIN] epoch=11 batch=12/21 loss=0.0000 lr=0.000080 speed=230.6s/s elapsed=87s eta=210s
# [EPOCH] 11/36: train_loss=1.0931 val_loss=0.2668 val_acc=0.8893 macro_f1=0.7759
# [TRAIN] epoch=12 batch=12/21 loss=0.0000 lr=0.000077 speed=230.3s/s elapsed=93s eta=196s
# [CKPT] batch_250 epoch=12 step=250
# [EPOCH] 12/36: train_loss=1.0694 val_loss=0.2757 val_acc=0.8857 macro_f1=0.7818
# [TRAIN] epoch=13 batch=12/21 loss=0.0000 lr=0.000073 speed=223.8s/s elapsed=100s eta=187s
# [EPOCH] 13/36: train_loss=1.0550 val_loss=0.3292 val_acc=0.8929 macro_f1=0.7838
# [TRAIN] epoch=14 batch=12/21 loss=0.0000 lr=0.000069 speed=230.8s/s elapsed=106s eta=175s
# [CKPT] epoch_end epoch=14 step=294
# [EPOCH] 14/36: train_loss=1.0403 val_loss=0.2610 val_acc=0.9107 macro_f1=0.8454 * BEST
# [TRAIN] epoch=15 batch=12/21 loss=0.0000 lr=0.000065 speed=226.5s/s elapsed=114s eta=168s
# [CKPT] epoch_end epoch=15 step=315
# [EPOCH] 15/36: train_loss=1.0325 val_loss=0.2528 val_acc=0.9179 macro_f1=0.8487 * BEST
# [TRAIN] epoch=16 batch=12/21 loss=0.0000 lr=0.000061 speed=228.7s/s elapsed=123s eta=162s
# [EPOCH] 16/36: train_loss=1.0170 val_loss=0.2732 val_acc=0.9179 macro_f1=0.8439
# [TRAIN] epoch=17 batch=12/21 loss=0.0000 lr=0.000057 speed=231.3s/s elapsed=129s eta=151s
# [EPOCH] 17/36: train_loss=1.0196 val_loss=0.2687 val_acc=0.9179 macro_f1=0.8527
# [TRAIN] epoch=18 batch=12/21 loss=0.0000 lr=0.000052 speed=229.3s/s elapsed=135s eta=141s
# [CKPT] epoch_end epoch=18 step=378
# [EPOCH] 18/36: train_loss=1.0185 val_loss=0.2252 val_acc=0.9250 macro_f1=0.8700 * BEST
# [TRAIN] epoch=19 batch=12/21 loss=0.0000 lr=0.000048 speed=230.8s/s elapsed=143s eta=134s
# [EPOCH] 19/36: train_loss=1.0092 val_loss=0.2940 val_acc=0.9250 macro_f1=0.8677
# [TRAIN] epoch=20 batch=12/21 loss=0.0000 lr=0.000044 speed=227.3s/s elapsed=149s eta=125s
# [EPOCH] 20/36: train_loss=0.9944 val_loss=0.2280 val_acc=0.9500 macro_f1=0.9262
# [TRAIN] epoch=21 batch=12/21 loss=0.0000 lr=0.000039 speed=231.4s/s elapsed=156s eta=117s
# [EPOCH] 21/36: train_loss=0.9863 val_loss=0.2278 val_acc=0.9429 macro_f1=0.9090
# [TRAIN] epoch=22 batch=12/21 loss=0.0000 lr=0.000035 speed=230.7s/s elapsed=161s eta=108s
# [CKPT] epoch_end epoch=22 step=462
# [EPOCH] 22/36: train_loss=1.0021 val_loss=0.2174 val_acc=0.9536 macro_f1=0.9224 * BEST
# [TRAIN] epoch=23 batch=12/21 loss=0.0000 lr=0.000031 speed=231.2s/s elapsed=170s eta=101s
# [EPOCH] 23/36: train_loss=0.9991 val_loss=0.2299 val_acc=0.9393 macro_f1=0.9044
# [TRAIN] epoch=24 batch=12/21 loss=0.0000 lr=0.000027 speed=227.4s/s elapsed=176s eta=93s
# [CKPT] batch_250 epoch=24 step=500
# [EPOCH] 24/36: train_loss=0.9899 val_loss=0.2270 val_acc=0.9429 macro_f1=0.9070
# [TRAIN] epoch=25 batch=12/21 loss=0.0000 lr=0.000024 speed=230.6s/s elapsed=184s eta=86s
# [EPOCH] 25/36: train_loss=0.9882 val_loss=0.2406 val_acc=0.9393 macro_f1=0.9009
# [TRAIN] epoch=26 batch=12/21 loss=0.0000 lr=0.000020 speed=231.1s/s elapsed=191s eta=78s
# [EPOCH] 26/36: train_loss=0.9873 val_loss=0.2322 val_acc=0.9393 macro_f1=0.9009
# [TRAIN] epoch=27 batch=12/21 loss=0.0000 lr=0.000017 speed=231.3s/s elapsed=196s eta=70s
# [EPOCH] 27/36: train_loss=0.9814 val_loss=0.2375 val_acc=0.9429 macro_f1=0.9076
# [TRAIN] epoch=28 batch=12/21 loss=0.0000 lr=0.000014 speed=232.1s/s elapsed=202s eta=62s
# [EPOCH] 28/36: train_loss=0.9778 val_loss=0.2309 val_acc=0.9464 macro_f1=0.9138
# [TRAIN] Complete. elapsed=205.0s stopped_early=True stopped_by_user=False cycles=1
# [OOD] Kalibrasyon tamamlandi. classes=5 version=1
# Cell 8: adapter save started
# Kaydedilen adapter klasoru: /content/bitirmeprojesi/outputs/colab_notebook_training/apricot/fruit/continual_sd_lora_adapter
#  - outputs/colab_notebook_training/apricot/fruit/continual_sd_lora_adapter/README.md
#  - outputs/colab_notebook_training/apricot/fruit/continual_sd_lora_adapter/adapter_config.json
#  - outputs/colab_notebook_training/apricot/fruit/continual_sd_lora_adapter/adapter_meta.json
#  - outputs/colab_notebook_training/apricot/fruit/continual_sd_lora_adapter/adapter_model.safetensors
#  - outputs/colab_notebook_training/apricot/fruit/continual_sd_lora_adapter/classifier.pth
#  - outputs/colab_notebook_training/apricot/fruit/continual_sd_lora_adapter/fusion.pth
# Telemetry adapter klasoru: /content/bitirmeprojesi/outputs/colab_notebook_training/telemetry_runtime/telemetry/apricot_fruit_2026-05-25_16-55-03/artifacts/adapter_export/apricot/fruit/continual_sd_lora_adapter
# Cell 8: adapter save completed
# [DOGRULAMA (referans)] ornek=280 sinif=5 accuracy=0.9464 ood_auroc=0.9210 sure_ds_f1=0.4539 conformal_cov=0.9536
# [TEST (ayrilmis)] ornek=280 sinif=5 accuracy=0.9500 ood_auroc=0.9180 sure_ds_f1=0.4153 conformal_cov=0.9643
# [OOD] kanit=real_ood_split durum=failed gecti=False
# [DONE] Dogrulama ve held-out test artefaktlari kaydedildi.
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
# [RUNS] checkpoint_state -> /content/bitirmeprojesi/runs/apricot/fruit/apricot_fruit_2026-05-25_16-55-03/checkpoint_state
# [RUNS] outputs -> /content/bitirmeprojesi/runs/apricot/fruit/apricot_fruit_2026-05-25_16-55-03/outputs/colab_notebook_training
# [RUNS] telemetry -> /content/bitirmeprojesi/runs/apricot/fruit/apricot_fruit_2026-05-25_16-55-03/telemetry
# [RUNS] notebook -> /content/bitirmeprojesi/runs/apricot/fruit/apricot_fruit_2026-05-25_16-55-03/notebooks/6_train_all_continual_sd_lora_adapters.executed.ipynb
# [GIT] Local branch realigned to origin/master before secure run push.
# [SECURITY] scanned=148 redacted_files=64
# [GIT] Stage prepared for runs/apricot/fruit/apricot_fruit_2026-05-25_16-55-03: staged=413 skipped=3
# [GIT] Pushed 413 file(s) from runs/apricot/fruit/apricot_fruit_2026-05-25_16-55-03 to origin/master.
# [COLAB] completion checks -> {'evaluation_artifacts': True, 'production_readiness': True, 'telemetry_summary': True, 'repo_exports': True, 'executed_notebook_export': True}
# [COLAB] Auto-disconnect disabled.
#
# [NB6] Starting 3/8: strawberry__leaf
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# [BOOTSTRAP] run_id=strawberry_leaf_2026-05-25_16-59-18 crop=strawberry part=leaf
# [ADAPTER_SELECTED] key=strawberry__leaf crop=strawberry part=leaf dataset=strawberry__leaf ood=data/prepared_runtime_datasets/strawberry__leaf/ood oe_enabled=True oe=data/prepared_runtime_datasets/strawberry__leaf/oe run_id=strawberry_leaf_2026-05-25_16-59-18
# [TRAINING_PLAN] epochs=24 batch=88 lr=0.00012 lora_r=24 allow_under_min=False validation_every=1
# [SONRAKI] Erisim kontrolu -> dataset validation -> engine init -> training -> calibration -> save/eval hucresini sirayla calistirin.
# [HF] Kimlik dogrulandi: Grizzmann
# [GIT] Auto-push on kontrolu gecti: GitHub token cozuldu.
# [CONFIG] source=notebook_cell crop=strawberry epochs=12 bs=96 lr=0.0002 resume=fresh ber=False loss=logitnorm tau=1.0 auto_disconnect=True auto_push=True bayes_opt=True
# [DATASET] runtime_root=data/prepared_runtime_datasets dataset_name=strawberry__leaf
# [OOD] ood_root=data/prepared_runtime_datasets/strawberry__leaf/ood ask_for_ood_root=False
# [OE] oe_root=data/prepared_runtime_datasets/strawberry__leaf/oe ask_for_oe_root=False enabled=True loss_weight=0.45
# [RUNTIME] defaults=notebook_cell mp=bf16 workers=12 prefetch=8 sched=cosine wd=0.01 accum=1 grad_clip=1.0 label_smooth=0.0 warmup=0.1 early_stop=5/0.0 val_every=1 cache_train=True aug=randaugment randaug=2/7
# [OOD] factor=3.0 sure=90.0/97.0 conformal=raps alpha=0.05 raps_lambda=0.2 raps_k=1
# [KONTROL] Repo guncel gorunuyor.
# [KONTROL] GitHub okuma erisimi public; clone/pull icin ekstra token gerekmiyor.
# [KONTROL] GitHub push icin kimlik bilgisi hazir.
# [KONTROL] Gerekli Hugging Face modelleri anonim erisimle aciliyor.
# [BOOTSTRAP] Fetching selected Notebook 2 dataset paths: ['data/prepared_runtime_datasets/strawberry__leaf', 'data/ood_dataset/final/strawberry__leaf_ood_final', 'data/oe_dataset/strawberry_leaf_oe_from_blossom_candidates', 'data/prepared_runtime_datasets/strawberry__leaf/ood', 'data/prepared_runtime_datasets/strawberry__leaf/oe']
# [OOD] explicit ood root=/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__leaf/ood
# [OE] explicit oe root=/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__leaf/oe
# [DATASET] runtime root=/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__leaf classes=4: ['healthy', 'strawberry_leaf_scorch_leaf', 'strawberry_leaf_spot_leaf', 'strawberry_powdery_mildew_leaf']
# [DATASET][CHECK] scale=small continual=1606 val=491 test=491 ood=60 classes=4
# [PARAMS] Manual overrides uygulandi: {'EPOCHS': 24, 'BATCH_SIZE': 88, 'LEARNING_RATE': 0.00012, 'LORA_R': 24, 'LORA_ALPHA': 24, 'LORA_DROPOUT': 0.125, 'OOD_FACTOR': 2.0, 'LABEL_SMOOTHING': 0.1, 'EARLY_STOPPING_PATIENCE': 5, 'OE_LOSS_WEIGHT': 0.45, 'REACT_ENABLED': True, 'REACT_PERCENTILE': 0.99, 'FUSION_DROPOUT': 0.1, 'CLASSIFIER_REBALANCE_ENABLED': False, 'AUTO_DISCONNECT_RUNTIME': False, 'AUTO_PUSH_TO_GITHUB': True, 'WEIGHT_DECAY': 0.01, 'LOSS_NAME': 'logitnorm', 'LOGITNORM_TAU': 1.0, 'MIXED_PRECISION': 'bf16', 'GRAD_ACCUM_STEPS': 1, 'VALIDATION_EVERY_N_EPOCHS': 1, 'RANDAUGMENT_NUM_OPS': 2, 'RANDAUGMENT_MAGNITUDE': 7, 'NUM_WORKERS': 12, 'PREFETCH': 8, 'CACHE_TRAIN_SPLIT': True, 'ENABLE_BAYESIAN_OPTIMIZATION': True}
# [PARAMS][FINAL] epochs=24 bs=88 lr=0.00012 lora=24/24 dropout=0.125 accum=1 workers=12 prefetch=8
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
# [OPT] No prior comparable run yet. Bootstrap run will use the visible notebook parameters.
# [OOD] selected ood root=/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__leaf/ood
# [OE] selected oe root=/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__leaf/oe
# [CLASSES] ['healthy', 'strawberry_leaf_scorch_leaf', 'strawberry_leaf_spot_leaf', 'strawberry_powdery_mildew_leaf']
# [CLASSES] mode=dataset_fallback reason=partial_taxonomy_alignment_fallback matched=1 unmatched=3
# [CLASSES] taxonomy-unmatched classes kept: ['strawberry_leaf_scorch_leaf', 'strawberry_leaf_spot_leaf', 'strawberry_powdery_mildew_leaf']
# [ENGINE][OOD_CFG] {"ber_enabled": false, "ber_lambda_new": 0.1, "ber_lambda_old": 0.1, "ber_warmup_steps": 50, "conformal_alpha": 0.05, "conformal_enabled": true, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "energy_temperature": 1.0, "energy_temperature_mode": "auto", "energy_temperature_range": [0.5, 3.0], "energy_temperature_steps": 16, "enforce_oe_disjoint": true, "knn_backend": "auto", "knn_chunk_size": 2048, "oe_enabled": true, "oe_loss_weight": 0.45, "oe_root": "/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__leaf/oe", "oe_target": "uniform", "primary_score_method": "auto", "radial_beta_range": [0.5, 2.0], "radial_beta_steps": 16, "radial_l2_enabled": true, "react_apply_during_calibration": true, "react_apply_during_inference": true, "react_enabled": true, "react_percentile": 0.99, "real_dev_selection_enabled": true, "real_dev_target_fpr": 0.05, "real_split_dev_fraction": 0.4, "real_split_enabled": true, "real_split_manifest_name": "ood_split_manifest.json", "real_split_min_per_slice": 2, "real_split_min_total": 30, "sure_confidence_percentile": 97.0, "sure_enabled": true, "sure_semantic_percentile": 90.0, "threshold_factor": 2.0}
# [ENGINE][OPT_CFG] loss=logitnorm tau=1.0 label_smoothing=0.1 mixed_precision=bf16
# [ENGINE] Initializing adapter (may download backbone)...
# Loading weights:   0%|          | 0/415 [00:00<?, ?it/s]
# [ENGINE] Hazir. trainable_params=13,770,248  classes=4
# [VERIFY][OOD][expected] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 2.0}
# [VERIFY][OOD][resolved] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 2.0}
# [VERIFY][OOD] OK: cozulmus OOD ayari istenen parametrelerle eslesiyor.
# [TRAIN] epochs=24 device=cuda batch_interval=12
# [TRAIN] epoch=1 batch=12/18 loss=0.0000 lr=0.000120 speed=262.8s/s elapsed=7s eta=249s
# [CKPT] epoch_end epoch=1 step=18
# [EPOCH] 1/24: train_loss=1.3857 val_loss=1.2506 val_acc=0.7312 macro_f1=0.5958 * BEST
# [TRAIN] epoch=2 batch=12/18 loss=0.0000 lr=0.000119 speed=261.8s/s elapsed=21s eta=287s
# [CKPT] epoch_end epoch=2 step=36
# [EPOCH] 2/24: train_loss=1.2664 val_loss=0.9867 val_acc=0.7251 macro_f1=0.6264 * BEST
# [TRAIN] epoch=3 batch=12/18 loss=0.0000 lr=0.000116 speed=262.2s/s elapsed=34s eta=275s
# [CKPT] epoch_end epoch=3 step=54
# [EPOCH] 3/24: train_loss=1.0531 val_loss=0.5603 val_acc=0.9613 macro_f1=0.9577 * BEST
# [TRAIN] epoch=4 batch=12/18 loss=0.0000 lr=0.000113 speed=262.5s/s elapsed=46s eta=257s
# [CKPT] epoch_end epoch=4 step=72
# [EPOCH] 4/24: train_loss=0.9083 val_loss=0.2169 val_acc=0.9532 macro_f1=0.9485 * BEST
# [TRAIN] epoch=5 batch=12/18 loss=0.0000 lr=0.000109 speed=262.7s/s elapsed=58s eta=242s
# [CKPT] epoch_end epoch=5 step=90
# [EPOCH] 5/24: train_loss=0.8026 val_loss=0.0485 val_acc=0.9959 macro_f1=0.9951 * BEST
# [TRAIN] epoch=6 batch=12/18 loss=0.0000 lr=0.000104 speed=261.9s/s elapsed=71s eta=229s
# [CKPT] epoch_end epoch=6 step=108
# [EPOCH] 6/24: train_loss=0.7728 val_loss=0.0314 val_acc=0.9939 macro_f1=0.9924 * BEST
# [TRAIN] epoch=7 batch=12/18 loss=0.0000 lr=0.000099 speed=261.5s/s elapsed=83s eta=216s
# [CKPT] epoch_end epoch=7 step=126
# [EPOCH] 7/24: train_loss=0.7673 val_loss=0.0208 val_acc=0.9939 macro_f1=0.9924 * BEST
# [TRAIN] epoch=8 batch=12/18 loss=0.0000 lr=0.000092 speed=262.5s/s elapsed=95s eta=202s
# [CKPT] epoch_end epoch=8 step=144
# [EPOCH] 8/24: train_loss=0.7611 val_loss=0.0179 val_acc=0.9939 macro_f1=0.9924 * BEST
# [TRAIN] epoch=9 batch=12/18 loss=0.0000 lr=0.000086 speed=262.1s/s elapsed=107s eta=190s
# [CKPT] epoch_end epoch=9 step=162
# [EPOCH] 9/24: train_loss=0.7602 val_loss=0.0122 val_acc=0.9959 macro_f1=0.9951 * BEST
# [TRAIN] epoch=10 batch=12/18 loss=0.0000 lr=0.000078 speed=261.9s/s elapsed=119s eta=177s
# [EPOCH] 10/24: train_loss=0.7578 val_loss=0.0204 val_acc=0.9959 macro_f1=0.9951
# [TRAIN] epoch=11 batch=12/18 loss=0.0000 lr=0.000071 speed=262.4s/s elapsed=129s eta=161s
# [CKPT] epoch_end epoch=11 step=198
# [EPOCH] 11/24: train_loss=0.7565 val_loss=0.0084 val_acc=0.9959 macro_f1=0.9951 * BEST
# [TRAIN] epoch=12 batch=12/18 loss=0.0000 lr=0.000063 speed=262.0s/s elapsed=141s eta=149s
# [CKPT] epoch_end epoch=12 step=216
# [EPOCH] 12/24: train_loss=0.7558 val_loss=0.0053 val_acc=0.9959 macro_f1=0.9951 * BEST
# [TRAIN] epoch=13 batch=12/18 loss=0.0000 lr=0.000055 speed=262.3s/s elapsed=153s eta=137s
# [EPOCH] 13/24: train_loss=0.7562 val_loss=0.0139 val_acc=0.9959 macro_f1=0.9951
# [TRAIN] epoch=14 batch=12/18 loss=0.0000 lr=0.000048 speed=261.9s/s elapsed=162s eta=122s
# [CKPT] batch_250 epoch=14 step=250
# [EPOCH] 14/24: train_loss=0.7554 val_loss=0.0082 val_acc=0.9959 macro_f1=0.9951
# [TRAIN] epoch=15 batch=12/18 loss=0.0000 lr=0.000040 speed=262.5s/s elapsed=173s eta=110s
# [EPOCH] 15/24: train_loss=0.7566 val_loss=0.0133 val_acc=0.9959 macro_f1=0.9951
# [TRAIN] epoch=16 batch=12/18 loss=0.0000 lr=0.000033 speed=261.8s/s elapsed=182s eta=97s
# [EPOCH] 16/24: train_loss=0.7556 val_loss=0.0228 val_acc=0.9939 macro_f1=0.9924
# [TRAIN] epoch=17 batch=12/18 loss=0.0000 lr=0.000026 speed=261.5s/s elapsed=191s eta=84s
# [EPOCH] 17/24: train_loss=0.7552 val_loss=0.0221 val_acc=0.9959 macro_f1=0.9951
# [TRAIN] Complete. elapsed=195.7s stopped_early=True stopped_by_user=False cycles=1
# [OOD] Kalibrasyon tamamlandi. classes=4 version=1
# Cell 8: adapter save started
# Kaydedilen adapter klasoru: /content/bitirmeprojesi/outputs/colab_notebook_training/strawberry/leaf/continual_sd_lora_adapter
#  - outputs/colab_notebook_training/strawberry/leaf/continual_sd_lora_adapter/README.md
#  - outputs/colab_notebook_training/strawberry/leaf/continual_sd_lora_adapter/adapter_config.json
#  - outputs/colab_notebook_training/strawberry/leaf/continual_sd_lora_adapter/adapter_meta.json
#  - outputs/colab_notebook_training/strawberry/leaf/continual_sd_lora_adapter/adapter_model.safetensors
#  - outputs/colab_notebook_training/strawberry/leaf/continual_sd_lora_adapter/classifier.pth
#  - outputs/colab_notebook_training/strawberry/leaf/continual_sd_lora_adapter/fusion.pth
# Telemetry adapter klasoru: /content/bitirmeprojesi/outputs/colab_notebook_training/telemetry_runtime/telemetry/strawberry_leaf_2026-05-25_16-59-18/artifacts/adapter_export/strawberry/leaf/continual_sd_lora_adapter
# Cell 8: adapter save completed
# [DOGRULAMA (referans)] ornek=491 sinif=4 accuracy=0.9959 ood_auroc=0.9672 sure_ds_f1=0.6253 conformal_cov=0.9959
# [TEST (ayrilmis)] ornek=491 sinif=4 accuracy=0.9980 ood_auroc=0.9619 sure_ds_f1=0.6181 conformal_cov=0.9980
# [OOD] kanit=real_ood_split durum=failed gecti=False
# [DONE] Dogrulama ve held-out test artefaktlari kaydedildi.
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
# [RUNS] checkpoint_state -> /content/bitirmeprojesi/runs/strawberry/leaf/strawberry_leaf_2026-05-25_16-59-18/checkpoint_state
# [RUNS] outputs -> /content/bitirmeprojesi/runs/strawberry/leaf/strawberry_leaf_2026-05-25_16-59-18/outputs/colab_notebook_training
# [RUNS] telemetry -> /content/bitirmeprojesi/runs/strawberry/leaf/strawberry_leaf_2026-05-25_16-59-18/telemetry
# [RUNS] notebook -> /content/bitirmeprojesi/runs/strawberry/leaf/strawberry_leaf_2026-05-25_16-59-18/notebooks/6_train_all_continual_sd_lora_adapters.executed.ipynb
# [GIT] Local branch realigned to origin/master before secure run push.
# [SECURITY] scanned=151 redacted_files=66
# [GIT] Stage prepared for runs/strawberry/leaf/strawberry_leaf_2026-05-25_16-59-18: staged=387 skipped=3
# [GIT] Pushed 387 file(s) from runs/strawberry/leaf/strawberry_leaf_2026-05-25_16-59-18 to origin/master.
# [COLAB] completion checks -> {'evaluation_artifacts': True, 'production_readiness': True, 'telemetry_summary': True, 'repo_exports': True, 'executed_notebook_export': True}
# [COLAB] Auto-disconnect disabled.
#
# [NB6] Starting 4/8: strawberry__fruit
# [BOOTSTRAP] run_id=strawberry_fruit_2026-05-25_17-03-42 crop=strawberry part=fruit
# [ADAPTER_SELECTED] key=strawberry__fruit crop=strawberry part=fruit dataset=strawberry__fruit ood=data/prepared_runtime_datasets/strawberry__fruit/ood oe_enabled=True oe=data/prepared_runtime_datasets/strawberry__fruit/oe run_id=strawberry_fruit_2026-05-25_17-03-42
# [TRAINING_PLAN] epochs=36 batch=40 lr=8e-05 lora_r=20 allow_under_min=True validation_every=1
# [SONRAKI] Erisim kontrolu -> dataset validation -> engine init -> training -> calibration -> save/eval hucresini sirayla calistirin.
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# [HF] Kimlik dogrulandi: Grizzmann
# [GIT] Auto-push on kontrolu gecti: GitHub token cozuldu.
# [CONFIG] source=notebook_cell crop=strawberry epochs=12 bs=96 lr=0.0002 resume=fresh ber=False loss=logitnorm tau=1.0 auto_disconnect=True auto_push=True bayes_opt=True
# [DATASET] runtime_root=data/prepared_runtime_datasets dataset_name=strawberry__fruit
# [OOD] ood_root=data/prepared_runtime_datasets/strawberry__fruit/ood ask_for_ood_root=False
# [OE] oe_root=data/prepared_runtime_datasets/strawberry__fruit/oe ask_for_oe_root=False enabled=True loss_weight=0.25
# [RUNTIME] defaults=notebook_cell mp=bf16 workers=12 prefetch=8 sched=cosine wd=0.01 accum=1 grad_clip=1.0 label_smooth=0.0 warmup=0.1 early_stop=5/0.0 val_every=1 cache_train=True aug=randaugment randaug=2/7
# [OOD] factor=3.0 sure=90.0/97.0 conformal=raps alpha=0.05 raps_lambda=0.2 raps_k=1
# [KONTROL] Repo guncel gorunuyor.
# [KONTROL] GitHub okuma erisimi public; clone/pull icin ekstra token gerekmiyor.
# [KONTROL] GitHub push icin kimlik bilgisi hazir.
# [KONTROL] Gerekli Hugging Face modelleri anonim erisimle aciliyor.
# [BOOTSTRAP] Fetching selected Notebook 2 dataset paths: ['data/prepared_runtime_datasets/strawberry__fruit', 'data/ood_dataset/final/strawberry__fruit_ood_final', 'data/oe_dataset/strawberry_fruit_oe_candidates', 'data/prepared_runtime_datasets/strawberry__fruit/ood', 'data/prepared_runtime_datasets/strawberry__fruit/oe']
# [NB6] FAILED strawberry__fruit: OOD klasoru bulunamadi veya klasor degil: /content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__fruit/ood
#
# [NB6] Starting 5/8: grape__leaf
# [BOOTSTRAP] run_id=grape_leaf_2026-05-25_17-03-59 crop=grape part=leaf
# [ADAPTER_SELECTED] key=grape__leaf crop=grape part=leaf dataset=grape__leaf ood=data/prepared_runtime_datasets/grape__leaf/ood oe_enabled=True oe=data/prepared_runtime_datasets/grape__leaf/oe run_id=grape_leaf_2026-05-25_17-03-59
# [TRAINING_PLAN] epochs=30 batch=56 lr=0.0001 lora_r=24 allow_under_min=False validation_every=1
# [SONRAKI] Erisim kontrolu -> dataset validation -> engine init -> training -> calibration -> save/eval hucresini sirayla calistirin.
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# [HF] Kimlik dogrulandi: Grizzmann
# [GIT] Auto-push on kontrolu gecti: GitHub token cozuldu.
# [CONFIG] source=notebook_cell crop=grape epochs=12 bs=96 lr=0.0002 resume=fresh ber=False loss=logitnorm tau=1.0 auto_disconnect=True auto_push=True bayes_opt=True
# [DATASET] runtime_root=data/prepared_runtime_datasets dataset_name=grape__leaf
# [OOD] ood_root=data/prepared_runtime_datasets/grape__leaf/ood ask_for_ood_root=False
# [OE] oe_root=data/prepared_runtime_datasets/grape__leaf/oe ask_for_oe_root=False enabled=True loss_weight=0.3
# [RUNTIME] defaults=notebook_cell mp=bf16 workers=12 prefetch=8 sched=cosine wd=0.01 accum=1 grad_clip=1.0 label_smooth=0.0 warmup=0.1 early_stop=5/0.0 val_every=1 cache_train=True aug=randaugment randaug=2/7
# [OOD] factor=3.0 sure=90.0/97.0 conformal=raps alpha=0.05 raps_lambda=0.2 raps_k=1
# [KONTROL] Repo guncel gorunuyor.
# [KONTROL] GitHub okuma erisimi public; clone/pull icin ekstra token gerekmiyor.
# [KONTROL] GitHub push icin kimlik bilgisi hazir.
# [KONTROL] Gerekli Hugging Face modelleri anonim erisimle aciliyor.
# [BOOTSTRAP] Fetching selected Notebook 2 dataset paths: ['data/prepared_runtime_datasets/grape__leaf', 'data/ood_dataset/final/grape__leaf_ood_final', 'data/oe_dataset/grape_leaf_oe_unsupported_leaf_candidates', 'data/prepared_runtime_datasets/grape__leaf/ood', 'data/prepared_runtime_datasets/grape__leaf/oe']
# [OOD] explicit ood root=/content/bitirmeprojesi/data/prepared_runtime_datasets/grape__leaf/ood
# [OE] explicit oe root=/content/bitirmeprojesi/data/prepared_runtime_datasets/grape__leaf/oe
# [DATASET] runtime root=/content/bitirmeprojesi/data/prepared_runtime_datasets/grape__leaf classes=7: ['üzüm_antraknoz_yaprak', 'üzüm_kav_esca_yaprak', 'üzüm_külleme_yaprak', 'üzüm_leafroll_virüs_yaprak', 'üzüm_mildiyö_yaprak', 'üzüm_sağlıklı_yaprak', 'üzüm_yelpaze_virüsü_yaprak']
# [DATASET][CHECK] scale=small continual=1207 val=324 test=324 ood=430 classes=7
# [DATASET][WARN] Manifest rows include 182 eval-quality-risk item(s); prefer cautious regularization.
# [PARAMS] Manual overrides uygulandi: {'EPOCHS': 30, 'BATCH_SIZE': 56, 'LEARNING_RATE': 0.0001, 'LORA_R': 24, 'LORA_ALPHA': 24, 'LORA_DROPOUT': 0.14, 'OOD_FACTOR': 3.5, 'LABEL_SMOOTHING': 0.08, 'OE_LOSS_WEIGHT': 0.3, 'REACT_ENABLED': True, 'REACT_PERCENTILE': 0.985, 'FUSION_DROPOUT': 0.12, 'CLASSIFIER_REBALANCE_ENABLED': True, 'CLASSIFIER_REBALANCE_LOGIT_ADJUSTMENT_TAU': 1.15, 'AUTO_DISCONNECT_RUNTIME': False, 'AUTO_PUSH_TO_GITHUB': True, 'WEIGHT_DECAY': 0.01, 'LOSS_NAME': 'logitnorm', 'LOGITNORM_TAU': 1.0, 'MIXED_PRECISION': 'bf16', 'GRAD_ACCUM_STEPS': 1, 'VALIDATION_EVERY_N_EPOCHS': 1, 'EARLY_STOPPING_PATIENCE': 6, 'RANDAUGMENT_NUM_OPS': 2, 'RANDAUGMENT_MAGNITUDE': 7, 'NUM_WORKERS': 12, 'PREFETCH': 8, 'CACHE_TRAIN_SPLIT': True, 'ENABLE_BAYESIAN_OPTIMIZATION': True}
# [PARAMS][FINAL] epochs=30 bs=56 lr=0.0001 lora=24/24 dropout=0.14 accum=1 workers=12 prefetch=8
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
# [OPT] No prior comparable run yet. Bootstrap run will use the visible notebook parameters.
# [OOD] selected ood root=/content/bitirmeprojesi/data/prepared_runtime_datasets/grape__leaf/ood
# [OE] selected oe root=/content/bitirmeprojesi/data/prepared_runtime_datasets/grape__leaf/oe
# [CLASSES] ['üzüm_antraknoz_yaprak', 'üzüm_kav_esca_yaprak', 'üzüm_külleme_yaprak', 'üzüm_leafroll_virüs_yaprak', 'üzüm_mildiyö_yaprak', 'üzüm_sağlıklı_yaprak', 'üzüm_yelpaze_virüsü_yaprak']
# [CLASSES] mode=dataset_fallback reason=partial_taxonomy_alignment_fallback matched=0 unmatched=7
# [CLASSES] taxonomy-unmatched classes kept: ['u_zu_m_antraknoz_yaprak', 'u_zu_m_kav_esca_yaprak', 'u_zu_m_ku_lleme_yaprak', 'u_zu_m_leafroll_viru_s_yaprak', 'u_zu_m_mildiyo_yaprak', 'u_zu_m_sag_lıklı_yaprak', 'u_zu_m_yelpaze_viru_su_yaprak']
# [ENGINE][OOD_CFG] {"ber_enabled": false, "ber_lambda_new": 0.1, "ber_lambda_old": 0.1, "ber_warmup_steps": 50, "conformal_alpha": 0.05, "conformal_enabled": true, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "energy_temperature": 1.0, "energy_temperature_mode": "auto", "energy_temperature_range": [0.5, 3.0], "energy_temperature_steps": 16, "enforce_oe_disjoint": true, "knn_backend": "auto", "knn_chunk_size": 2048, "oe_enabled": true, "oe_loss_weight": 0.3, "oe_root": "/content/bitirmeprojesi/data/prepared_runtime_datasets/grape__leaf/oe", "oe_target": "uniform", "primary_score_method": "auto", "radial_beta_range": [0.5, 2.0], "radial_beta_steps": 16, "radial_l2_enabled": true, "react_apply_during_calibration": true, "react_apply_during_inference": true, "react_enabled": true, "react_percentile": 0.985, "real_dev_selection_enabled": true, "real_dev_target_fpr": 0.05, "real_split_dev_fraction": 0.4, "real_split_enabled": true, "real_split_manifest_name": "ood_split_manifest.json", "real_split_min_per_slice": 2, "real_split_min_total": 30, "sure_confidence_percentile": 97.0, "sure_enabled": true, "sure_semantic_percentile": 90.0, "threshold_factor": 3.5}
# [ENGINE][OPT_CFG] loss=logitnorm tau=1.0 label_smoothing=0.08 mixed_precision=bf16
# [ENGINE] Initializing adapter (may download backbone)...
# Loading weights:   0%|          | 0/415 [00:00<?, ?it/s]
# [ENGINE] Hazir. trainable_params=13,772,555  classes=7
# [VERIFY][OOD][expected] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 3.5}
# ...
#  - outputs/colab_notebook_training/grape/leaf/continual_sd_lora_adapter/fusion.pth
# Telemetry adapter klasoru: /content/bitirmeprojesi/outputs/colab_notebook_training/telemetry_runtime/telemetry/grape_leaf_2026-05-25_17-03-59/artifacts/adapter_export/grape/leaf/continual_sd_lora_adapter
# Cell 8: adapter save completed
# [DOGRULAMA (referans)] ornek=324 sinif=7 accuracy=0.8364 ood_auroc=0.8304 sure_ds_f1=0.3354 conformal_cov=0.9537
# [TEST (ayrilmis)] ornek=324 sinif=7 accuracy=0.8765 ood_auroc=0.8229 sure_ds_f1=0.3141 conformal_cov=0.9753
# [OOD] kanit=real_ood_split durum=failed gecti=False
# [DONE] Dogrulama ve held-out test artefaktlari kaydedildi.
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
# [RUNS] checkpoint_state -> /content/bitirmeprojesi/runs/grape/leaf/grape_leaf_2026-05-25_17-03-59/checkpoint_state
# [RUNS] outputs -> /content/bitirmeprojesi/runs/grape/leaf/grape_leaf_2026-05-25_17-03-59/outputs/colab_notebook_training
# [RUNS] telemetry -> /content/bitirmeprojesi/runs/grape/leaf/grape_leaf_2026-05-25_17-03-59/telemetry
# [RUNS] notebook -> /content/bitirmeprojesi/runs/grape/leaf/grape_leaf_2026-05-25_17-03-59/notebooks/6_train_all_continual_sd_lora_adapters.executed.ipynb
# [GIT] Local branch realigned to origin/master before secure run push.
# [SECURITY] scanned=154 redacted_files=68
# [GIT] Stage prepared for runs/grape/leaf/grape_leaf_2026-05-25_17-03-59: staged=512 skipped=3
# [GIT] Pushed 512 file(s) from runs/grape/leaf/grape_leaf_2026-05-25_17-03-59 to origin/master.
# [COLAB] completion checks -> {'evaluation_artifacts': True, 'production_readiness': True, 'telemetry_summary': True, 'repo_exports': True, 'executed_notebook_export': True}
# [COLAB] Auto-disconnect disabled.
#
# [NB6] Starting 6/8: grape__fruit
# [BOOTSTRAP] run_id=grape_fruit_2026-05-25_17-10-17 crop=grape part=fruit
# [ADAPTER_SELECTED] key=grape__fruit crop=grape part=fruit dataset=grape__fruit ood=data/prepared_runtime_datasets/grape__fruit/ood oe_enabled=True oe=data/prepared_runtime_datasets/grape__fruit/oe run_id=grape_fruit_2026-05-25_17-10-17
# [TRAINING_PLAN] epochs=34 batch=48 lr=0.0001 lora_r=24 allow_under_min=False validation_every=1
# [SONRAKI] Erisim kontrolu -> dataset validation -> engine init -> training -> calibration -> save/eval hucresini sirayla calistirin.
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# [HF] Kimlik dogrulandi: Grizzmann
# [GIT] Auto-push on kontrolu gecti: GitHub token cozuldu.
# [CONFIG] source=notebook_cell crop=grape epochs=12 bs=96 lr=0.0002 resume=fresh ber=False loss=logitnorm tau=1.0 auto_disconnect=True auto_push=True bayes_opt=True
# [DATASET] runtime_root=data/prepared_runtime_datasets dataset_name=grape__fruit
# [OOD] ood_root=data/prepared_runtime_datasets/grape__fruit/ood ask_for_ood_root=False
# [OE] oe_root=data/prepared_runtime_datasets/grape__fruit/oe ask_for_oe_root=False enabled=True loss_weight=0.32
# [RUNTIME] defaults=notebook_cell mp=bf16 workers=12 prefetch=8 sched=cosine wd=0.01 accum=1 grad_clip=1.0 label_smooth=0.0 warmup=0.1 early_stop=5/0.0 val_every=1 cache_train=True aug=randaugment randaug=2/7
# [OOD] factor=3.0 sure=90.0/97.0 conformal=raps alpha=0.05 raps_lambda=0.2 raps_k=1
# [KONTROL] Repo guncel gorunuyor.
# [KONTROL] GitHub okuma erisimi public; clone/pull icin ekstra token gerekmiyor.
# [KONTROL] GitHub push icin kimlik bilgisi hazir.
# [KONTROL] Gerekli Hugging Face modelleri anonim erisimle aciliyor.
# [BOOTSTRAP] Fetching selected Notebook 2 dataset paths: ['data/prepared_runtime_datasets/grape__fruit', 'data/ood_dataset/final/grape__fruit_ood_final', 'data/oe_dataset/grape_fruit_oe_from_leaf', 'data/prepared_runtime_datasets/grape__fruit/ood', 'data/prepared_runtime_datasets/grape__fruit/oe']
# [OOD] explicit ood root=/content/bitirmeprojesi/data/prepared_runtime_datasets/grape__fruit/ood
# [OE] explicit oe root=/content/bitirmeprojesi/data/prepared_runtime_datasets/grape__fruit/oe
# [DATASET] runtime root=/content/bitirmeprojesi/data/prepared_runtime_datasets/grape__fruit classes=5: ['üzüm_antraknoz_meyve', 'üzüm_botrytis_cinerea_meyve', 'üzüm_külleme_meyve', 'üzüm_mildiyö_meyve', 'üzüm_sağlıklı_meyve']
# [DATASET][CHECK] scale=small continual=767 val=174 test=174 ood=372 classes=5
# [DATASET][WARN] Manifest rows include 209 eval-quality-risk item(s); prefer cautious regularization.
# [PARAMS] Manual overrides uygulandi: {'EPOCHS': 34, 'BATCH_SIZE': 48, 'LEARNING_RATE': 0.0001, 'LORA_R': 24, 'LORA_ALPHA': 24, 'LORA_DROPOUT': 0.16, 'OOD_FACTOR': 3.5, 'LABEL_SMOOTHING': 0.08, 'OE_LOSS_WEIGHT': 0.32, 'REACT_ENABLED': True, 'REACT_PERCENTILE': 0.985, 'FUSION_DROPOUT': 0.14, 'CLASSIFIER_REBALANCE_ENABLED': True, 'CLASSIFIER_REBALANCE_LOGIT_ADJUSTMENT_TAU': 1.2, 'AUTO_DISCONNECT_RUNTIME': False, 'AUTO_PUSH_TO_GITHUB': True, 'WEIGHT_DECAY': 0.01, 'LOSS_NAME': 'logitnorm', 'LOGITNORM_TAU': 1.0, 'MIXED_PRECISION': 'bf16', 'GRAD_ACCUM_STEPS': 1, 'VALIDATION_EVERY_N_EPOCHS': 1, 'EARLY_STOPPING_PATIENCE': 6, 'RANDAUGMENT_NUM_OPS': 2, 'RANDAUGMENT_MAGNITUDE': 7, 'NUM_WORKERS': 12, 'PREFETCH': 8, 'CACHE_TRAIN_SPLIT': True, 'ENABLE_BAYESIAN_OPTIMIZATION': True}
# [PARAMS][FINAL] epochs=34 bs=48 lr=0.0001 lora=24/24 dropout=0.16 accum=1 workers=12 prefetch=8
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
# [OPT] No prior comparable run yet. Bootstrap run will use the visible notebook parameters.
# [OOD] selected ood root=/content/bitirmeprojesi/data/prepared_runtime_datasets/grape__fruit/ood
# [OE] selected oe root=/content/bitirmeprojesi/data/prepared_runtime_datasets/grape__fruit/oe
# [CLASSES] ['üzüm_antraknoz_meyve', 'üzüm_botrytis_cinerea_meyve', 'üzüm_külleme_meyve', 'üzüm_mildiyö_meyve', 'üzüm_sağlıklı_meyve']
# [CLASSES] mode=dataset_fallback reason=partial_taxonomy_alignment_fallback matched=0 unmatched=5
# [CLASSES] taxonomy-unmatched classes kept: ['u_zu_m_antraknoz_meyve', 'u_zu_m_botrytis_cinerea_meyve', 'u_zu_m_ku_lleme_meyve', 'u_zu_m_mildiyo_meyve', 'u_zu_m_sag_lıklı_meyve']
# [ENGINE][OOD_CFG] {"ber_enabled": false, "ber_lambda_new": 0.1, "ber_lambda_old": 0.1, "ber_warmup_steps": 50, "conformal_alpha": 0.05, "conformal_enabled": true, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "energy_temperature": 1.0, "energy_temperature_mode": "auto", "energy_temperature_range": [0.5, 3.0], "energy_temperature_steps": 16, "enforce_oe_disjoint": true, "knn_backend": "auto", "knn_chunk_size": 2048, "oe_enabled": true, "oe_loss_weight": 0.32, "oe_root": "/content/bitirmeprojesi/data/prepared_runtime_datasets/grape__fruit/oe", "oe_target": "uniform", "primary_score_method": "auto", "radial_beta_range": [0.5, 2.0], "radial_beta_steps": 16, "radial_l2_enabled": true, "react_apply_during_calibration": true, "react_apply_during_inference": true, "react_enabled": true, "react_percentile": 0.985, "real_dev_selection_enabled": true, "real_dev_target_fpr": 0.05, "real_split_dev_fraction": 0.4, "real_split_enabled": true, "real_split_manifest_name": "ood_split_manifest.json", "real_split_min_per_slice": 2, "real_split_min_total": 30, "sure_confidence_percentile": 97.0, "sure_enabled": true, "sure_semantic_percentile": 90.0, "threshold_factor": 3.5}
# [ENGINE][OPT_CFG] loss=logitnorm tau=1.0 label_smoothing=0.08 mixed_precision=bf16
# [ENGINE] Initializing adapter (may download backbone)...
# Loading weights:   0%|          | 0/415 [00:00<?, ?it/s]
# [ENGINE] Hazir. trainable_params=13,771,017  classes=5
# [VERIFY][OOD][expected] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 3.5}
# [VERIFY][OOD][resolved] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 3.5}
# [VERIFY][OOD] OK: cozulmus OOD ayari istenen parametrelerle eslesiyor.
# [TRAIN] epochs=34 device=cuda batch_interval=12
# [TRAIN] epoch=1 batch=12/15 loss=0.0000 lr=0.000100 speed=245.4s/s elapsed=4s eta=184s
# [CKPT] epoch_end epoch=1 step=15
# [EPOCH] 1/34: train_loss=1.6344 val_loss=1.7019 val_acc=0.0517 macro_f1=0.0197 * BEST
# [TRAIN] epoch=2 batch=12/15 loss=0.0000 lr=0.000099 speed=244.9s/s elapsed=15s eta=276s
# [CKPT] epoch_end epoch=2 step=30
# [EPOCH] 2/34: train_loss=1.6091 val_loss=1.6888 val_acc=0.1379 macro_f1=0.0526 * BEST
# [TRAIN] epoch=3 batch=12/15 loss=0.0000 lr=0.000098 speed=244.1s/s elapsed=24s eta=270s
# [CKPT] epoch_end epoch=3 step=45
# [EPOCH] 3/34: train_loss=1.6052 val_loss=1.4740 val_acc=0.3621 macro_f1=0.1868 * BEST
# [TRAIN] epoch=4 batch=12/15 loss=0.0000 lr=0.000097 speed=243.3s/s elapsed=32s eta=254s
# [CKPT] epoch_end epoch=4 step=60
# [EPOCH] 4/34: train_loss=1.5907 val_loss=1.4312 val_acc=0.5287 macro_f1=0.3356 * BEST
# [TRAIN] epoch=5 batch=12/15 loss=0.0000 lr=0.000095 speed=244.4s/s elapsed=40s eta=241s
# [CKPT] epoch_end epoch=5 step=75
# [EPOCH] 5/34: train_loss=1.4896 val_loss=1.2452 val_acc=0.4540 macro_f1=0.3171 * BEST
# [TRAIN] epoch=6 batch=12/15 loss=0.0000 lr=0.000093 speed=243.8s/s elapsed=47s eta=231s
# [CKPT] epoch_end epoch=6 step=90
# [EPOCH] 6/34: train_loss=1.3718 val_loss=0.9468 val_acc=0.6724 macro_f1=0.5733 * BEST
# [TRAIN] epoch=7 batch=12/15 loss=0.0000 lr=0.000091 speed=244.4s/s elapsed=55s eta=221s
# [CKPT] epoch_end epoch=7 step=105
# [EPOCH] 7/34: train_loss=1.2857 val_loss=0.7162 val_acc=0.7356 macro_f1=0.5891 * BEST
# [TRAIN] epoch=8 batch=12/15 loss=0.0000 lr=0.000088 speed=245.4s/s elapsed=63s eta=211s
# [CKPT] epoch_end epoch=8 step=120
# [EPOCH] 8/34: train_loss=1.2100 val_loss=0.6654 val_acc=0.7529 macro_f1=0.6491 * BEST
# [TRAIN] epoch=9 batch=12/15 loss=0.0000 lr=0.000085 speed=246.6s/s elapsed=70s eta=202s
# [CKPT] epoch_end epoch=9 step=135
# [EPOCH] 9/34: train_loss=1.1757 val_loss=0.6347 val_acc=0.7931 macro_f1=0.7396 * BEST
# [TRAIN] epoch=10 batch=12/15 loss=0.0000 lr=0.000081 speed=245.6s/s elapsed=78s eta=193s
# [EPOCH] 10/34: train_loss=1.1342 val_loss=0.6375 val_acc=0.7701 macro_f1=0.7061
# [TRAIN] epoch=11 batch=12/15 loss=0.0000 lr=0.000077 speed=246.6s/s elapsed=84s eta=180s
# [EPOCH] 11/34: train_loss=1.1369 val_loss=0.6389 val_acc=0.7759 macro_f1=0.7179
# [TRAIN] epoch=12 batch=12/15 loss=0.0000 lr=0.000073 speed=243.6s/s elapsed=88s eta=166s
# [CKPT] epoch_end epoch=12 step=180
# [EPOCH] 12/34: train_loss=1.1081 val_loss=0.5738 val_acc=0.8046 macro_f1=0.7570 * BEST
# [TRAIN] epoch=13 batch=12/15 loss=0.0000 lr=0.000069 speed=245.9s/s elapsed=96s eta=159s
# [CKPT] epoch_end epoch=13 step=195
# [EPOCH] 13/34: train_loss=1.0823 val_loss=0.5474 val_acc=0.8276 macro_f1=0.7854 * BEST
# [TRAIN] epoch=14 batch=12/15 loss=0.0000 lr=0.000065 speed=246.6s/s elapsed=107s eta=157s
# [CKPT] epoch_end epoch=14 step=210
# [EPOCH] 14/34: train_loss=1.0695 val_loss=0.4667 val_acc=0.8736 macro_f1=0.8599 * BEST
# [TRAIN] epoch=15 batch=12/15 loss=0.0000 lr=0.000060 speed=245.7s/s elapsed=115s eta=149s
# [EPOCH] 15/34: train_loss=1.0571 val_loss=0.4705 val_acc=0.8621 macro_f1=0.8343
# [TRAIN] epoch=16 batch=12/15 loss=0.0000 lr=0.000056 speed=246.1s/s elapsed=120s eta=138s
# [CKPT] epoch_end epoch=16 step=240
# [EPOCH] 16/34: train_loss=1.0534 val_loss=0.4504 val_acc=0.8621 macro_f1=0.8254 * BEST
# [CKPT] batch_250 epoch=17 step=250
# [TRAIN] epoch=17 batch=12/15 loss=0.0000 lr=0.000051 speed=240.6s/s elapsed=130s eta=133s
# [CKPT] epoch_end epoch=17 step=255
# [EPOCH] 17/34: train_loss=1.0394 val_loss=0.3822 val_acc=0.8793 macro_f1=0.8643 * BEST
# [TRAIN] epoch=18 batch=12/15 loss=0.0000 lr=0.000047 speed=245.0s/s elapsed=141s eta=128s
# [EPOCH] 18/34: train_loss=1.0231 val_loss=0.3911 val_acc=0.8678 macro_f1=0.8414
# [TRAIN] epoch=19 batch=12/15 loss=0.0000 lr=0.000042 speed=244.4s/s elapsed=146s eta=118s
# [CKPT] epoch_end epoch=19 step=285
# [EPOCH] 19/34: train_loss=1.0141 val_loss=0.3614 val_acc=0.8851 macro_f1=0.8631 * BEST
# [TRAIN] epoch=20 batch=12/15 loss=0.0000 lr=0.000038 speed=244.2s/s elapsed=153s eta=110s
# [EPOCH] 20/34: train_loss=1.0099 val_loss=0.3708 val_acc=0.8793 macro_f1=0.8456
# [TRAIN] epoch=21 batch=12/15 loss=0.0000 lr=0.000033 speed=244.6s/s elapsed=158s eta=101s
# [CKPT] epoch_end epoch=21 step=315
# [EPOCH] 21/34: train_loss=1.0153 val_loss=0.3290 val_acc=0.8908 macro_f1=0.8643 * BEST
# [TRAIN] epoch=22 batch=12/15 loss=0.0000 lr=0.000029 speed=246.8s/s elapsed=166s eta=93s
# [CKPT] epoch_end epoch=22 step=330
# [EPOCH] 22/34: train_loss=0.9979 val_loss=0.3231 val_acc=0.8908 macro_f1=0.8626 * BEST
# [TRAIN] epoch=23 batch=12/15 loss=0.0000 lr=0.000025 speed=245.6s/s elapsed=174s eta=85s
# [CKPT] epoch_end epoch=23 step=345
# [EPOCH] 23/34: train_loss=1.0022 val_loss=0.3108 val_acc=0.8908 macro_f1=0.8592 * BEST
# [TRAIN] epoch=24 batch=12/15 loss=0.0000 lr=0.000021 speed=244.1s/s elapsed=182s eta=78s
# [CKPT] epoch_end epoch=24 step=360
# [EPOCH] 24/34: train_loss=0.9929 val_loss=0.3061 val_acc=0.8851 macro_f1=0.8554 * BEST
# [TRAIN] epoch=25 batch=12/15 loss=0.0000 lr=0.000018 speed=243.7s/s elapsed=189s eta=70s
# [EPOCH] 25/34: train_loss=1.0055 val_loss=0.3368 val_acc=0.8908 macro_f1=0.8661
# [TRAIN] epoch=26 batch=12/15 loss=0.0000 lr=0.000015 speed=245.7s/s elapsed=195s eta=62s
# [CKPT] epoch_end epoch=26 step=390
# [EPOCH] 26/34: train_loss=0.9894 val_loss=0.2666 val_acc=0.9023 macro_f1=0.8816 * BEST
# [TRAIN] epoch=27 batch=12/15 loss=0.0000 lr=0.000012 speed=244.4s/s elapsed=202s eta=54s
# [EPOCH] 27/34: train_loss=0.9995 val_loss=0.3146 val_acc=0.8851 macro_f1=0.8554
# [TRAIN] epoch=28 batch=12/15 loss=0.0000 lr=0.000009 speed=244.1s/s elapsed=207s eta=46s
# [EPOCH] 28/34: train_loss=0.9896 val_loss=0.3115 val_acc=0.8851 macro_f1=0.8554
# [TRAIN] epoch=29 batch=12/15 loss=0.0000 lr=0.000007 speed=245.9s/s elapsed=212s eta=38s
# [EPOCH] 29/34: train_loss=1.0012 val_loss=0.2935 val_acc=0.8908 macro_f1=0.8643
# [TRAIN] epoch=30 batch=12/15 loss=0.0000 lr=0.000005 speed=244.1s/s elapsed=216s eta=30s
# [EPOCH] 30/34: train_loss=0.9883 val_loss=0.3122 val_acc=0.8851 macro_f1=0.8554
# [TRAIN] epoch=31 batch=12/15 loss=0.0000 lr=0.000003 speed=246.3s/s elapsed=222s eta=23s
# [EPOCH] 31/34: train_loss=0.9946 val_loss=0.3095 val_acc=0.8851 macro_f1=0.8554
# [TRAIN] epoch=32 batch=12/15 loss=0.0000 lr=0.000002 speed=246.4s/s elapsed=226s eta=16s
# [EPOCH] 32/34: train_loss=0.9916 val_loss=0.3036 val_acc=0.8851 macro_f1=0.8554
# [TRAIN] Complete. elapsed=228.4s stopped_early=True stopped_by_user=False cycles=1
# [OOD] Kalibrasyon tamamlandi. classes=5 version=1
# Cell 8: adapter save started
# Kaydedilen adapter klasoru: /content/bitirmeprojesi/outputs/colab_notebook_training/grape/fruit/continual_sd_lora_adapter
#  - outputs/colab_notebook_training/grape/fruit/continual_sd_lora_adapter/README.md
#  - outputs/colab_notebook_training/grape/fruit/continual_sd_lora_adapter/adapter_config.json
#  - outputs/colab_notebook_training/grape/fruit/continual_sd_lora_adapter/adapter_meta.json
#  - outputs/colab_notebook_training/grape/fruit/continual_sd_lora_adapter/adapter_model.safetensors
#  - outputs/colab_notebook_training/grape/fruit/continual_sd_lora_adapter/classifier.pth
#  - outputs/colab_notebook_training/grape/fruit/continual_sd_lora_adapter/fusion.pth
# Telemetry adapter klasoru: /content/bitirmeprojesi/outputs/colab_notebook_training/telemetry_runtime/telemetry/grape_fruit_2026-05-25_17-10-17/artifacts/adapter_export/grape/fruit/continual_sd_lora_adapter
# Cell 8: adapter save completed
# [DOGRULAMA (referans)] ornek=174 sinif=5 accuracy=0.8851 ood_auroc=0.7932 sure_ds_f1=0.4860 conformal_cov=0.9598
# [TEST (ayrilmis)] ornek=174 sinif=5 accuracy=0.9138 ood_auroc=0.7837 sure_ds_f1=0.4825 conformal_cov=0.9655
# [OOD] kanit=real_ood_split durum=failed gecti=False
# [DONE] Dogrulama ve held-out test artefaktlari kaydedildi.
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
