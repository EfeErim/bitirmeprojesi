# %% [markdown]
# # Notebook 6: Batch Train All Continual SD-LoRA Adapters
#
# Bu notebook, Notebook 2 akisini baz alir ve tanimli adapterleri sirayla egitir.
#
# Akis:
# 1. Repo bootstrap ve Notebook 2 helper'larini yukle.
# 2. Adapter matrisi ve sirayi tanimla.
# 3. Her adapter icin Notebook 2 parametre, dataset validation, training, OOD calibration, export ve final evaluation hucrelerini calistir.
# 4. Her run icin ozet yazdir; runtime auto-disconnect batch bitene kadar kapali kalir.

# %%
from pathlib import Path
import os
import subprocess
import sys
from urllib.parse import urlsplit, urlunsplit

CLONE_TARGET = Path('/content/bitirmeprojesi')
REPO_URL = os.environ.get('AADS_REPO_URL', 'https://github.com/EfeErim/bitirmeprojesi.git')
NOTEBOOK6_SPARSE_PATHS = (
    'README.md',
    'docs',
    'src',
    'scripts',
    'config',
    'colab_notebooks',
    'requirements.txt',
    'requirements_colab.txt',
    'pyproject.toml',
)

def _build_repo_access_url(repo_url, token):
    token = str(token or '').strip()
    if not token:
        return repo_url
    parsed = urlsplit(str(repo_url or '').strip())
    if parsed.scheme != 'https' or not parsed.netloc:
        return repo_url
    netloc = parsed.netloc.split('@', 1)[-1]
    return urlunsplit((parsed.scheme, f'{token}@{netloc}', parsed.path, parsed.query, parsed.fragment))

def _ensure_aads_repo_on_path():
    candidates = [Path.cwd(), Path.cwd().parent, CLONE_TARGET, Path('/content/bitirmeprojesi'), Path('/content/bitirme projesi')]
    for candidate in candidates:
        marker = candidate / 'scripts' / 'notebook_helpers' / 'cell_script_runner.py'
        if marker.is_file():
            repo_root = candidate.resolve()
            if str(repo_root) not in sys.path:
                sys.path.insert(0, str(repo_root))
            return repo_root
    clone_url = _build_repo_access_url(REPO_URL, os.environ.get('GH_TOKEN') or os.environ.get('GITHUB_TOKEN'))
    if not CLONE_TARGET.exists():
        subprocess.run(['git', 'clone', '--depth', '1', '--filter=blob:none', '--sparse', clone_url, str(CLONE_TARGET)], check=True)
        subprocess.run(['git', 'sparse-checkout', 'set', *NOTEBOOK6_SPARSE_PATHS], cwd=str(CLONE_TARGET), check=True)
    if str(CLONE_TARGET) not in sys.path:
        sys.path.insert(0, str(CLONE_TARGET))
    return CLONE_TARGET

_ensure_aads_repo_on_path()

from scripts.notebook_helpers.cell_script_runner import run_cell_script
run_cell_script('nb2_cell01_bootstrap_access.py', globals())
# Out:
# [BOOTSTRAP] GitHub token found.
# [BOOTSTRAP] HuggingFace token found.
# [BOOTSTRAP] Repo root: /content/bitirmeprojesi
# [BOOTSTRAP] Installing requirements_colab.txt...
# [BOOTSTRAP] Notebook 2: Continual Adapter Training bootstrap complete.
#
# ======================================================================
# BOOTSTRAP STATUS
# ======================================================================
# Status: ok
# Repo Root: /content/bitirmeprojesi
# In Colab: True
# GitHub Token: ✓
# HuggingFace Token: ✓
# ======================================================================
#
# [SONRAKI] Parametre ve adapter secimi hucresine gecin; model erisimi ayrica access-check hucresinde dogrulanacak.

# %%
NOTEBOOK_NAME = "6_train_all_continual_sd_lora_adapters.ipynb"
NOTEBOOK_FILENAME = "6_train_all_continual_sd_lora_adapters.executed.ipynb"
AUTO_DISCONNECT_RUNTIME = False
AUTO_PUSH_TO_GITHUB = True
NB6_AUTO_DISCONNECT_RUNTIME = True
NB6_AUTO_DISCONNECT_GRACE_SECONDS = 20
ENABLE_BAYESIAN_OPTIMIZATION = True
MANUAL_PARAM_OVERRIDES = {}
DEFAULT_RUNTIME_PARAMS = {
    "AUTO_DISCONNECT_RUNTIME": False,
    "AUTO_PUSH_TO_GITHUB": True,
}
NB6_MANUAL_PARAM_OVERRIDES = {}

ADAPTER_RECS = {
    "grape__fruit": {"crop": "grape", "part": "fruit", "ood": "data/prepared_runtime_datasets/grape__fruit/ood", "oe": "data/prepared_runtime_datasets/grape__fruit/oe", "oe_enabled": True, "oe_w": 0.22, "allow_under_min": False, "overrides": {"EPOCHS": 34, "BATCH_SIZE": 48, "LEARNING_RATE": 1e-4, "LORA_R": 24, "LORA_ALPHA": 24, "LORA_DROPOUT": 0.16, "OOD_FACTOR": 3.5, "LABEL_SMOOTHING": 0.08}},
    "grape__leaf": {"crop": "grape", "part": "leaf", "ood": "data/prepared_runtime_datasets/grape__leaf/ood", "oe": "data/prepared_runtime_datasets/grape__leaf/oe", "oe_enabled": True, "oe_w": 0.22, "allow_under_min": False, "overrides": {"EPOCHS": 30, "BATCH_SIZE": 56, "LEARNING_RATE": 1e-4, "LORA_R": 24, "LORA_ALPHA": 24, "LORA_DROPOUT": 0.14, "OOD_FACTOR": 3.5, "LABEL_SMOOTHING": 0.08}},
    "strawberry__fruit": {"crop": "strawberry", "part": "fruit", "ood": "data/prepared_runtime_datasets/strawberry__fruit/ood", "oe": "data/prepared_runtime_datasets/strawberry__fruit/oe", "oe_enabled": True, "oe_w": 0.20, "allow_under_min": True, "overrides": {"EPOCHS": 38, "BATCH_SIZE": 40, "LEARNING_RATE": 8e-5, "LORA_R": 20, "LORA_ALPHA": 20, "LORA_DROPOUT": 0.20, "OOD_FACTOR": 4.0, "LABEL_SMOOTHING": 0.10}},
    "strawberry__leaf": {"crop": "strawberry", "part": "leaf", "ood": "data/prepared_runtime_datasets/strawberry__leaf/ood", "oe": "data/prepared_runtime_datasets/strawberry__leaf/oe", "oe_enabled": True, "oe_w": 0.25, "allow_under_min": False, "overrides": {"EPOCHS": 24, "BATCH_SIZE": 88, "LEARNING_RATE": 1.2e-4, "LORA_R": 24, "LORA_ALPHA": 24, "LORA_DROPOUT": 0.18, "OOD_FACTOR": 4.0, "LABEL_SMOOTHING": 0.10}},
    "tomato__fruit": {"crop": "tomato", "part": "fruit", "ood": "data/prepared_runtime_datasets/tomato__fruit/ood", "oe": "data/prepared_runtime_datasets/tomato__fruit/oe", "oe_enabled": True, "oe_w": 0.18, "allow_under_min": False, "overrides": {"EPOCHS": 32, "BATCH_SIZE": 64, "LEARNING_RATE": 9e-5, "LORA_R": 24, "LORA_ALPHA": 24, "LORA_DROPOUT": 0.16, "OOD_FACTOR": 3.5, "LABEL_SMOOTHING": 0.08}},
    "tomato__leaf": {"crop": "tomato", "part": "leaf", "ood": "data/prepared_runtime_datasets/tomato__leaf/ood", "oe": "data/prepared_runtime_datasets/tomato__leaf/oe", "oe_enabled": True, "oe_w": 0.18, "allow_under_min": False, "overrides": {"EPOCHS": 24, "BATCH_SIZE": 88, "LEARNING_RATE": 1.1e-4, "LORA_R": 32, "LORA_ALPHA": 32, "LORA_DROPOUT": 0.12, "OOD_FACTOR": 3.5, "LABEL_SMOOTHING": 0.08}},
    "apricot__fruit": {"crop": "apricot", "part": "fruit", "ood": "data/ood_dataset/final/apricot__fruit_ood_final", "oe": "", "oe_enabled": False, "oe_w": 0.10, "allow_under_min": False, "overrides": {"EPOCHS": 36, "BATCH_SIZE": 40, "LEARNING_RATE": 1e-4, "LORA_R": 20, "LORA_ALPHA": 20, "LORA_DROPOUT": 0.25, "OOD_FACTOR": 4.5, "LABEL_SMOOTHING": 0.15}},
    "apricot__leaf": {"crop": "apricot", "part": "leaf", "ood": "data/ood_dataset/final/apricot__leaf_ood_final", "oe": "data/oe_dataset/apricot_leaf_oe_unsupported_leaf_candidates", "oe_enabled": True, "oe_w": 0.30, "allow_under_min": False, "overrides": {"EPOCHS": 38, "BATCH_SIZE": 52, "LEARNING_RATE": 1.2e-4, "LORA_R": 26, "LORA_ALPHA": 26, "LORA_DROPOUT": 0.22, "OOD_FACTOR": 5.5, "LABEL_SMOOTHING": 0.15}},
}

for _adapter_rec in ADAPTER_RECS.values():
    if "defaults" not in _adapter_rec and "overrides" in _adapter_rec:
        _adapter_rec["defaults"] = dict(_adapter_rec["overrides"])

NB6_ADAPTER_SEQUENCE = [
    "apricot__leaf",
    "apricot__fruit",
    "strawberry__leaf",
    "strawberry__fruit",
    "grape__leaf",
    "grape__fruit",
    "tomato__leaf",
    "tomato__fruit",
]

# %%
import json

NB6_RESULTS = {}

for index, adapter_key in enumerate(NB6_ADAPTER_SEQUENCE, start=1):
    print(f"\n[NB6] Starting {index}/{len(NB6_ADAPTER_SEQUENCE)}: {adapter_key}")
    adapter_rec = ADAPTER_RECS[adapter_key]
    CROP_NAME = adapter_rec["crop"]
    PART_NAME = adapter_rec["part"]
    DATASET_NAME = adapter_key
    ADAPTER_KEY = adapter_key
    MANUAL_PARAM_OVERRIDES = dict(NB6_MANUAL_PARAM_OVERRIDES.get(adapter_key, {}))
    try:
        run_cell_script('nb2_cell03_runtime_setup.py', globals())
        run_cell_script('nb2_cell04_parameter_resolution.py', globals())
        run_cell_script('nb2_cell05_access_check.py', globals())
        run_cell_script('nb2_cell06_dataset_validation.py', globals())
        run_cell_script('nb2_cell07_engine_init.py', globals())
        run_cell_script('nb2_cell08_ood_config_verify.py', globals())
        run_cell_script('nb2_cell09_training.py', globals())
        run_cell_script('nb2_cell10_ood_calibration.py', globals())
        run_cell_script('nb2_cell11_adapter_save.py', globals())
        run_cell_script('nb2_cell12_final_evaluation.py', globals())
        NB6_RESULTS[adapter_key] = {
            "status": "ok",
            "run_id": str(globals().get("RUN_ID", "")),
            "crop": str(globals().get("CROP_NAME", "")),
            "part": str(globals().get("PART_NAME", "")),
        }
    except Exception as exc:
        NB6_RESULTS[adapter_key] = {
            "status": "failed",
            "error": str(exc),
            "run_id": str(globals().get("RUN_ID", "")),
            "crop": str(globals().get("CROP_NAME", "")),
            "part": str(globals().get("PART_NAME", "")),
        }
        print(f"[NB6] FAILED {adapter_key}: {exc}")
        continue

print('\n[NB6] SUMMARY')
print(json.dumps(NB6_RESULTS, indent=2, ensure_ascii=False))

from scripts.colab_notebook_helpers import maybe_auto_disconnect_colab_runtime

NB6_COMPLETION_REPORT = {
    "ready": True,
    "checks": {
        "batch_loop_completed": True,
        "all_adapters_attempted": len(NB6_RESULTS) == len(NB6_ADAPTER_SEQUENCE),
    },
    "missing": [],
    "soft_missing": [],
    "adapter_results": NB6_RESULTS,
}
maybe_auto_disconnect_colab_runtime(
    enabled=bool(NB6_AUTO_DISCONNECT_RUNTIME),
    grace_period_sec=float(NB6_AUTO_DISCONNECT_GRACE_SECONDS),
    telemetry=globals().get("TELEMETRY"),
    completion_report=NB6_COMPLETION_REPORT,
)
# Out:
# [NB6] Starting 1/8: apricot__leaf
# [BOOTSTRAP] run_id=apricot_leaf_2026-05-13_17-38-34 crop=apricot part=leaf
# [ADAPTER_SELECTED] key=apricot__leaf crop=apricot part=leaf dataset=apricot__leaf ood=data/ood_dataset/final/apricot__leaf_ood_final oe_enabled=True oe=data/oe_dataset/apricot_leaf_oe_unsupported_leaf_candidates run_id=apricot_leaf_2026-05-13_17-38-34
# [TRAINING_PLAN] epochs=38 batch=52 lr=0.00012 lora_r=26 allow_under_min=False validation_every=1
# [SONRAKI] Erisim kontrolu -> dataset validation -> engine init -> training -> calibration -> save/eval hucresini sirayla calistirin.
# [BAYES] Toggle acik ama dosya yok: /content/bitirmeprojesi/runs/_index/bayesian_recommendations.json
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# [HF] Kimlik dogrulandi: Grizzmann
# [GIT] Auto-push on kontrolu gecti: GitHub token cozuldu.
# [CONFIG] source=notebook_cell crop=apricot epochs=12 bs=96 lr=0.0002 resume=fresh ber=False loss=logitnorm tau=1.0 auto_disconnect=True auto_push=True bayes_opt=True
# [DATASET] runtime_root=data/prepared_runtime_datasets dataset_name=apricot__leaf
# [OOD] ood_root=data/ood_dataset/final/apricot__leaf_ood_final ask_for_ood_root=False
# [OE] oe_root=data/oe_dataset/apricot_leaf_oe_unsupported_leaf_candidates ask_for_oe_root=False enabled=True loss_weight=0.3
# [RUNTIME] defaults=notebook_cell mp=bf16 workers=12 prefetch=8 sched=cosine wd=0.01 accum=1 grad_clip=1.0 label_smooth=0.0 warmup=0.1 early_stop=5/0.0 val_every=1 cache_train=True aug=randaugment randaug=2/7
# [OOD] factor=3.0 sure=90.0/97.0 conformal=raps alpha=0.05 raps_lambda=0.2 raps_k=1
# [KONTROL] Repo guncel gorunuyor.
# [KONTROL] GitHub okuma erisimi public; clone/pull icin ekstra token gerekmiyor.
# [KONTROL] GitHub push icin kimlik bilgisi hazir.
# [KONTROL] Gerekli Hugging Face modelleri anonim erisimle aciliyor.
# [BOOTSTRAP] Fetching selected Notebook 2 dataset paths: ['data/prepared_runtime_datasets/apricot__leaf', 'data/ood_dataset/final/apricot__leaf_ood_final', 'data/oe_dataset/apricot_leaf_oe_unsupported_leaf_candidates']
# [OOD] explicit ood root=/content/bitirmeprojesi/data/ood_dataset/final/apricot__leaf_ood_final
# [OE] explicit oe root=/content/bitirmeprojesi/data/oe_dataset/apricot_leaf_oe_unsupported_leaf_candidates
# [DATASET] runtime root=/content/bitirmeprojesi/data/prepared_runtime_datasets/apricot__leaf classes=3: ['kayısı_sağlıklı_yaprak_302', 'kayısı_şarka_virüsü_yaprak_206', 'kayısı_yaprak_delen_çil_hastalığı_yaprak_300']
# [DATASET][CHECK] scale=small continual=508 val=150 test=150 ood=117 classes=3
# [PARAMS] Manual overrides uygulandi: {'EPOCHS': 38, 'BATCH_SIZE': 52, 'LEARNING_RATE': 0.00012, 'LORA_R': 26, 'LORA_ALPHA': 26, 'LORA_DROPOUT': 0.22, 'OOD_FACTOR': 5.5, 'LABEL_SMOOTHING': 0.15, 'AUTO_DISCONNECT_RUNTIME': False, 'AUTO_PUSH_TO_GITHUB': True, 'WEIGHT_DECAY': 0.01, 'LOSS_NAME': 'logitnorm', 'LOGITNORM_TAU': 1.0, 'MIXED_PRECISION': 'bf16', 'GRAD_ACCUM_STEPS': 1, 'VALIDATION_EVERY_N_EPOCHS': 1, 'EARLY_STOPPING_PATIENCE': 6, 'RANDAUGMENT_NUM_OPS': 2, 'RANDAUGMENT_MAGNITUDE': 7, 'NUM_WORKERS': 12, 'PREFETCH': 8, 'CACHE_TRAIN_SPLIT': True, 'ENABLE_BAYESIAN_OPTIMIZATION': True}
# [PARAMS][FINAL] epochs=38 bs=52 lr=0.00012 lora=26/26 dropout=0.22 accum=1 workers=12 prefetch=8
# [OOD] selected ood root=/content/bitirmeprojesi/data/ood_dataset/final/apricot__leaf_ood_final
# [OE] selected oe root=/content/bitirmeprojesi/data/oe_dataset/apricot_leaf_oe_unsupported_leaf_candidates
# [CLASSES] ['kayısı_s_arka_viru_su_yaprak_206', 'kayısı_sag_lıklı_yaprak_302', 'kayısı_yaprak_delen_c_il_hastalıg_ı_yaprak_300']
# [CLASSES] mode=dataset_fallback reason=partial_taxonomy_alignment_fallback matched=0 unmatched=3
# [CLASSES] taxonomy-unmatched classes kept: ['kayısı_s_arka_viru_su_yaprak_206', 'kayısı_sag_lıklı_yaprak_302', 'kayısı_yaprak_delen_c_il_hastalıg_ı_yaprak_300']
# [ENGINE][OOD_CFG] {"ber_enabled": false, "ber_lambda_new": 0.1, "ber_lambda_old": 0.1, "ber_warmup_steps": 50, "conformal_alpha": 0.05, "conformal_enabled": true, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "energy_temperature": 1.0, "energy_temperature_mode": "auto", "energy_temperature_range": [0.5, 3.0], "energy_temperature_steps": 16, "knn_backend": "auto", "knn_chunk_size": 2048, "oe_enabled": true, "oe_loss_weight": 0.3, "oe_root": "/content/bitirmeprojesi/data/oe_dataset/apricot_leaf_oe_unsupported_leaf_candidates", "oe_target": "uniform", "primary_score_method": "auto", "radial_beta_range": [0.5, 2.0], "radial_beta_steps": 16, "radial_l2_enabled": true, "react_apply_during_calibration": true, "react_apply_during_inference": true, "react_enabled": false, "react_percentile": 0.99, "real_dev_selection_enabled": true, "real_dev_target_fpr": 0.05, "real_split_dev_fraction": 0.4, "real_split_enabled": true, "real_split_manifest_name": "ood_split_manifest.json", "real_split_min_per_slice": 2, "sure_confidence_percentile": 97.0, "sure_enabled": true, "sure_semantic_percentile": 90.0, "threshold_factor": 5.5}
# [ENGINE][OPT_CFG] loss=logitnorm tau=1.0 label_smoothing=0.15 mixed_precision=bf16
# [ENGINE] Initializing adapter (may download backbone)...
# config.json:   0%|          | 0.00/745 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.21G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/415 [00:00<?, ?it/s]
# [ENGINE] Hazir. trainable_params=14,654,215  classes=3
# [VERIFY][OOD][expected] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 5.5}
# [VERIFY][OOD][resolved] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 5.5}
# [VERIFY][OOD] OK: cozulmus OOD ayari istenen parametrelerle eslesiyor.
# [TRAIN] epochs=38 device=cuda batch_interval=12
# [CKPT] epoch_end epoch=1 step=9
# [EPOCH] 1/38: train_loss=1.1058 val_loss=1.0604 val_acc=0.4133 macro_f1=0.2437 * BEST
# [EPOCH] 2/38: train_loss=1.0892 val_loss=1.0766 val_acc=0.4200 macro_f1=0.3397
# [CKPT] epoch_end epoch=3 step=27
# [EPOCH] 3/38: train_loss=1.0816 val_loss=1.0346 val_acc=0.5200 macro_f1=0.3953 * BEST
# [CKPT] epoch_end epoch=4 step=36
# [EPOCH] 4/38: train_loss=1.0584 val_loss=1.0108 val_acc=0.4933 macro_f1=0.4162 * BEST
# [CKPT] epoch_end epoch=5 step=45
# [EPOCH] 5/38: train_loss=0.9835 val_loss=0.9018 val_acc=0.5933 macro_f1=0.5884 * BEST
# [CKPT] epoch_end epoch=6 step=54
# [EPOCH] 6/38: train_loss=0.9003 val_loss=0.8566 val_acc=0.5867 macro_f1=0.5775 * BEST
# [EPOCH] 7/38: train_loss=0.8487 val_loss=0.8596 val_acc=0.5733 macro_f1=0.5512
# [CKPT] epoch_end epoch=8 step=72
# [EPOCH] 8/38: train_loss=0.8132 val_loss=0.7471 val_acc=0.6533 macro_f1=0.6394 * BEST
# [EPOCH] 9/38: train_loss=0.7568 val_loss=0.7862 val_acc=0.6867 macro_f1=0.6819
# [EPOCH] 10/38: train_loss=0.7354 val_loss=0.8017 val_acc=0.7267 macro_f1=0.7267
# [CKPT] epoch_end epoch=11 step=99
# [EPOCH] 11/38: train_loss=0.7061 val_loss=0.6087 val_acc=0.8200 macro_f1=0.8185 * BEST
# [EPOCH] 12/38: train_loss=0.6824 val_loss=0.7162 val_acc=0.8067 macro_f1=0.8003
# [CKPT] epoch_end epoch=13 step=117
# [EPOCH] 13/38: train_loss=0.6903 val_loss=0.5955 val_acc=0.8200 macro_f1=0.8173 * BEST
# [CKPT] epoch_end epoch=14 step=126
# [EPOCH] 14/38: train_loss=0.6436 val_loss=0.5572 val_acc=0.8400 macro_f1=0.8363 * BEST
# [CKPT] epoch_end epoch=15 step=135
# [EPOCH] 15/38: train_loss=0.6598 val_loss=0.5181 val_acc=0.8467 macro_f1=0.8432 * BEST
# [CKPT] epoch_end epoch=16 step=144
# [EPOCH] 16/38: train_loss=0.6616 val_loss=0.4621 val_acc=0.8333 macro_f1=0.8310 * BEST
# [CKPT] epoch_end epoch=17 step=153
# [EPOCH] 17/38: train_loss=0.6382 val_loss=0.4380 val_acc=0.8467 macro_f1=0.8439 * BEST
# [CKPT] epoch_end epoch=18 step=162
# [EPOCH] 18/38: train_loss=0.6695 val_loss=0.3916 val_acc=0.8400 macro_f1=0.8376 * BEST
# [CKPT] epoch_end epoch=19 step=171
# [EPOCH] 19/38: train_loss=0.6425 val_loss=0.3238 val_acc=0.8467 macro_f1=0.8448 * BEST
# [CKPT] epoch_end epoch=20 step=180
# [EPOCH] 20/38: train_loss=0.6290 val_loss=0.2653 val_acc=0.8800 macro_f1=0.8786 * BEST
# [CKPT] epoch_end epoch=21 step=189
# [EPOCH] 21/38: train_loss=0.6211 val_loss=0.2386 val_acc=0.9000 macro_f1=0.8996 * BEST
# [CKPT] epoch_end epoch=22 step=198
# [EPOCH] 22/38: train_loss=0.6163 val_loss=0.2249 val_acc=0.9200 macro_f1=0.9191 * BEST
# [CKPT] epoch_end epoch=23 step=207
# [EPOCH] 23/38: train_loss=0.6155 val_loss=0.2204 val_acc=0.9133 macro_f1=0.9120 * BEST
# [CKPT] epoch_end epoch=24 step=216
# [EPOCH] 24/38: train_loss=0.6089 val_loss=0.1942 val_acc=0.9267 macro_f1=0.9258 * BEST
# [EPOCH] 25/38: train_loss=0.6101 val_loss=0.2203 val_acc=0.9133 macro_f1=0.9120
# [EPOCH] 26/38: train_loss=0.6114 val_loss=0.2064 val_acc=0.9333 macro_f1=0.9310
# [EPOCH] 27/38: train_loss=0.6058 val_loss=0.1984 val_acc=0.9267 macro_f1=0.9258
# [CKPT] batch_250 epoch=28 step=250
# [EPOCH] 28/38: train_loss=0.6099 val_loss=0.2004 val_acc=0.9333 macro_f1=0.9310
# [EPOCH] 29/38: train_loss=0.6099 val_loss=0.2028 val_acc=0.9333 macro_f1=0.9310
# [CKPT] epoch_end epoch=30 step=270
# [EPOCH] 30/38: train_loss=0.6018 val_loss=0.1932 val_acc=0.9467 macro_f1=0.9449 * BEST
# [CKPT] epoch_end epoch=31 step=279
# [EPOCH] 31/38: train_loss=0.6140 val_loss=0.1893 val_acc=0.9467 macro_f1=0.9446 * BEST
# [EPOCH] 32/38: train_loss=0.6168 val_loss=0.1917 val_acc=0.9467 macro_f1=0.9446
# [EPOCH] 33/38: train_loss=0.6072 val_loss=0.1965 val_acc=0.9333 macro_f1=0.9325
# [EPOCH] 34/38: train_loss=0.6128 val_loss=0.1982 val_acc=0.9267 macro_f1=0.9253
# [EPOCH] 35/38: train_loss=0.6061 val_loss=0.1980 val_acc=0.9333 macro_f1=0.9325
# [EPOCH] 36/38: train_loss=0.6056 val_loss=0.1957 val_acc=0.9333 macro_f1=0.9325
# [EPOCH] 37/38: train_loss=0.6085 val_loss=0.1944 val_acc=0.9400 macro_f1=0.9385
# [TRAIN] Complete. elapsed=218.7s stopped_early=True stopped_by_user=False cycles=1
# [OOD] Kalibrasyon tamamlandi. classes=3 version=1
# Cell 8: adapter save started
# Kaydedilen adapter klasoru: /content/bitirmeprojesi/outputs/colab_notebook_training/apricot/leaf/continual_sd_lora_adapter
#  - outputs/colab_notebook_training/apricot/leaf/continual_sd_lora_adapter/README.md
#  - outputs/colab_notebook_training/apricot/leaf/continual_sd_lora_adapter/adapter_config.json
#  - outputs/colab_notebook_training/apricot/leaf/continual_sd_lora_adapter/adapter_meta.json
#  - outputs/colab_notebook_training/apricot/leaf/continual_sd_lora_adapter/adapter_model.safetensors
#  - outputs/colab_notebook_training/apricot/leaf/continual_sd_lora_adapter/classifier.pth
#  - outputs/colab_notebook_training/apricot/leaf/continual_sd_lora_adapter/fusion.pth
# Telemetry adapter klasoru: /content/bitirmeprojesi/outputs/colab_notebook_training/telemetry_runtime/telemetry/apricot_leaf_2026-05-13_17-38-34/artifacts/adapter_export/apricot/leaf/continual_sd_lora_adapter
# Cell 8: adapter save completed
# [DOGRULAMA (referans)] ornek=150 sinif=3 accuracy=0.9400 ood_auroc=0.8223 sure_ds_f1=0.2128 conformal_cov=0.9600
# [TEST (ayrilmis)] ornek=150 sinif=3 accuracy=0.8867 ood_auroc=0.8099 sure_ds_f1=0.2375 conformal_cov=0.9400
# [OOD] kanit=real_ood_split durum=failed gecti=False
# [DONE] Dogrulama ve held-out test artefaktlari kaydedildi.
# /usr/local/lib/python3.12/dist-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k1__constant_value is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
# [RUNS] checkpoint_state -> /content/bitirmeprojesi/runs/apricot/leaf/apricot_leaf_2026-05-13_17-38-34/checkpoint_state
# [RUNS] outputs -> /content/bitirmeprojesi/runs/apricot/leaf/apricot_leaf_2026-05-13_17-38-34/outputs/colab_notebook_training
# [RUNS] telemetry -> /content/bitirmeprojesi/runs/apricot/leaf/apricot_leaf_2026-05-13_17-38-34/telemetry
# [RUNS] notebook -> /content/bitirmeprojesi/runs/apricot/leaf/apricot_leaf_2026-05-13_17-38-34/notebooks/6_train_all_continual_sd_lora_adapters.executed.ipynb
# [GIT] Local branch realigned to origin/master before secure run push.
# [SECURITY] scanned=145 redacted_files=62
# [GIT] Stage prepared for runs/apricot/leaf/apricot_leaf_2026-05-13_17-38-34: staged=384 skipped=3
# [GIT] Pushed 384 file(s) from runs/apricot/leaf/apricot_leaf_2026-05-13_17-38-34 to origin/master.
# [COLAB] completion checks -> {'evaluation_artifacts': True, 'production_readiness': True, 'telemetry_summary': True, 'repo_exports': True, 'executed_notebook_export': True}
# [COLAB] Auto-disconnect disabled.
#
# [NB6] Starting 2/8: apricot__fruit
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# [BOOTSTRAP] run_id=apricot_fruit_2026-05-13_17-43-26 crop=apricot part=fruit
# [ADAPTER_SELECTED] key=apricot__fruit crop=apricot part=fruit dataset=apricot__fruit ood=data/ood_dataset/final/apricot__fruit_ood_final oe_enabled=False oe= run_id=apricot_fruit_2026-05-13_17-43-26
# [TRAINING_PLAN] epochs=36 batch=40 lr=0.0001 lora_r=20 allow_under_min=False validation_every=1
# [SONRAKI] Erisim kontrolu -> dataset validation -> engine init -> training -> calibration -> save/eval hucresini sirayla calistirin.
# [BAYES] rank=1 ile 10 parametre onerisi yuklendi.
# [HF] Kimlik dogrulandi: Grizzmann
# [GIT] Auto-push on kontrolu gecti: GitHub token cozuldu.
# [CONFIG] source=notebook_cell crop=apricot epochs=12 bs=96 lr=0.0002 resume=fresh ber=False loss=logitnorm tau=1.0 auto_disconnect=True auto_push=True bayes_opt=True
# [DATASET] runtime_root=data/prepared_runtime_datasets dataset_name=apricot__fruit
# [OOD] ood_root=data/ood_dataset/final/apricot__fruit_ood_final ask_for_ood_root=False
# [OE] oe_root=<ask> ask_for_oe_root=False enabled=False loss_weight=0.1
# [RUNTIME] defaults=notebook_cell mp=bf16 workers=12 prefetch=8 sched=cosine wd=0.01 accum=1 grad_clip=1.0 label_smooth=0.0 warmup=0.1 early_stop=5/0.0 val_every=1 cache_train=True aug=randaugment randaug=2/7
# [OOD] factor=3.0 sure=90.0/97.0 conformal=raps alpha=0.05 raps_lambda=0.2 raps_k=1
# [KONTROL] Repo guncel gorunuyor.
# [KONTROL] GitHub okuma erisimi public; clone/pull icin ekstra token gerekmiyor.
# [KONTROL] GitHub push icin kimlik bilgisi hazir.
# [KONTROL] Gerekli Hugging Face modelleri anonim erisimle aciliyor.
# [BOOTSTRAP] Fetching selected Notebook 2 dataset paths: ['data/prepared_runtime_datasets/apricot__fruit', 'data/ood_dataset/final/apricot__fruit_ood_final']
# [OOD] explicit ood root=/content/bitirmeprojesi/data/ood_dataset/final/apricot__fruit_ood_final
# [DATASET] runtime root=/content/bitirmeprojesi/data/prepared_runtime_datasets/apricot__fruit classes=5: ['kayısı_sağlıklı_meyve_800', 'kayısıda_çiçek_monilyası_meyve_40', 'kayısıda_şarka_virüsü_meyve_230', 'kayısıda_şeftali_karalekesi_meyve_232', 'kayısıda_yaprak_delen_çil_hastalığı_meyve_128']
# [DATASET][CHECK] scale=small continual=871 val=280 test=280 ood=81 classes=5
# [DATASET][WARN] Manifest rows include 2 eval-quality-risk item(s); prefer cautious regularization.
# [DATASET][BLOCK] Supported classes remain below the production minimum of 100 images/class: kayısıda_çiçek_monilyası_meyve_40=40. Enable ALLOW_UNDER_MIN_TRAINING manually only for a research-only run.
# [PARAMS] Manual overrides uygulandi: {'EPOCHS': 36, 'BATCH_SIZE': 40, 'LEARNING_RATE': 0.0001, 'LORA_R': 20, 'LORA_ALPHA': 20, 'LORA_DROPOUT': 0.25, 'OOD_FACTOR': 4.5, 'LABEL_SMOOTHING': 0.15, 'AUTO_DISCONNECT_RUNTIME': False, 'AUTO_PUSH_TO_GITHUB': True, 'WEIGHT_DECAY': 0.01, 'LOSS_NAME': 'logitnorm', 'LOGITNORM_TAU': 1.0, 'MIXED_PRECISION': 'bf16', 'GRAD_ACCUM_STEPS': 1, 'VALIDATION_EVERY_N_EPOCHS': 1, 'EARLY_STOPPING_PATIENCE': 6, 'RANDAUGMENT_NUM_OPS': 2, 'RANDAUGMENT_MAGNITUDE': 7, 'NUM_WORKERS': 12, 'PREFETCH': 8, 'CACHE_TRAIN_SPLIT': True, 'ENABLE_BAYESIAN_OPTIMIZATION': True}
# [PARAMS][FINAL] epochs=36 bs=40 lr=0.0001 lora=20/20 dropout=0.25 accum=1 workers=12 prefetch=8
# [OOD] selected ood root=/content/bitirmeprojesi/data/ood_dataset/final/apricot__fruit_ood_final
# [CLASSES] ['kayısı_sag_lıklı_meyve_800', 'kayısıda_c_ic_ek_monilyası_meyve_40', 'kayısıda_s_arka_viru_su_meyve_230', 'kayısıda_s_eftali_karalekesi_meyve_232', 'kayısıda_yaprak_delen_c_il_hastalıg_ı_meyve_128']
# [CLASSES] mode=dataset_fallback reason=partial_taxonomy_alignment_fallback matched=0 unmatched=5
# [CLASSES] taxonomy-unmatched classes kept: ['kayısı_sag_lıklı_meyve_800', 'kayısıda_c_ic_ek_monilyası_meyve_40', 'kayısıda_s_arka_viru_su_meyve_230', 'kayısıda_s_eftali_karalekesi_meyve_232', 'kayısıda_yaprak_delen_c_il_hastalıg_ı_meyve_128']
# [ENGINE][OOD_CFG] {"ber_enabled": false, "ber_lambda_new": 0.1, "ber_lambda_old": 0.1, "ber_warmup_steps": 50, "conformal_alpha": 0.05, "conformal_enabled": true, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "energy_temperature": 1.0, "energy_temperature_mode": "auto", "energy_temperature_range": [0.5, 3.0], "energy_temperature_steps": 16, "knn_backend": "auto", "knn_chunk_size": 2048, "oe_enabled": false, "oe_loss_weight": 0.1, "oe_root": "", "oe_target": "uniform", "primary_score_method": "auto", "radial_beta_range": [0.5, 2.0], "radial_beta_steps": 16, "radial_l2_enabled": true, "react_apply_during_calibration": true, "react_apply_during_inference": true, "react_enabled": false, "react_percentile": 0.99, "real_dev_selection_enabled": true, "real_dev_target_fpr": 0.05, "real_split_dev_fraction": 0.4, "real_split_enabled": true, "real_split_manifest_name": "ood_split_manifest.json", "real_split_min_per_slice": 2, "sure_confidence_percentile": 97.0, "sure_enabled": true, "sure_semantic_percentile": 90.0, "threshold_factor": 4.5}
# [ENGINE][OPT_CFG] loss=logitnorm tau=1.0 label_smoothing=0.15 mixed_precision=bf16
# [ENGINE] Initializing adapter (may download backbone)...
# Loading weights:   0%|          | 0/415 [00:00<?, ?it/s]
# [ENGINE] Hazir. trainable_params=12,001,545  classes=5
# [VERIFY][OOD][expected] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 4.5}
# [VERIFY][OOD][resolved] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 4.5}
# [VERIFY][OOD] OK: cozulmus OOD ayari istenen parametrelerle eslesiyor.
# [TRAIN] epochs=36 device=cuda batch_interval=12
# [TRAIN] epoch=1 batch=12/21 loss=0.0000 lr=0.000100 speed=225.9s/s elapsed=4s eta=268s
# [CKPT] epoch_end epoch=1 step=21
# [EPOCH] 1/36: train_loss=1.6208 val_loss=1.4927 val_acc=0.1571 macro_f1=0.0543 * BEST
# [TRAIN] epoch=2 batch=12/21 loss=0.0000 lr=0.000100 speed=229.3s/s elapsed=15s eta=336s
# [EPOCH] 2/36: train_loss=1.6080 val_loss=1.7045 val_acc=0.1679 macro_f1=0.0838
# [TRAIN] epoch=3 batch=12/21 loss=0.0000 lr=0.000099 speed=229.2s/s elapsed=21s eta=274s
# [CKPT] epoch_end epoch=3 step=63
# [EPOCH] 3/36: train_loss=1.5927 val_loss=1.4113 val_acc=0.5214 macro_f1=0.3441 * BEST
# [TRAIN] epoch=4 batch=12/21 loss=0.0000 lr=0.000098 speed=229.9s/s elapsed=31s eta=279s
# [CKPT] epoch_end epoch=4 step=84
# [EPOCH] 4/36: train_loss=1.4836 val_loss=0.9940 val_acc=0.6821 macro_f1=0.4948 * BEST
# [TRAIN] epoch=5 batch=12/21 loss=0.0000 lr=0.000096 speed=229.0s/s elapsed=40s eta=273s
# [CKPT] epoch_end epoch=5 step=105
# [EPOCH] 5/36: train_loss=1.3000 val_loss=0.6159 val_acc=0.8250 macro_f1=0.6302 * BEST
# [TRAIN] epoch=6 batch=12/21 loss=0.0000 lr=0.000094 speed=229.9s/s elapsed=48s eta=263s
# [CKPT] epoch_end epoch=6 step=126
# [EPOCH] 6/36: train_loss=1.2126 val_loss=0.4159 val_acc=0.8607 macro_f1=0.6688 * BEST
# [TRAIN] epoch=7 batch=12/21 loss=0.0000 lr=0.000092 speed=229.6s/s elapsed=57s eta=256s
# [EPOCH] 7/36: train_loss=1.1599 val_loss=0.4256 val_acc=0.8643 macro_f1=0.6754
# [TRAIN] epoch=8 batch=12/21 loss=0.0000 lr=0.000090 speed=230.5s/s elapsed=63s eta=236s
# [CKPT] epoch_end epoch=8 step=168
# [EPOCH] 8/36: train_loss=1.1438 val_loss=0.2850 val_acc=0.8893 macro_f1=0.7677 * BEST
# [TRAIN] epoch=9 batch=12/21 loss=0.0000 lr=0.000087 speed=229.6s/s elapsed=72s eta=230s
# [EPOCH] 9/36: train_loss=1.1297 val_loss=0.2986 val_acc=0.8821 macro_f1=0.7739
# [TRAIN] epoch=10 batch=12/21 loss=0.0000 lr=0.000084 speed=222.3s/s elapsed=78s eta=215s
# [CKPT] epoch_end epoch=10 step=210
# [EPOCH] 10/36: train_loss=1.1090 val_loss=0.2604 val_acc=0.8893 macro_f1=0.7846 * BEST
# [TRAIN] epoch=11 batch=12/21 loss=0.0000 lr=0.000080 speed=230.2s/s elapsed=86s eta=208s
# [EPOCH] 11/36: train_loss=1.1125 val_loss=0.2680 val_acc=0.8857 macro_f1=0.7593
# [TRAIN] epoch=12 batch=12/21 loss=0.0000 lr=0.000077 speed=228.6s/s elapsed=92s eta=195s
# [CKPT] batch_250 epoch=12 step=250
# [EPOCH] 12/36: train_loss=1.0896 val_loss=0.2643 val_acc=0.8893 macro_f1=0.8018
# [TRAIN] epoch=13 batch=12/21 loss=0.0000 lr=0.000073 speed=229.7s/s elapsed=99s eta=185s
# [EPOCH] 13/36: train_loss=1.0749 val_loss=0.3012 val_acc=0.8893 macro_f1=0.7791
# [TRAIN] epoch=14 batch=12/21 loss=0.0000 lr=0.000069 speed=229.0s/s elapsed=105s eta=174s
# [CKPT] epoch_end epoch=14 step=294
# [EPOCH] 14/36: train_loss=1.0609 val_loss=0.2472 val_acc=0.9107 macro_f1=0.8454 * BEST
# [TRAIN] epoch=15 batch=12/21 loss=0.0000 lr=0.000065 speed=229.3s/s elapsed=114s eta=167s
# [CKPT] epoch_end epoch=15 step=315
# [EPOCH] 15/36: train_loss=1.0530 val_loss=0.2405 val_acc=0.9143 macro_f1=0.8408 * BEST
# [TRAIN] epoch=16 batch=12/21 loss=0.0000 lr=0.000061 speed=228.1s/s elapsed=123s eta=161s
# [EPOCH] 16/36: train_loss=1.0390 val_loss=0.2765 val_acc=0.9143 macro_f1=0.8439
# [TRAIN] epoch=17 batch=12/21 loss=0.0000 lr=0.000057 speed=229.7s/s elapsed=128s eta=151s
# [EPOCH] 17/36: train_loss=1.0424 val_loss=0.2592 val_acc=0.9179 macro_f1=0.8527
# [TRAIN] epoch=18 batch=12/21 loss=0.0000 lr=0.000052 speed=229.5s/s elapsed=134s eta=141s
# [CKPT] epoch_end epoch=18 step=378
# [EPOCH] 18/36: train_loss=1.0405 val_loss=0.2200 val_acc=0.9214 macro_f1=0.8582 * BEST
# [TRAIN] epoch=19 batch=12/21 loss=0.0000 lr=0.000048 speed=229.5s/s elapsed=143s eta=134s
# [EPOCH] 19/36: train_loss=1.0334 val_loss=0.2959 val_acc=0.9179 macro_f1=0.8465
# [TRAIN] epoch=20 batch=12/21 loss=0.0000 lr=0.000044 speed=227.4s/s elapsed=149s eta=125s
# [EPOCH] 20/36: train_loss=1.0197 val_loss=0.2257 val_acc=0.9464 macro_f1=0.9156
# [TRAIN] epoch=21 batch=12/21 loss=0.0000 lr=0.000039 speed=230.0s/s elapsed=155s eta=116s
# [EPOCH] 21/36: train_loss=1.0109 val_loss=0.2252 val_acc=0.9357 macro_f1=0.8990
# [TRAIN] epoch=22 batch=12/21 loss=0.0000 lr=0.000035 speed=229.4s/s elapsed=161s eta=108s
# [CKPT] epoch_end epoch=22 step=462
# [EPOCH] 22/36: train_loss=1.0271 val_loss=0.2092 val_acc=0.9536 macro_f1=0.9328 * BEST
# [TRAIN] epoch=23 batch=12/21 loss=0.0000 lr=0.000031 speed=229.3s/s elapsed=170s eta=101s
# [EPOCH] 23/36: train_loss=1.0233 val_loss=0.2172 val_acc=0.9429 macro_f1=0.9075
# [TRAIN] epoch=24 batch=12/21 loss=0.0000 lr=0.000027 speed=229.6s/s elapsed=175s eta=92s
# [CKPT] batch_250 epoch=24 step=500
# [CKPT] epoch_end epoch=24 step=504
# [EPOCH] 24/36: train_loss=1.0148 val_loss=0.2057 val_acc=0.9429 macro_f1=0.9075 * BEST
# [TRAIN] epoch=25 batch=12/21 loss=0.0000 lr=0.000024 speed=229.3s/s elapsed=186s eta=86s
# [EPOCH] 25/36: train_loss=1.0139 val_loss=0.2188 val_acc=0.9393 macro_f1=0.9013
# [TRAIN] epoch=26 batch=12/21 loss=0.0000 lr=0.000020 speed=228.4s/s elapsed=193s eta=79s
# [EPOCH] 26/36: train_loss=1.0122 val_loss=0.2097 val_acc=0.9393 macro_f1=0.9003
# [TRAIN] epoch=27 batch=12/21 loss=0.0000 lr=0.000017 speed=229.9s/s elapsed=198s eta=70s
# [EPOCH] 27/36: train_loss=1.0064 val_loss=0.2164 val_acc=0.9357 macro_f1=0.8867
# [TRAIN] epoch=28 batch=12/21 loss=0.0000 lr=0.000014 speed=228.1s/s elapsed=204s eta=62s
# [EPOCH] 28/36: train_loss=1.0031 val_loss=0.2113 val_acc=0.9393 macro_f1=0.8941
# [TRAIN] epoch=29 batch=12/21 loss=0.0000 lr=0.000011 speed=229.8s/s elapsed=210s eta=55s
# [EPOCH] 29/36: train_loss=1.0085 val_loss=0.2353 val_acc=0.9321 macro_f1=0.8848
# [TRAIN] epoch=30 batch=12/21 loss=0.0000 lr=0.000009 speed=228.0s/s elapsed=215s eta=47s
# [EPOCH] 30/36: train_loss=1.0130 val_loss=0.2080 val_acc=0.9393 macro_f1=0.8941
# [TRAIN] Complete. elapsed=219.4s stopped_early=True stopped_by_user=False cycles=1
# [OOD] Kalibrasyon tamamlandi. classes=5 version=1
# Cell 8: adapter save started
# Kaydedilen adapter klasoru: /content/bitirmeprojesi/outputs/colab_notebook_training/apricot/fruit/continual_sd_lora_adapter
#  - outputs/colab_notebook_training/apricot/fruit/continual_sd_lora_adapter/README.md
#  - outputs/colab_notebook_training/apricot/fruit/continual_sd_lora_adapter/adapter_config.json
#  - outputs/colab_notebook_training/apricot/fruit/continual_sd_lora_adapter/adapter_meta.json
#  - outputs/colab_notebook_training/apricot/fruit/continual_sd_lora_adapter/adapter_model.safetensors
#  - outputs/colab_notebook_training/apricot/fruit/continual_sd_lora_adapter/classifier.pth
#  - outputs/colab_notebook_training/apricot/fruit/continual_sd_lora_adapter/fusion.pth
# Telemetry adapter klasoru: /content/bitirmeprojesi/outputs/colab_notebook_training/telemetry_runtime/telemetry/apricot_fruit_2026-05-13_17-43-26/artifacts/adapter_export/apricot/fruit/continual_sd_lora_adapter
# Cell 8: adapter save completed
# [DOGRULAMA (referans)] ornek=280 sinif=5 accuracy=0.9393 ood_auroc=0.8312 sure_ds_f1=0.4770 conformal_cov=0.9536
# [TEST (ayrilmis)] ornek=280 sinif=5 accuracy=0.9536 ood_auroc=0.8373 sure_ds_f1=0.4462 conformal_cov=0.9607
# [OOD] kanit=real_ood_split durum=failed gecti=False
# [DONE] Dogrulama ve held-out test artefaktlari kaydedildi.
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
# [RUNS] checkpoint_state -> /content/bitirmeprojesi/runs/apricot/fruit/apricot_fruit_2026-05-13_17-43-26/checkpoint_state
# [RUNS] outputs -> /content/bitirmeprojesi/runs/apricot/fruit/apricot_fruit_2026-05-13_17-43-26/outputs/colab_notebook_training
# [RUNS] telemetry -> /content/bitirmeprojesi/runs/apricot/fruit/apricot_fruit_2026-05-13_17-43-26/telemetry
# [RUNS] notebook -> /content/bitirmeprojesi/runs/apricot/fruit/apricot_fruit_2026-05-13_17-43-26/notebooks/6_train_all_continual_sd_lora_adapters.executed.ipynb
# [GIT] Local branch realigned to origin/master before secure run push.
# [SECURITY] scanned=148 redacted_files=64
# [GIT] Stage prepared for runs/apricot/fruit/apricot_fruit_2026-05-13_17-43-26: staged=420 skipped=3
# [GIT] Pushed 420 file(s) from runs/apricot/fruit/apricot_fruit_2026-05-13_17-43-26 to origin/master.
# [COLAB] completion checks -> {'evaluation_artifacts': True, 'production_readiness': True, 'telemetry_summary': True, 'repo_exports': True, 'executed_notebook_export': True}
# [COLAB] Auto-disconnect disabled.
#
# [NB6] Starting 3/8: strawberry__leaf
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# [BOOTSTRAP] run_id=strawberry_leaf_2026-05-13_17-47-58 crop=strawberry part=leaf
# [ADAPTER_SELECTED] key=strawberry__leaf crop=strawberry part=leaf dataset=strawberry__leaf ood=data/prepared_runtime_datasets/strawberry__leaf/ood oe_enabled=True oe=data/prepared_runtime_datasets/strawberry__leaf/oe run_id=strawberry_leaf_2026-05-13_17-47-58
# [TRAINING_PLAN] epochs=24 batch=88 lr=0.00012 lora_r=24 allow_under_min=False validation_every=1
# [SONRAKI] Erisim kontrolu -> dataset validation -> engine init -> training -> calibration -> save/eval hucresini sirayla calistirin.
# [BAYES] rank=1 ile 10 parametre onerisi yuklendi.
# [HF] Kimlik dogrulandi: Grizzmann
# [GIT] Auto-push on kontrolu gecti: GitHub token cozuldu.
# [CONFIG] source=notebook_cell crop=strawberry epochs=12 bs=96 lr=0.0002 resume=fresh ber=False loss=logitnorm tau=1.0 auto_disconnect=True auto_push=True bayes_opt=True
# [DATASET] runtime_root=data/prepared_runtime_datasets dataset_name=strawberry__leaf
# [OOD] ood_root=data/prepared_runtime_datasets/strawberry__leaf/ood ask_for_ood_root=False
# [OE] oe_root=data/prepared_runtime_datasets/strawberry__leaf/oe ask_for_oe_root=False enabled=True loss_weight=0.25
# [RUNTIME] defaults=notebook_cell mp=bf16 workers=12 prefetch=8 sched=cosine wd=0.01 accum=1 grad_clip=1.0 label_smooth=0.0 warmup=0.1 early_stop=5/0.0 val_every=1 cache_train=True aug=randaugment randaug=2/7
# [OOD] factor=3.0 sure=90.0/97.0 conformal=raps alpha=0.05 raps_lambda=0.2 raps_k=1
# [KONTROL] Repo guncel gorunuyor.
# [KONTROL] GitHub okuma erisimi public; clone/pull icin ekstra token gerekmiyor.
# [KONTROL] GitHub push icin kimlik bilgisi hazir.
# [KONTROL] Gerekli Hugging Face modelleri anonim erisimle aciliyor.
# [BOOTSTRAP] Fetching selected Notebook 2 dataset paths: ['data/prepared_runtime_datasets/strawberry__leaf', 'data/ood_dataset/final/strawberry__leaf_ood_final', 'data/oe_dataset/strawberry_leaf_oe_from_blossom_candidates', 'data/prepared_runtime_datasets/strawberry__leaf/ood', 'data/prepared_runtime_datasets/strawberry__leaf/oe']
# [OOD] explicit ood root=/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__leaf/ood
# [OE] explicit oe root=/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__leaf/oe
# [DATASET] runtime root=/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__leaf classes=4: ['healthy', 'strawberry_leaf_scorch_leaf', 'strawberry_leaf_spot_leaf', 'strawberry_powdery_mildew_leaf']
# [DATASET][CHECK] scale=small continual=1606 val=491 test=491 ood=37 classes=4
# [PARAMS] Manual overrides uygulandi: {'EPOCHS': 24, 'BATCH_SIZE': 88, 'LEARNING_RATE': 0.00012, 'LORA_R': 24, 'LORA_ALPHA': 24, 'LORA_DROPOUT': 0.18, 'OOD_FACTOR': 4.0, 'LABEL_SMOOTHING': 0.1, 'AUTO_DISCONNECT_RUNTIME': False, 'AUTO_PUSH_TO_GITHUB': True, 'WEIGHT_DECAY': 0.01, 'LOSS_NAME': 'logitnorm', 'LOGITNORM_TAU': 1.0, 'MIXED_PRECISION': 'bf16', 'GRAD_ACCUM_STEPS': 1, 'VALIDATION_EVERY_N_EPOCHS': 1, 'EARLY_STOPPING_PATIENCE': 6, 'RANDAUGMENT_NUM_OPS': 2, 'RANDAUGMENT_MAGNITUDE': 7, 'NUM_WORKERS': 12, 'PREFETCH': 8, 'CACHE_TRAIN_SPLIT': True, 'ENABLE_BAYESIAN_OPTIMIZATION': True}
# [PARAMS][FINAL] epochs=24 bs=88 lr=0.00012 lora=24/24 dropout=0.18 accum=1 workers=12 prefetch=8
# [OOD] selected ood root=/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__leaf/ood
# [OE] selected oe root=/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__leaf/oe
# [CLASSES] ['healthy', 'strawberry_leaf_scorch_leaf', 'strawberry_leaf_spot_leaf', 'strawberry_powdery_mildew_leaf']
# [CLASSES] mode=dataset_fallback reason=partial_taxonomy_alignment_fallback matched=1 unmatched=3
# [CLASSES] taxonomy-unmatched classes kept: ['strawberry_leaf_scorch_leaf', 'strawberry_leaf_spot_leaf', 'strawberry_powdery_mildew_leaf']
# [ENGINE][OOD_CFG] {"ber_enabled": false, "ber_lambda_new": 0.1, "ber_lambda_old": 0.1, "ber_warmup_steps": 50, "conformal_alpha": 0.05, "conformal_enabled": true, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "energy_temperature": 1.0, "energy_temperature_mode": "auto", "energy_temperature_range": [0.5, 3.0], "energy_temperature_steps": 16, "knn_backend": "auto", "knn_chunk_size": 2048, "oe_enabled": true, "oe_loss_weight": 0.25, "oe_root": "/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__leaf/oe", "oe_target": "uniform", "primary_score_method": "auto", "radial_beta_range": [0.5, 2.0], "radial_beta_steps": 16, "radial_l2_enabled": true, "react_apply_during_calibration": true, "react_apply_during_inference": true, "react_enabled": false, "react_percentile": 0.99, "real_dev_selection_enabled": true, "real_dev_target_fpr": 0.05, "real_split_dev_fraction": 0.4, "real_split_enabled": true, "real_split_manifest_name": "ood_split_manifest.json", "real_split_min_per_slice": 2, "sure_confidence_percentile": 97.0, "sure_enabled": true, "sure_semantic_percentile": 90.0, "threshold_factor": 4.0}
# [ENGINE][OPT_CFG] loss=logitnorm tau=1.0 label_smoothing=0.1 mixed_precision=bf16
# [ENGINE] Initializing adapter (may download backbone)...
# Loading weights:   0%|          | 0/415 [00:00<?, ?it/s]
# [ENGINE] Hazir. trainable_params=13,770,248  classes=4
# [VERIFY][OOD][expected] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 4.0}
# [VERIFY][OOD][resolved] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 4.0}
# [VERIFY][OOD] OK: cozulmus OOD ayari istenen parametrelerle eslesiyor.
# [TRAIN] epochs=24 device=cuda batch_interval=12
# [TRAIN] epoch=1 batch=12/18 loss=0.0000 lr=0.000120 speed=261.4s/s elapsed=7s eta=254s
# [CKPT] epoch_end epoch=1 step=18
# [EPOCH] 1/24: train_loss=1.3857 val_loss=1.2507 val_acc=0.7312 macro_f1=0.5958 * BEST
# [TRAIN] epoch=2 batch=12/18 loss=0.0000 lr=0.000119 speed=261.1s/s elapsed=22s eta=293s
# [CKPT] epoch_end epoch=2 step=36
# [EPOCH] 2/24: train_loss=1.2667 val_loss=0.9874 val_acc=0.7251 macro_f1=0.6261 * BEST
# [TRAIN] epoch=3 batch=12/18 loss=0.0000 lr=0.000116 speed=260.7s/s elapsed=35s eta=280s
# [CKPT] epoch_end epoch=3 step=54
# [EPOCH] 3/24: train_loss=1.0538 val_loss=0.5618 val_acc=0.9633 macro_f1=0.9602 * BEST
# [TRAIN] epoch=4 batch=12/18 loss=0.0000 lr=0.000113 speed=260.6s/s elapsed=47s eta=262s
# [CKPT] epoch_end epoch=4 step=72
# [EPOCH] 4/24: train_loss=0.9087 val_loss=0.2189 val_acc=0.9552 macro_f1=0.9511 * BEST
# [TRAIN] epoch=5 batch=12/18 loss=0.0000 lr=0.000109 speed=261.1s/s elapsed=59s eta=245s
# [CKPT] epoch_end epoch=5 step=90
# [EPOCH] 5/24: train_loss=0.8028 val_loss=0.0497 val_acc=0.9959 macro_f1=0.9951 * BEST
# [TRAIN] epoch=6 batch=12/18 loss=0.0000 lr=0.000104 speed=260.2s/s elapsed=72s eta=232s
# [CKPT] epoch_end epoch=6 step=108
# [EPOCH] 6/24: train_loss=0.7731 val_loss=0.0318 val_acc=0.9939 macro_f1=0.9924 * BEST
# [TRAIN] epoch=7 batch=12/18 loss=0.0000 lr=0.000099 speed=260.4s/s elapsed=83s eta=217s
# [CKPT] epoch_end epoch=7 step=126
# [EPOCH] 7/24: train_loss=0.7674 val_loss=0.0209 val_acc=0.9939 macro_f1=0.9924 * BEST
# [TRAIN] epoch=8 batch=12/18 loss=0.0000 lr=0.000092 speed=261.1s/s elapsed=96s eta=204s
# [CKPT] epoch_end epoch=8 step=144
# [EPOCH] 8/24: train_loss=0.7612 val_loss=0.0177 val_acc=0.9939 macro_f1=0.9924 * BEST
# [TRAIN] epoch=9 batch=12/18 loss=0.0000 lr=0.000086 speed=260.8s/s elapsed=108s eta=191s
# [CKPT] epoch_end epoch=9 step=162
# [EPOCH] 9/24: train_loss=0.7604 val_loss=0.0123 val_acc=0.9959 macro_f1=0.9951 * BEST
# [TRAIN] epoch=10 batch=12/18 loss=0.0000 lr=0.000078 speed=260.8s/s elapsed=120s eta=178s
# [EPOCH] 10/24: train_loss=0.7579 val_loss=0.0209 val_acc=0.9959 macro_f1=0.9951
# [TRAIN] epoch=11 batch=12/18 loss=0.0000 lr=0.000071 speed=260.8s/s elapsed=131s eta=163s
# [CKPT] epoch_end epoch=11 step=198
# [EPOCH] 11/24: train_loss=0.7566 val_loss=0.0086 val_acc=0.9959 macro_f1=0.9951 * BEST
# [TRAIN] epoch=12 batch=12/18 loss=0.0000 lr=0.000063 speed=261.0s/s elapsed=143s eta=151s
# [CKPT] epoch_end epoch=12 step=216
# [EPOCH] 12/24: train_loss=0.7560 val_loss=0.0052 val_acc=0.9959 macro_f1=0.9951 * BEST
# [TRAIN] epoch=13 batch=12/18 loss=0.0000 lr=0.000055 speed=260.9s/s elapsed=155s eta=138s
# [EPOCH] 13/24: train_loss=0.7562 val_loss=0.0137 val_acc=0.9959 macro_f1=0.9951
# [TRAIN] epoch=14 batch=12/18 loss=0.0000 lr=0.000048 speed=261.2s/s elapsed=164s eta=124s
# [CKPT] batch_250 epoch=14 step=250
# [EPOCH] 14/24: train_loss=0.7554 val_loss=0.0081 val_acc=0.9959 macro_f1=0.9951
# [TRAIN] epoch=15 batch=12/18 loss=0.0000 lr=0.000040 speed=261.0s/s elapsed=175s eta=111s
# [EPOCH] 15/24: train_loss=0.7565 val_loss=0.0127 val_acc=0.9959 macro_f1=0.9951
# [TRAIN] epoch=16 batch=12/18 loss=0.0000 lr=0.000033 speed=260.9s/s elapsed=185s eta=98s
# [EPOCH] 16/24: train_loss=0.7557 val_loss=0.0212 val_acc=0.9939 macro_f1=0.9924
# [TRAIN] epoch=17 batch=12/18 loss=0.0000 lr=0.000026 speed=260.9s/s elapsed=194s eta=85s
# [EPOCH] 17/24: train_loss=0.7552 val_loss=0.0215 val_acc=0.9959 macro_f1=0.9951
# [TRAIN] epoch=18 batch=12/18 loss=0.0000 lr=0.000020 speed=260.9s/s elapsed=203s eta=73s
# [EPOCH] 18/24: train_loss=0.7555 val_loss=0.0194 val_acc=0.9939 macro_f1=0.9924
# [TRAIN] Complete. elapsed=207.1s stopped_early=True stopped_by_user=False cycles=1
# [OOD] Kalibrasyon tamamlandi. classes=4 version=1
# Cell 8: adapter save started
# Kaydedilen adapter klasoru: /content/bitirmeprojesi/outputs/colab_notebook_training/strawberry/leaf/continual_sd_lora_adapter
#  - outputs/colab_notebook_training/strawberry/leaf/continual_sd_lora_adapter/README.md
#  - outputs/colab_notebook_training/strawberry/leaf/continual_sd_lora_adapter/adapter_config.json
#  - outputs/colab_notebook_training/strawberry/leaf/continual_sd_lora_adapter/adapter_meta.json
#  - outputs/colab_notebook_training/strawberry/leaf/continual_sd_lora_adapter/adapter_model.safetensors
#  - outputs/colab_notebook_training/strawberry/leaf/continual_sd_lora_adapter/classifier.pth
#  - outputs/colab_notebook_training/strawberry/leaf/continual_sd_lora_adapter/fusion.pth
# Telemetry adapter klasoru: /content/bitirmeprojesi/outputs/colab_notebook_training/telemetry_runtime/telemetry/strawberry_leaf_2026-05-13_17-47-58/artifacts/adapter_export/strawberry/leaf/continual_sd_lora_adapter
# Cell 8: adapter save completed
# [DOGRULAMA (referans)] ornek=491 sinif=4 accuracy=0.9939 ood_auroc=0.9620 sure_ds_f1=0.5405 conformal_cov=0.9939
# [TEST (ayrilmis)] ornek=491 sinif=4 accuracy=0.9980 ood_auroc=0.9586 sure_ds_f1=0.5081 conformal_cov=0.9980
# [OOD] kanit=real_ood_split durum=failed gecti=False
# [DONE] Dogrulama ve held-out test artefaktlari kaydedildi.
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
# [RUNS] checkpoint_state -> /content/bitirmeprojesi/runs/strawberry/leaf/strawberry_leaf_2026-05-13_17-47-58/checkpoint_state
# [RUNS] outputs -> /content/bitirmeprojesi/runs/strawberry/leaf/strawberry_leaf_2026-05-13_17-47-58/outputs/colab_notebook_training
# [RUNS] telemetry -> /content/bitirmeprojesi/runs/strawberry/leaf/strawberry_leaf_2026-05-13_17-47-58/telemetry
# [RUNS] notebook -> /content/bitirmeprojesi/runs/strawberry/leaf/strawberry_leaf_2026-05-13_17-47-58/notebooks/6_train_all_continual_sd_lora_adapters.executed.ipynb
# [GIT] Local branch realigned to origin/master before secure run push.
# [SECURITY] scanned=151 redacted_files=66
# [GIT] Stage prepared for runs/strawberry/leaf/strawberry_leaf_2026-05-13_17-47-58: staged=426 skipped=3
# [GIT] Pushed 426 file(s) from runs/strawberry/leaf/strawberry_leaf_2026-05-13_17-47-58 to origin/master.
# [COLAB] completion checks -> {'evaluation_artifacts': True, 'production_readiness': True, 'telemetry_summary': True, 'repo_exports': True, 'executed_notebook_export': True}
# [COLAB] Auto-disconnect disabled.
#
# [NB6] Starting 4/8: strawberry__fruit
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# [BOOTSTRAP] run_id=strawberry_fruit_2026-05-13_17-52-38 crop=strawberry part=fruit
# [ADAPTER_SELECTED] key=strawberry__fruit crop=strawberry part=fruit dataset=strawberry__fruit ood=data/prepared_runtime_datasets/strawberry__fruit/ood oe_enabled=True oe=data/prepared_runtime_datasets/strawberry__fruit/oe run_id=strawberry_fruit_2026-05-13_17-52-38
# [TRAINING_PLAN] epochs=38 batch=40 lr=8e-05 lora_r=20 allow_under_min=True validation_every=1
# [SONRAKI] Erisim kontrolu -> dataset validation -> engine init -> training -> calibration -> save/eval hucresini sirayla calistirin.
# [BAYES] rank=1 ile 10 parametre onerisi yuklendi.
# [HF] Kimlik dogrulandi: Grizzmann
# [GIT] Auto-push on kontrolu gecti: GitHub token cozuldu.
# [CONFIG] source=notebook_cell crop=strawberry epochs=12 bs=96 lr=0.0002 resume=fresh ber=False loss=logitnorm tau=1.0 auto_disconnect=True auto_push=True bayes_opt=True
# [DATASET] runtime_root=data/prepared_runtime_datasets dataset_name=strawberry__fruit
# [OOD] ood_root=data/prepared_runtime_datasets/strawberry__fruit/ood ask_for_ood_root=False
# [OE] oe_root=data/prepared_runtime_datasets/strawberry__fruit/oe ask_for_oe_root=False enabled=True loss_weight=0.2
# [RUNTIME] defaults=notebook_cell mp=bf16 workers=12 prefetch=8 sched=cosine wd=0.01 accum=1 grad_clip=1.0 label_smooth=0.0 warmup=0.1 early_stop=5/0.0 val_every=1 cache_train=True aug=randaugment randaug=2/7
# [OOD] factor=3.0 sure=90.0/97.0 conformal=raps alpha=0.05 raps_lambda=0.2 raps_k=1
# [KONTROL] Repo guncel gorunuyor.
# [KONTROL] GitHub okuma erisimi public; clone/pull icin ekstra token gerekmiyor.
# [KONTROL] GitHub push icin kimlik bilgisi hazir.
# [KONTROL] Gerekli Hugging Face modelleri anonim erisimle aciliyor.
# [BOOTSTRAP] Fetching selected Notebook 2 dataset paths: ['data/prepared_runtime_datasets/strawberry__fruit', 'data/ood_dataset/final/strawberry__fruit_ood_final', 'data/oe_dataset/strawberry_fruit_oe_candidates', 'data/prepared_runtime_datasets/strawberry__fruit/ood', 'data/prepared_runtime_datasets/strawberry__fruit/oe']
# [OOD] explicit ood root=/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__fruit/ood
# [OE] explicit oe root=/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__fruit/oe
# [DATASET] runtime root=/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__fruit classes=5: ['strawberry_anthracnose_fruit', 'strawberry_gray_mold_fruit', 'strawberry_healthy_fruit', 'strawberry_powdery_mildew_fruit', 'strawberry_unripe_fruit']
# [DATASET][CHECK] scale=small continual=688 val=223 test=223 ood=219 classes=5
# [DATASET][WARN] Manifest rows include 5 eval-quality-risk item(s); prefer cautious regularization.
# [DATASET][BLOCK] Supported classes remain below the production minimum of 100 images/class: strawberry_anthracnose_fruit=88. Enable ALLOW_UNDER_MIN_TRAINING manually only for a research-only run.
# [PARAMS] Manual overrides uygulandi: {'EPOCHS': 38, 'BATCH_SIZE': 40, 'LEARNING_RATE': 8e-05, 'LORA_R': 20, 'LORA_ALPHA': 20, 'LORA_DROPOUT': 0.2, 'OOD_FACTOR': 4.0, 'LABEL_SMOOTHING': 0.1, 'AUTO_DISCONNECT_RUNTIME': False, 'AUTO_PUSH_TO_GITHUB': True, 'WEIGHT_DECAY': 0.01, 'LOSS_NAME': 'logitnorm', 'LOGITNORM_TAU': 1.0, 'MIXED_PRECISION': 'bf16', 'GRAD_ACCUM_STEPS': 1, 'VALIDATION_EVERY_N_EPOCHS': 1, 'EARLY_STOPPING_PATIENCE': 6, 'RANDAUGMENT_NUM_OPS': 2, 'RANDAUGMENT_MAGNITUDE': 7, 'NUM_WORKERS': 12, 'PREFETCH': 8, 'CACHE_TRAIN_SPLIT': True, 'ENABLE_BAYESIAN_OPTIMIZATION': True}
# [PARAMS][FINAL] epochs=38 bs=40 lr=8e-05 lora=20/20 dropout=0.2 accum=1 workers=12 prefetch=8
# [OOD] selected ood root=/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__fruit/ood
# [OE] selected oe root=/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__fruit/oe
# [CLASSES] ['strawberry_anthracnose_fruit', 'strawberry_gray_mold_fruit', 'strawberry_healthy_fruit', 'strawberry_powdery_mildew_fruit', 'strawberry_unripe_fruit']
# [CLASSES] mode=dataset_fallback reason=partial_taxonomy_alignment_fallback matched=0 unmatched=5
# [CLASSES] taxonomy-unmatched classes kept: ['strawberry_anthracnose_fruit', 'strawberry_gray_mold_fruit', 'strawberry_healthy_fruit', 'strawberry_powdery_mildew_fruit', 'strawberry_unripe_fruit']
# [ENGINE][OOD_CFG] {"ber_enabled": false, "ber_lambda_new": 0.1, "ber_lambda_old": 0.1, "ber_warmup_steps": 50, "conformal_alpha": 0.05, "conformal_enabled": true, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "energy_temperature": 1.0, "energy_temperature_mode": "auto", "energy_temperature_range": [0.5, 3.0], "energy_temperature_steps": 16, "knn_backend": "auto", "knn_chunk_size": 2048, "oe_enabled": true, "oe_loss_weight": 0.2, "oe_root": "/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__fruit/oe", "oe_target": "uniform", "primary_score_method": "auto", "radial_beta_range": [0.5, 2.0], "radial_beta_steps": 16, "radial_l2_enabled": true, "react_apply_during_calibration": true, "react_apply_during_inference": true, "react_enabled": false, "react_percentile": 0.99, "real_dev_selection_enabled": true, "real_dev_target_fpr": 0.05, "real_split_dev_fraction": 0.4, "real_split_enabled": true, "real_split_manifest_name": "ood_split_manifest.json", "real_split_min_per_slice": 2, "sure_confidence_percentile": 97.0, "sure_enabled": true, "sure_semantic_percentile": 90.0, "threshold_factor": 4.0}
# [ENGINE][OPT_CFG] loss=logitnorm tau=1.0 label_smoothing=0.1 mixed_precision=bf16
# [ENGINE] Initializing adapter (may download backbone)...
# Loading weights:   0%|          | 0/415 [00:00<?, ?it/s]
# [ENGINE] Hazir. trainable_params=12,001,545  classes=5
# [VERIFY][OOD][expected] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 4.0}
# [VERIFY][OOD][resolved] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 4.0}
# [VERIFY][OOD] OK: cozulmus OOD ayari istenen parametrelerle eslesiyor.
# [TRAIN] epochs=38 device=cuda batch_interval=12
# [TRAIN] epoch=1 batch=12/17 loss=0.0000 lr=0.000080 speed=228.8s/s elapsed=4s eta=236s
# [CKPT] epoch_end epoch=1 step=17
# [EPOCH] 1/38: train_loss=1.6256 val_loss=1.6370 val_acc=0.1345 macro_f1=0.0474 * BEST
# [TRAIN] epoch=2 batch=12/17 loss=0.0000 lr=0.000080 speed=228.2s/s elapsed=15s eta=325s
# [EPOCH] 2/38: train_loss=1.6026 val_loss=1.6531 val_acc=0.1031 macro_f1=0.0374
# [TRAIN] epoch=3 batch=12/17 loss=0.0000 lr=0.000079 speed=229.6s/s elapsed=21s eta=269s
# [CKPT] epoch_end epoch=3 step=51
# [EPOCH] 3/38: train_loss=1.5769 val_loss=1.3907 val_acc=0.5516 macro_f1=0.3125 * BEST
# [TRAIN] epoch=4 batch=12/17 loss=0.0000 lr=0.000078 speed=229.1s/s elapsed=30s eta=274s
# [CKPT] epoch_end epoch=4 step=68
# [EPOCH] 4/38: train_loss=1.4886 val_loss=1.2187 val_acc=0.6368 macro_f1=0.4460 * BEST
# [TRAIN] epoch=5 batch=12/17 loss=0.0000 lr=0.000077 speed=228.5s/s elapsed=38s eta=268s
# [CKPT] epoch_end epoch=5 step=85
# [EPOCH] 5/38: train_loss=1.3247 val_loss=0.9523 val_acc=0.7220 macro_f1=0.5509 * BEST
# [TRAIN] epoch=6 batch=12/17 loss=0.0000 lr=0.000076 speed=229.1s/s elapsed=46s eta=258s
# [CKPT] epoch_end epoch=6 step=102
# [EPOCH] 6/38: train_loss=1.2740 val_loss=0.8520 val_acc=0.7220 macro_f1=0.5572 * BEST
# [TRAIN] epoch=7 batch=12/17 loss=0.0000 lr=0.000074 speed=228.1s/s elapsed=54s eta=251s
# [CKPT] epoch_end epoch=7 step=119
# [EPOCH] 7/38: train_loss=1.2552 val_loss=0.7355 val_acc=0.7444 macro_f1=0.6301 * BEST
# [TRAIN] epoch=8 batch=12/17 loss=0.0000 lr=0.000072 speed=227.5s/s elapsed=62s eta=245s
# [EPOCH] 8/38: train_loss=1.2132 val_loss=0.7504 val_acc=0.7623 macro_f1=0.6851
# [TRAIN] epoch=9 batch=12/17 loss=0.0000 lr=0.000070 speed=227.7s/s elapsed=67s eta=226s
# [CKPT] epoch_end epoch=9 step=153
# [EPOCH] 9/38: train_loss=1.1961 val_loss=0.6855 val_acc=0.7534 macro_f1=0.6674 * BEST
# [TRAIN] epoch=10 batch=12/17 loss=0.0000 lr=0.000068 speed=228.0s/s elapsed=76s eta=220s
# [EPOCH] 10/38: train_loss=1.1689 val_loss=0.7113 val_acc=0.7444 macro_f1=0.6559
# ...
#  - outputs/colab_notebook_training/strawberry/fruit/continual_sd_lora_adapter/README.md
#  - outputs/colab_notebook_training/strawberry/fruit/continual_sd_lora_adapter/adapter_config.json
#  - outputs/colab_notebook_training/strawberry/fruit/continual_sd_lora_adapter/adapter_meta.json
#  - outputs/colab_notebook_training/strawberry/fruit/continual_sd_lora_adapter/adapter_model.safetensors
#  - outputs/colab_notebook_training/strawberry/fruit/continual_sd_lora_adapter/classifier.pth
#  - outputs/colab_notebook_training/strawberry/fruit/continual_sd_lora_adapter/fusion.pth
# Telemetry adapter klasoru: /content/bitirmeprojesi/outputs/colab_notebook_training/telemetry_runtime/telemetry/strawberry_fruit_2026-05-13_17-52-38/artifacts/adapter_export/strawberry/fruit/continual_sd_lora_adapter
# Cell 8: adapter save completed
# [DOGRULAMA (referans)] ornek=223 sinif=5 accuracy=0.7803 ood_auroc=0.9269 sure_ds_f1=0.2938 conformal_cov=0.9552
# [TEST (ayrilmis)] ornek=223 sinif=5 accuracy=0.8117 ood_auroc=0.9273 sure_ds_f1=0.2630 conformal_cov=0.9686
# [OOD] kanit=real_ood_split durum=failed gecti=False
# [DONE] Dogrulama ve held-out test artefaktlari kaydedildi.
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
# [RUNS] checkpoint_state -> /content/bitirmeprojesi/runs/strawberry/fruit/strawberry_fruit_2026-05-13_17-52-38/checkpoint_state
# [RUNS] outputs -> /content/bitirmeprojesi/runs/strawberry/fruit/strawberry_fruit_2026-05-13_17-52-38/outputs/colab_notebook_training
# [RUNS] telemetry -> /content/bitirmeprojesi/runs/strawberry/fruit/strawberry_fruit_2026-05-13_17-52-38/telemetry
# [RUNS] notebook -> /content/bitirmeprojesi/runs/strawberry/fruit/strawberry_fruit_2026-05-13_17-52-38/notebooks/6_train_all_continual_sd_lora_adapters.executed.ipynb
# [GIT] Local branch realigned to origin/master before secure run push.
# [SECURITY] scanned=154 redacted_files=68
# [GIT] Stage prepared for runs/strawberry/fruit/strawberry_fruit_2026-05-13_17-52-38: staged=504 skipped=3
# [GIT] Pushed 504 file(s) from runs/strawberry/fruit/strawberry_fruit_2026-05-13_17-52-38 to origin/master.
# [COLAB] completion checks -> {'evaluation_artifacts': True, 'production_readiness': True, 'telemetry_summary': True, 'repo_exports': True, 'executed_notebook_export': True}
# [COLAB] Auto-disconnect disabled.
#
# [NB6] Starting 5/8: grape__leaf
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# [BOOTSTRAP] run_id=grape_leaf_2026-05-13_17-55-48 crop=grape part=leaf
# [ADAPTER_SELECTED] key=grape__leaf crop=grape part=leaf dataset=grape__leaf ood=data/prepared_runtime_datasets/grape__leaf/ood oe_enabled=True oe=data/prepared_runtime_datasets/grape__leaf/oe run_id=grape_leaf_2026-05-13_17-55-48
# [TRAINING_PLAN] epochs=30 batch=56 lr=0.0001 lora_r=24 allow_under_min=False validation_every=1
# [SONRAKI] Erisim kontrolu -> dataset validation -> engine init -> training -> calibration -> save/eval hucresini sirayla calistirin.
# [BAYES] rank=1 ile 10 parametre onerisi yuklendi.
# [HF] Kimlik dogrulandi: Grizzmann
# [GIT] Auto-push on kontrolu gecti: GitHub token cozuldu.
# [CONFIG] source=notebook_cell crop=grape epochs=12 bs=96 lr=0.0002 resume=fresh ber=False loss=logitnorm tau=1.0 auto_disconnect=True auto_push=True bayes_opt=True
# [DATASET] runtime_root=data/prepared_runtime_datasets dataset_name=grape__leaf
# [OOD] ood_root=data/prepared_runtime_datasets/grape__leaf/ood ask_for_ood_root=False
# [OE] oe_root=data/prepared_runtime_datasets/grape__leaf/oe ask_for_oe_root=False enabled=True loss_weight=0.22
# [RUNTIME] defaults=notebook_cell mp=bf16 workers=12 prefetch=8 sched=cosine wd=0.01 accum=1 grad_clip=1.0 label_smooth=0.0 warmup=0.1 early_stop=5/0.0 val_every=1 cache_train=True aug=randaugment randaug=2/7
# [OOD] factor=3.0 sure=90.0/97.0 conformal=raps alpha=0.05 raps_lambda=0.2 raps_k=1
# [KONTROL] Repo guncel gorunuyor.
# [KONTROL] GitHub okuma erisimi public; clone/pull icin ekstra token gerekmiyor.
# [KONTROL] GitHub push icin kimlik bilgisi hazir.
# [KONTROL] Gerekli Hugging Face modelleri anonim erisimle aciliyor.
# [BOOTSTRAP] Fetching selected Notebook 2 dataset paths: ['data/prepared_runtime_datasets/grape__leaf', 'data/ood_dataset/final/grape__leaf_ood_final', 'data/oe_dataset/grape_leaf_oe_unsupported_leaf_candidates', 'data/prepared_runtime_datasets/grape__leaf/ood', 'data/prepared_runtime_datasets/grape__leaf/oe']
# [OOD] explicit ood root=/content/bitirmeprojesi/data/prepared_runtime_datasets/grape__leaf/ood
# [OE] explicit oe root=/content/bitirmeprojesi/data/prepared_runtime_datasets/grape__leaf/oe
# [DATASET] runtime root=/content/bitirmeprojesi/data/prepared_runtime_datasets/grape__leaf classes=7: ['üzüm_antraknoz_yaprak', 'üzüm_kav_esca_yaprak', 'üzüm_külleme_yaprak', 'üzüm_leafroll_virüs_yaprak', 'üzüm_mildiyö_yaprak', 'üzüm_sağlıklı_yaprak', 'üzüm_yelpaze_virüsü_yaprak']
# [DATASET][CHECK] scale=small continual=1207 val=324 test=324 ood=327 classes=7
# [DATASET][WARN] Manifest rows include 182 eval-quality-risk item(s); prefer cautious regularization.
# [PARAMS] Manual overrides uygulandi: {'EPOCHS': 30, 'BATCH_SIZE': 56, 'LEARNING_RATE': 0.0001, 'LORA_R': 24, 'LORA_ALPHA': 24, 'LORA_DROPOUT': 0.14, 'OOD_FACTOR': 3.5, 'LABEL_SMOOTHING': 0.08, 'AUTO_DISCONNECT_RUNTIME': False, 'AUTO_PUSH_TO_GITHUB': True, 'WEIGHT_DECAY': 0.01, 'LOSS_NAME': 'logitnorm', 'LOGITNORM_TAU': 1.0, 'MIXED_PRECISION': 'bf16', 'GRAD_ACCUM_STEPS': 1, 'VALIDATION_EVERY_N_EPOCHS': 1, 'EARLY_STOPPING_PATIENCE': 6, 'RANDAUGMENT_NUM_OPS': 2, 'RANDAUGMENT_MAGNITUDE': 7, 'NUM_WORKERS': 12, 'PREFETCH': 8, 'CACHE_TRAIN_SPLIT': True, 'ENABLE_BAYESIAN_OPTIMIZATION': True}
# [PARAMS][FINAL] epochs=30 bs=56 lr=0.0001 lora=24/24 dropout=0.14 accum=1 workers=12 prefetch=8
# [OOD] selected ood root=/content/bitirmeprojesi/data/prepared_runtime_datasets/grape__leaf/ood
# [OE] selected oe root=/content/bitirmeprojesi/data/prepared_runtime_datasets/grape__leaf/oe
# [CLASSES] ['u_zu_m_antraknoz_yaprak', 'u_zu_m_kav_esca_yaprak', 'u_zu_m_ku_lleme_yaprak', 'u_zu_m_leafroll_viru_s_yaprak', 'u_zu_m_mildiyo_yaprak', 'u_zu_m_sag_lıklı_yaprak', 'u_zu_m_yelpaze_viru_su_yaprak']
# [CLASSES] mode=dataset_fallback reason=partial_taxonomy_alignment_fallback matched=0 unmatched=7
# [CLASSES] taxonomy-unmatched classes kept: ['u_zu_m_antraknoz_yaprak', 'u_zu_m_kav_esca_yaprak', 'u_zu_m_ku_lleme_yaprak', 'u_zu_m_leafroll_viru_s_yaprak', 'u_zu_m_mildiyo_yaprak', 'u_zu_m_sag_lıklı_yaprak', 'u_zu_m_yelpaze_viru_su_yaprak']
# [ENGINE][OOD_CFG] {"ber_enabled": false, "ber_lambda_new": 0.1, "ber_lambda_old": 0.1, "ber_warmup_steps": 50, "conformal_alpha": 0.05, "conformal_enabled": true, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "energy_temperature": 1.0, "energy_temperature_mode": "auto", "energy_temperature_range": [0.5, 3.0], "energy_temperature_steps": 16, "knn_backend": "auto", "knn_chunk_size": 2048, "oe_enabled": true, "oe_loss_weight": 0.22, "oe_root": "/content/bitirmeprojesi/data/prepared_runtime_datasets/grape__leaf/oe", "oe_target": "uniform", "primary_score_method": "auto", "radial_beta_range": [0.5, 2.0], "radial_beta_steps": 16, "radial_l2_enabled": true, "react_apply_during_calibration": true, "react_apply_during_inference": true, "react_enabled": false, "react_percentile": 0.99, "real_dev_selection_enabled": true, "real_dev_target_fpr": 0.05, "real_split_dev_fraction": 0.4, "real_split_enabled": true, "real_split_manifest_name": "ood_split_manifest.json", "real_split_min_per_slice": 2, "sure_confidence_percentile": 97.0, "sure_enabled": true, "sure_semantic_percentile": 90.0, "threshold_factor": 3.5}
# [ENGINE][OPT_CFG] loss=logitnorm tau=1.0 label_smoothing=0.08 mixed_precision=bf16
# [ENGINE] Initializing adapter (may download backbone)...
# Loading weights:   0%|          | 0/415 [00:00<?, ?it/s]
# [ENGINE] Hazir. trainable_params=13,772,555  classes=7
# [VERIFY][OOD][expected] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 3.5}
# [VERIFY][OOD][resolved] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 3.5}
# [VERIFY][OOD] OK: cozulmus OOD ayari istenen parametrelerle eslesiyor.
# [TRAIN] epochs=30 device=cuda batch_interval=12
# [TRAIN] epoch=1 batch=12/21 loss=0.0000 lr=0.000100 speed=247.3s/s elapsed=5s eta=279s
# [CKPT] epoch_end epoch=1 step=21
# [EPOCH] 1/30: train_loss=1.9833 val_loss=1.8905 val_acc=0.1759 macro_f1=0.0614 * BEST
# [TRAIN] epoch=2 batch=12/21 loss=0.0000 lr=0.000099 speed=247.4s/s elapsed=19s eta=341s
# [EPOCH] 2/30: train_loss=1.9373 val_loss=1.9251 val_acc=0.1111 macro_f1=0.0725
# [TRAIN] epoch=3 batch=12/21 loss=0.0000 lr=0.000098 speed=247.4s/s elapsed=27s eta=284s
# [CKPT] epoch_end epoch=3 step=63
# [EPOCH] 3/30: train_loss=1.9119 val_loss=1.8781 val_acc=0.2593 macro_f1=0.2147 * BEST
# [TRAIN] epoch=4 batch=12/21 loss=0.0000 lr=0.000097 speed=247.3s/s elapsed=38s eta=283s
# [CKPT] epoch_end epoch=4 step=84
# [EPOCH] 4/30: train_loss=1.7596 val_loss=1.4423 val_acc=0.4537 macro_f1=0.4083 * BEST
# [TRAIN] epoch=5 batch=12/21 loss=0.0000 lr=0.000094 speed=247.5s/s elapsed=49s eta=275s
# [CKPT] epoch_end epoch=5 step=105
# [EPOCH] 5/30: train_loss=1.6433 val_loss=1.2308 val_acc=0.4877 macro_f1=0.4379 * BEST
# [TRAIN] epoch=6 batch=12/21 loss=0.0000 lr=0.000092 speed=247.1s/s elapsed=60s eta=262s
# [CKPT] epoch_end epoch=6 step=126
# [EPOCH] 6/30: train_loss=1.5509 val_loss=1.0488 val_acc=0.6142 macro_f1=0.5889 * BEST
# [TRAIN] epoch=7 batch=12/21 loss=0.0000 lr=0.000089 speed=247.0s/s elapsed=71s eta=251s
# [CKPT] epoch_end epoch=7 step=147
# [EPOCH] 7/30: train_loss=1.5079 val_loss=0.9413 val_acc=0.6543 macro_f1=0.6337 * BEST
# [TRAIN] epoch=8 batch=12/21 loss=0.0000 lr=0.000085 speed=247.1s/s elapsed=82s eta=242s
# [CKPT] epoch_end epoch=8 step=168
# [EPOCH] 8/30: train_loss=1.4459 val_loss=0.8789 val_acc=0.7160 macro_f1=0.6907 * BEST
# [TRAIN] epoch=9 batch=12/21 loss=0.0000 lr=0.000081 speed=245.3s/s elapsed=93s eta=231s
# [EPOCH] 9/30: train_loss=1.4367 val_loss=0.8829 val_acc=0.7407 macro_f1=0.7091
# [TRAIN] epoch=10 batch=12/21 loss=0.0000 lr=0.000077 speed=247.2s/s elapsed=100s eta=214s
# [EPOCH] 10/30: train_loss=1.4434 val_loss=0.8944 val_acc=0.7284 macro_f1=0.6923
# [TRAIN] epoch=11 batch=12/21 loss=0.0000 lr=0.000073 speed=247.3s/s elapsed=109s eta=200s
# [CKPT] epoch_end epoch=11 step=231
# [EPOCH] 11/30: train_loss=1.4035 val_loss=0.7589 val_acc=0.7685 macro_f1=0.7370 * BEST
# [TRAIN] epoch=12 batch=12/21 loss=0.0000 lr=0.000068 speed=246.7s/s elapsed=119s eta=190s
# [CKPT] batch_250 epoch=12 step=250
# [EPOCH] 12/30: train_loss=1.3915 val_loss=0.7930 val_acc=0.7840 macro_f1=0.7600
# [TRAIN] epoch=13 batch=12/21 loss=0.0000 lr=0.000063 speed=247.3s/s elapsed=128s eta=178s
# [CKPT] epoch_end epoch=13 step=273
# [EPOCH] 13/30: train_loss=1.3888 val_loss=0.7134 val_acc=0.7932 macro_f1=0.7603 * BEST
# [TRAIN] epoch=14 batch=12/21 loss=0.0000 lr=0.000058 speed=247.7s/s elapsed=139s eta=168s
# [CKPT] epoch_end epoch=14 step=294
# [EPOCH] 14/30: train_loss=1.3722 val_loss=0.6689 val_acc=0.8056 macro_f1=0.7740 * BEST
# [TRAIN] epoch=15 batch=12/21 loss=0.0000 lr=0.000053 speed=247.6s/s elapsed=149s eta=158s
# [CKPT] epoch_end epoch=15 step=315
# [EPOCH] 15/30: train_loss=1.3665 val_loss=0.6335 val_acc=0.8117 macro_f1=0.7815 * BEST
# [TRAIN] epoch=16 batch=12/21 loss=0.0000 lr=0.000048 speed=246.9s/s elapsed=160s eta=148s
# [EPOCH] 16/30: train_loss=1.3569 val_loss=0.6419 val_acc=0.8302 macro_f1=0.8012
# [TRAIN] epoch=17 batch=12/21 loss=0.0000 lr=0.000042 speed=248.0s/s elapsed=167s eta=136s
# [EPOCH] 17/30: train_loss=1.3448 val_loss=0.6422 val_acc=0.8333 macro_f1=0.8099
# [TRAIN] epoch=18 batch=12/21 loss=0.0000 lr=0.000037 speed=246.7s/s elapsed=175s eta=124s
# [CKPT] epoch_end epoch=18 step=378
# [EPOCH] 18/30: train_loss=1.3352 val_loss=0.5750 val_acc=0.8549 macro_f1=0.8292 * BEST
# [TRAIN] epoch=19 batch=12/21 loss=0.0000 lr=0.000032 speed=247.3s/s elapsed=185s eta=114s
# [CKPT] epoch_end epoch=19 step=399
# [EPOCH] 19/30: train_loss=1.3320 val_loss=0.5607 val_acc=0.8611 macro_f1=0.8356 * BEST
# [TRAIN] epoch=20 batch=12/21 loss=0.0000 lr=0.000028 speed=247.6s/s elapsed=196s eta=104s
# [EPOCH] 20/30: train_loss=1.3205 val_loss=0.5851 val_acc=0.8519 macro_f1=0.8271
# [TRAIN] epoch=21 batch=12/21 loss=0.0000 lr=0.000023 speed=247.5s/s elapsed=204s eta=94s
# [EPOCH] 21/30: train_loss=1.3245 val_loss=0.5799 val_acc=0.8488 macro_f1=0.8229
# [TRAIN] epoch=22 batch=12/21 loss=0.0000 lr=0.000019 speed=247.1s/s elapsed=211s eta=83s
# [CKPT] epoch_end epoch=22 step=462
# [EPOCH] 22/30: train_loss=1.3286 val_loss=0.5377 val_acc=0.8488 macro_f1=0.8222 * BEST
# [TRAIN] epoch=23 batch=12/21 loss=0.0000 lr=0.000015 speed=246.3s/s elapsed=222s eta=73s
# [EPOCH] 23/30: train_loss=1.3230 val_loss=0.5486 val_acc=0.8611 macro_f1=0.8384
# [TRAIN] epoch=24 batch=12/21 loss=0.0000 lr=0.000012 speed=247.1s/s elapsed=229s eta=63s
# [CKPT] batch_250 epoch=24 step=500
# [CKPT] epoch_end epoch=24 step=504
# [EPOCH] 24/30: train_loss=1.3218 val_loss=0.5373 val_acc=0.8549 macro_f1=0.8270 * BEST
# [TRAIN] epoch=25 batch=12/21 loss=0.0000 lr=0.000009 speed=246.7s/s elapsed=242s eta=53s
# [CKPT] epoch_end epoch=25 step=525
# [EPOCH] 25/30: train_loss=1.3098 val_loss=0.5313 val_acc=0.8519 macro_f1=0.8239 * BEST
# [TRAIN] epoch=26 batch=12/21 loss=0.0000 lr=0.000006 speed=246.9s/s elapsed=252s eta=44s
# [EPOCH] 26/30: train_loss=1.3239 val_loss=0.5378 val_acc=0.8580 macro_f1=0.8318
# [TRAIN] epoch=27 batch=12/21 loss=0.0000 lr=0.000004 speed=246.9s/s elapsed=260s eta=34s
# [EPOCH] 27/30: train_loss=1.3111 val_loss=0.5330 val_acc=0.8580 macro_f1=0.8318
# [TRAIN] epoch=28 batch=12/21 loss=0.0000 lr=0.000003 speed=247.1s/s elapsed=267s eta=24s
# [CKPT] epoch_end epoch=28 step=588
# [EPOCH] 28/30: train_loss=1.3148 val_loss=0.5241 val_acc=0.8549 macro_f1=0.8262 * BEST
# [TRAIN] epoch=29 batch=12/21 loss=0.0000 lr=0.000002 speed=245.7s/s elapsed=278s eta=14s
# [EPOCH] 29/30: train_loss=1.3155 val_loss=0.5250 val_acc=0.8580 macro_f1=0.8302
# [TRAIN] epoch=30 batch=12/21 loss=0.0000 lr=0.000001 speed=245.8s/s elapsed=286s eta=4s
# [CKPT] epoch_end epoch=30 step=630
# [EPOCH] 30/30: train_loss=1.3071 val_loss=0.5279 val_acc=0.8549 macro_f1=0.8260
# [TRAIN] Complete. elapsed=292.3s stopped_early=False stopped_by_user=False cycles=1
# [OOD] Kalibrasyon tamamlandi. classes=7 version=1
# Cell 8: adapter save started
# Kaydedilen adapter klasoru: /content/bitirmeprojesi/outputs/colab_notebook_training/grape/leaf/continual_sd_lora_adapter
#  - outputs/colab_notebook_training/grape/leaf/continual_sd_lora_adapter/README.md
#  - outputs/colab_notebook_training/grape/leaf/continual_sd_lora_adapter/adapter_config.json
#  - outputs/colab_notebook_training/grape/leaf/continual_sd_lora_adapter/adapter_meta.json
#  - outputs/colab_notebook_training/grape/leaf/continual_sd_lora_adapter/adapter_model.safetensors
#  - outputs/colab_notebook_training/grape/leaf/continual_sd_lora_adapter/classifier.pth
#  - outputs/colab_notebook_training/grape/leaf/continual_sd_lora_adapter/fusion.pth
# Telemetry adapter klasoru: /content/bitirmeprojesi/outputs/colab_notebook_training/telemetry_runtime/telemetry/grape_leaf_2026-05-13_17-55-48/artifacts/adapter_export/grape/leaf/continual_sd_lora_adapter
# Cell 8: adapter save completed
# [DOGRULAMA (referans)] ornek=324 sinif=7 accuracy=0.8549 ood_auroc=0.8345 sure_ds_f1=0.3510 conformal_cov=0.9537
# [TEST (ayrilmis)] ornek=324 sinif=7 accuracy=0.8920 ood_auroc=0.8324 sure_ds_f1=0.3581 conformal_cov=0.9599
# [OOD] kanit=real_ood_split durum=failed gecti=False
# [DONE] Dogrulama ve held-out test artefaktlari kaydedildi.
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
