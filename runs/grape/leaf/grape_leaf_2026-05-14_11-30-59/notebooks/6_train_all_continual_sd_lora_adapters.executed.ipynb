# %% [markdown]
# # Notebook 6: Batch Train All Continual SD-LoRA Adapters
#
# Bu notebook, Notebook 2 akisini baz alir ve tanimli adapterleri sirayla egitir.
#
# Akis:
# 1. Repo bootstrap ve Notebook 2 helper'larini yukle.
# 2. Adapter matrisi ve sirayi tanimla.
# 3. Her adapter icin Notebook 2 parametre, dataset validation, training, OOD calibration, export ve final evaluation hucrelerini calistir.
# 4. Her run icin ozet yazdir; runtime auto-disconnect batch bitene kadar kapali kalir.

# %%
from pathlib import Path
import os
import subprocess
import sys
from urllib.parse import urlsplit, urlunsplit

CLONE_TARGET = Path('/content/bitirmeprojesi')
REPO_URL = os.environ.get('AADS_REPO_URL', 'https://github.com/EfeErim/bitirmeprojesi.git')
NOTEBOOK6_SPARSE_PATHS = (
    'README.md',
    'docs',
    'src',
    'scripts',
    'config',
    'colab_notebooks',
    'requirements.txt',
    'requirements_colab.txt',
    'pyproject.toml',
)

def _build_repo_access_url(repo_url, token):
    token = str(token or '').strip()
    if not token:
        return repo_url
    parsed = urlsplit(str(repo_url or '').strip())
    if parsed.scheme != 'https' or not parsed.netloc:
        return repo_url
    netloc = parsed.netloc.split('@', 1)[-1]
    return urlunsplit((parsed.scheme, f'{token}@{netloc}', parsed.path, parsed.query, parsed.fragment))

def _ensure_aads_repo_on_path():
    candidates = [Path.cwd(), Path.cwd().parent, CLONE_TARGET, Path('/content/bitirmeprojesi'), Path('/content/bitirme projesi')]
    for candidate in candidates:
        marker = candidate / 'scripts' / 'notebook_helpers' / 'cell_script_runner.py'
        if marker.is_file():
            repo_root = candidate.resolve()
            if str(repo_root) not in sys.path:
                sys.path.insert(0, str(repo_root))
            return repo_root
    clone_url = _build_repo_access_url(REPO_URL, os.environ.get('GH_TOKEN') or os.environ.get('GITHUB_TOKEN'))
    if not CLONE_TARGET.exists():
        subprocess.run(['git', 'clone', '--depth', '1', '--filter=blob:none', '--sparse', clone_url, str(CLONE_TARGET)], check=True)
        subprocess.run(['git', 'sparse-checkout', 'set', *NOTEBOOK6_SPARSE_PATHS], cwd=str(CLONE_TARGET), check=True)
    if str(CLONE_TARGET) not in sys.path:
        sys.path.insert(0, str(CLONE_TARGET))
    return CLONE_TARGET

_ensure_aads_repo_on_path()

from scripts.notebook_helpers.cell_script_runner import run_cell_script
run_cell_script('nb2_cell01_bootstrap_access.py', globals())
# Out:
# [BOOTSTRAP] GitHub token found.
# [BOOTSTRAP] HuggingFace token found.
# [BOOTSTRAP] Repo root: /content/bitirmeprojesi
# [BOOTSTRAP] Installing requirements_colab.txt...
# [BOOTSTRAP] Notebook 2: Continual Adapter Training bootstrap complete.
#
# ======================================================================
# BOOTSTRAP STATUS
# ======================================================================
# Status: ok
# Repo Root: /content/bitirmeprojesi
# In Colab: True
# GitHub Token: ✓
# HuggingFace Token: ✓
# ======================================================================
#
# [SONRAKI] Parametre ve adapter secimi hucresine gecin; model erisimi ayrica access-check hucresinde dogrulanacak.

# %%
NOTEBOOK_NAME = "6_train_all_continual_sd_lora_adapters.ipynb"
NOTEBOOK_FILENAME = "6_train_all_continual_sd_lora_adapters.executed.ipynb"
AUTO_DISCONNECT_RUNTIME = False
AUTO_PUSH_TO_GITHUB = True
NB6_AUTO_DISCONNECT_RUNTIME = True
NB6_AUTO_DISCONNECT_GRACE_SECONDS = 20
ENABLE_BAYESIAN_OPTIMIZATION = True
MANUAL_PARAM_OVERRIDES = {}
DEFAULT_RUNTIME_PARAMS = {
    "AUTO_DISCONNECT_RUNTIME": False,
    "AUTO_PUSH_TO_GITHUB": True,
}
NB6_MANUAL_PARAM_OVERRIDES = {}

from scripts.notebook_helpers.adapter_recommendations import get_adapter_recs
ADAPTER_RECS = get_adapter_recs()

NB6_ADAPTER_SEQUENCE = [
    "apricot__leaf",
    "apricot__fruit",
    "strawberry__leaf",
    "strawberry__fruit",
    "grape__leaf",
    "grape__fruit",
    "tomato__leaf",
    "tomato__fruit",
]

# %%
import json

NB6_RESULTS = {}

for index, adapter_key in enumerate(NB6_ADAPTER_SEQUENCE, start=1):
    print(f"\n[NB6] Starting {index}/{len(NB6_ADAPTER_SEQUENCE)}: {adapter_key}")
    adapter_rec = ADAPTER_RECS[adapter_key]
    CROP_NAME = adapter_rec["crop"]
    PART_NAME = adapter_rec["part"]
    DATASET_NAME = adapter_key
    ADAPTER_KEY = adapter_key
    MANUAL_PARAM_OVERRIDES = dict(NB6_MANUAL_PARAM_OVERRIDES.get(adapter_key, {}))
    try:
        run_cell_script('nb2_cell03_runtime_setup.py', globals())
        run_cell_script('nb2_cell04_parameter_resolution.py', globals())
        run_cell_script('nb2_cell05_access_check.py', globals())
        run_cell_script('nb2_cell06_dataset_validation.py', globals())
        run_cell_script('nb2_cell07_engine_init.py', globals())
        run_cell_script('nb2_cell08_ood_config_verify.py', globals())
        run_cell_script('nb2_cell09_training.py', globals())
        run_cell_script('nb2_cell10_ood_calibration.py', globals())
        run_cell_script('nb2_cell11_adapter_save.py', globals())
        run_cell_script('nb2_cell12_final_evaluation.py', globals())
        NB6_RESULTS[adapter_key] = {
            "status": "ok",
            "run_id": str(globals().get("RUN_ID", "")),
            "crop": str(globals().get("CROP_NAME", "")),
            "part": str(globals().get("PART_NAME", "")),
        }
    except Exception as exc:
        NB6_RESULTS[adapter_key] = {
            "status": "failed",
            "error": str(exc),
            "run_id": str(globals().get("RUN_ID", "")),
            "crop": str(globals().get("CROP_NAME", "")),
            "part": str(globals().get("PART_NAME", "")),
        }
        print(f"[NB6] FAILED {adapter_key}: {exc}")
        continue

print('\n[NB6] SUMMARY')
print(json.dumps(NB6_RESULTS, indent=2, ensure_ascii=False))

from scripts.colab_notebook_helpers import maybe_auto_disconnect_colab_runtime

NB6_COMPLETION_REPORT = {
    "ready": True,
    "checks": {
        "batch_loop_completed": True,
        "all_adapters_attempted": len(NB6_RESULTS) == len(NB6_ADAPTER_SEQUENCE),
    },
    "missing": [],
    "soft_missing": [],
    "adapter_results": NB6_RESULTS,
}
maybe_auto_disconnect_colab_runtime(
    enabled=bool(NB6_AUTO_DISCONNECT_RUNTIME),
    grace_period_sec=float(NB6_AUTO_DISCONNECT_GRACE_SECONDS),
    telemetry=globals().get("TELEMETRY"),
    completion_report=NB6_COMPLETION_REPORT,
)
# Out:
# [NB6] Starting 1/8: apricot__leaf
# [BOOTSTRAP] run_id=apricot_leaf_2026-05-14_11-17-54 crop=apricot part=leaf
# [ADAPTER_SELECTED] key=apricot__leaf crop=apricot part=leaf dataset=apricot__leaf ood=data/ood_dataset/final/apricot__leaf_ood_final oe_enabled=True oe=data/oe_dataset/apricot_leaf_oe_unsupported_leaf_candidates run_id=apricot_leaf_2026-05-14_11-17-54
# [TRAINING_PLAN] epochs=38 batch=52 lr=8.5e-05 lora_r=26 allow_under_min=False validation_every=1
# [SONRAKI] Erisim kontrolu -> dataset validation -> engine init -> training -> calibration -> save/eval hucresini sirayla calistirin.
# [BAYES] Toggle acik ama dosya yok: /content/bitirmeprojesi/runs/_index/bayesian_recommendations.json
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# [HF] Kimlik dogrulandi: Grizzmann
# [GIT] Auto-push on kontrolu gecti: GitHub token cozuldu.
# [CONFIG] source=notebook_cell crop=apricot epochs=12 bs=96 lr=0.0002 resume=fresh ber=False loss=logitnorm tau=1.0 auto_disconnect=True auto_push=True bayes_opt=True
# [DATASET] runtime_root=data/prepared_runtime_datasets dataset_name=apricot__leaf
# [OOD] ood_root=data/ood_dataset/final/apricot__leaf_ood_final ask_for_ood_root=False
# [OE] oe_root=data/oe_dataset/apricot_leaf_oe_unsupported_leaf_candidates ask_for_oe_root=False enabled=True loss_weight=0.25
# [RUNTIME] defaults=notebook_cell mp=bf16 workers=12 prefetch=8 sched=cosine wd=0.01 accum=1 grad_clip=1.0 label_smooth=0.0 warmup=0.1 early_stop=5/0.0 val_every=1 cache_train=True aug=randaugment randaug=2/7
# [OOD] factor=3.0 sure=90.0/97.0 conformal=raps alpha=0.05 raps_lambda=0.2 raps_k=1
# [KONTROL] Repo guncel gorunuyor.
# [KONTROL] GitHub okuma erisimi public; clone/pull icin ekstra token gerekmiyor.
# [KONTROL] GitHub push icin kimlik bilgisi hazir.
# [KONTROL] Gerekli Hugging Face modelleri anonim erisimle aciliyor.
# [BOOTSTRAP] Fetching selected Notebook 2 dataset paths: ['data/prepared_runtime_datasets/apricot__leaf', 'data/ood_dataset/final/apricot__leaf_ood_final', 'data/oe_dataset/apricot_leaf_oe_unsupported_leaf_candidates']
# [OOD] explicit ood root=/content/bitirmeprojesi/data/ood_dataset/final/apricot__leaf_ood_final
# [OE] explicit oe root=/content/bitirmeprojesi/data/oe_dataset/apricot_leaf_oe_unsupported_leaf_candidates
# [DATASET] runtime root=/content/bitirmeprojesi/data/prepared_runtime_datasets/apricot__leaf classes=3: ['kayısı_sağlıklı_yaprak_302', 'kayısı_şarka_virüsü_yaprak_206', 'kayısı_yaprak_delen_çil_hastalığı_yaprak_300']
# [DATASET][CHECK] scale=small continual=508 val=150 test=150 ood=195 classes=3
# [PARAMS] Manual overrides uygulandi: {'EPOCHS': 38, 'BATCH_SIZE': 52, 'LEARNING_RATE': 8.5e-05, 'LORA_R': 26, 'LORA_ALPHA': 24, 'LORA_DROPOUT': 0.125, 'OOD_FACTOR': 5.5, 'LABEL_SMOOTHING': 0.1, 'AUTO_DISCONNECT_RUNTIME': False, 'AUTO_PUSH_TO_GITHUB': True, 'WEIGHT_DECAY': 0.01, 'LOSS_NAME': 'logitnorm', 'LOGITNORM_TAU': 1.0, 'MIXED_PRECISION': 'bf16', 'GRAD_ACCUM_STEPS': 1, 'VALIDATION_EVERY_N_EPOCHS': 1, 'EARLY_STOPPING_PATIENCE': 6, 'RANDAUGMENT_NUM_OPS': 2, 'RANDAUGMENT_MAGNITUDE': 7, 'NUM_WORKERS': 12, 'PREFETCH': 8, 'CACHE_TRAIN_SPLIT': True, 'ENABLE_BAYESIAN_OPTIMIZATION': True}
# [PARAMS][FINAL] epochs=38 bs=52 lr=8.5e-05 lora=26/24 dropout=0.125 accum=1 workers=12 prefetch=8
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
# [OPT] No prior comparable run yet. Bootstrap run will use the visible notebook parameters.
# [OOD] selected ood root=/content/bitirmeprojesi/data/ood_dataset/final/apricot__leaf_ood_final
# [OE] selected oe root=/content/bitirmeprojesi/data/oe_dataset/apricot_leaf_oe_unsupported_leaf_candidates
# [CLASSES] ['kayısı_s_arka_viru_su_yaprak_206', 'kayısı_sag_lıklı_yaprak_302', 'kayısı_yaprak_delen_c_il_hastalıg_ı_yaprak_300']
# [CLASSES] mode=dataset_fallback reason=partial_taxonomy_alignment_fallback matched=0 unmatched=3
# [CLASSES] taxonomy-unmatched classes kept: ['kayısı_s_arka_viru_su_yaprak_206', 'kayısı_sag_lıklı_yaprak_302', 'kayısı_yaprak_delen_c_il_hastalıg_ı_yaprak_300']
# [ENGINE][OOD_CFG] {"ber_enabled": false, "ber_lambda_new": 0.1, "ber_lambda_old": 0.1, "ber_warmup_steps": 50, "conformal_alpha": 0.05, "conformal_enabled": true, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "energy_temperature": 1.0, "energy_temperature_mode": "auto", "energy_temperature_range": [0.5, 3.0], "energy_temperature_steps": 16, "enforce_oe_disjoint": true, "knn_backend": "auto", "knn_chunk_size": 2048, "oe_enabled": true, "oe_loss_weight": 0.25, "oe_root": "/content/bitirmeprojesi/data/oe_dataset/apricot_leaf_oe_unsupported_leaf_candidates", "oe_target": "uniform", "primary_score_method": "auto", "radial_beta_range": [0.5, 2.0], "radial_beta_steps": 16, "radial_l2_enabled": true, "react_apply_during_calibration": true, "react_apply_during_inference": true, "react_enabled": false, "react_percentile": 0.99, "real_dev_selection_enabled": true, "real_dev_target_fpr": 0.05, "real_split_dev_fraction": 0.4, "real_split_enabled": true, "real_split_manifest_name": "ood_split_manifest.json", "real_split_min_per_slice": 2, "real_split_min_total": 30, "sure_confidence_percentile": 97.0, "sure_enabled": true, "sure_semantic_percentile": 90.0, "threshold_factor": 5.5}
# [ENGINE][OPT_CFG] loss=logitnorm tau=1.0 label_smoothing=0.1 mixed_precision=bf16
# [ENGINE] Initializing adapter (may download backbone)...
# config.json:   0%|          | 0.00/745 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.21G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/415 [00:00<?, ?it/s]
# [NB6] FAILED apricot__leaf: Exact image overlap between real OOD evidence and OE training pool is not allowed: same_crop_unsupported_unknowns/takviye_20260514_100_25715e4add34.jpg == unsupported_leaf_disease_candidates/apricot_blight_leaf_disease/100.jpg; same_crop_unsupported_unknowns/takviye_20260514_108_f3b27c5c7944.jpeg == unsupported_leaf_disease_candidates/apricot_blight_leaf_disease/108.jpeg; same_crop_unsupported_unknowns/takviye_20260514_108_1d9ec3f940ae.jpg == unsupported_leaf_disease_candidates/apricot_blight_leaf_disease/108.jpg; same_crop_unsupported_unknowns/takviye_20260514_112_d06994f7e0f0.jpeg == unsupported_leaf_disease_candidates/apricot_blight_leaf_disease/112.jpeg; same_crop_unsupported_unknowns/takviye_20260514_114_2a1a9791d361.jpg == unsupported_leaf_disease_candidates/apricot_blight_leaf_disease/114.jpg; +40 more
#
# [NB6] Starting 2/8: apricot__fruit
# [BOOTSTRAP] run_id=apricot_fruit_2026-05-14_11-18-41 crop=apricot part=fruit
# [ADAPTER_SELECTED] key=apricot__fruit crop=apricot part=fruit dataset=apricot__fruit ood=data/ood_dataset/final/apricot__fruit_ood_final oe_enabled=False oe= run_id=apricot_fruit_2026-05-14_11-18-41
# [TRAINING_PLAN] epochs=36 batch=40 lr=0.0001 lora_r=20 allow_under_min=False validation_every=1
# [SONRAKI] Erisim kontrolu -> dataset validation -> engine init -> training -> calibration -> save/eval hucresini sirayla calistirin.
# [BAYES] Uygulanabilir oneriler bulunamadi.
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# [HF] Kimlik dogrulandi: Grizzmann
# [GIT] Auto-push on kontrolu gecti: GitHub token cozuldu.
# [CONFIG] source=notebook_cell crop=apricot epochs=12 bs=96 lr=0.0002 resume=fresh ber=False loss=logitnorm tau=1.0 auto_disconnect=True auto_push=True bayes_opt=True
# [DATASET] runtime_root=data/prepared_runtime_datasets dataset_name=apricot__fruit
# [OOD] ood_root=data/ood_dataset/final/apricot__fruit_ood_final ask_for_ood_root=False
# [OE] oe_root=<ask> ask_for_oe_root=False enabled=False loss_weight=0.1
# [RUNTIME] defaults=notebook_cell mp=bf16 workers=12 prefetch=8 sched=cosine wd=0.01 accum=1 grad_clip=1.0 label_smooth=0.0 warmup=0.1 early_stop=5/0.0 val_every=1 cache_train=True aug=randaugment randaug=2/7
# [OOD] factor=3.0 sure=90.0/97.0 conformal=raps alpha=0.05 raps_lambda=0.2 raps_k=1
# [KONTROL] Repo guncel gorunuyor.
# [KONTROL] GitHub okuma erisimi public; clone/pull icin ekstra token gerekmiyor.
# [KONTROL] GitHub push icin kimlik bilgisi hazir.
# [KONTROL] Gerekli Hugging Face modelleri anonim erisimle aciliyor.
# [BOOTSTRAP] Fetching selected Notebook 2 dataset paths: ['data/prepared_runtime_datasets/apricot__fruit', 'data/ood_dataset/final/apricot__fruit_ood_final']
# [OOD] explicit ood root=/content/bitirmeprojesi/data/ood_dataset/final/apricot__fruit_ood_final
# [DATASET] runtime root=/content/bitirmeprojesi/data/prepared_runtime_datasets/apricot__fruit classes=5: ['kayısı_sağlıklı_meyve_800', 'kayısıda_çiçek_monilyası_meyve_40', 'kayısıda_şarka_virüsü_meyve_230', 'kayısıda_şeftali_karalekesi_meyve_232', 'kayısıda_yaprak_delen_çil_hastalığı_meyve_128']
# [DATASET][CHECK] scale=small continual=871 val=280 test=280 ood=175 classes=5
# [DATASET][WARN] Manifest rows include 2 eval-quality-risk item(s); prefer cautious regularization.
# [DATASET][BLOCK] Supported classes remain below the production minimum of 100 images/class: kayısıda_çiçek_monilyası_meyve_40=40. Enable ALLOW_UNDER_MIN_TRAINING manually only for a research-only run.
# [PARAMS] Manual overrides uygulandi: {'EPOCHS': 36, 'BATCH_SIZE': 40, 'LEARNING_RATE': 0.0001, 'LORA_R': 20, 'LORA_ALPHA': 20, 'LORA_DROPOUT': 0.2, 'OOD_FACTOR': 4.5, 'LABEL_SMOOTHING': 0.1, 'AUTO_DISCONNECT_RUNTIME': False, 'AUTO_PUSH_TO_GITHUB': True, 'WEIGHT_DECAY': 0.01, 'LOSS_NAME': 'logitnorm', 'LOGITNORM_TAU': 1.0, 'MIXED_PRECISION': 'bf16', 'GRAD_ACCUM_STEPS': 1, 'VALIDATION_EVERY_N_EPOCHS': 1, 'EARLY_STOPPING_PATIENCE': 6, 'RANDAUGMENT_NUM_OPS': 2, 'RANDAUGMENT_MAGNITUDE': 7, 'NUM_WORKERS': 12, 'PREFETCH': 8, 'CACHE_TRAIN_SPLIT': True, 'ENABLE_BAYESIAN_OPTIMIZATION': True}
# [PARAMS][FINAL] epochs=36 bs=40 lr=0.0001 lora=20/20 dropout=0.2 accum=1 workers=12 prefetch=8
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
# [OPT] No prior comparable run yet. Bootstrap run will use the visible notebook parameters.
# [OOD] selected ood root=/content/bitirmeprojesi/data/ood_dataset/final/apricot__fruit_ood_final
# [CLASSES] ['kayısı_sag_lıklı_meyve_800', 'kayısıda_c_ic_ek_monilyası_meyve_40', 'kayısıda_s_arka_viru_su_meyve_230', 'kayısıda_s_eftali_karalekesi_meyve_232', 'kayısıda_yaprak_delen_c_il_hastalıg_ı_meyve_128']
# [CLASSES] mode=dataset_fallback reason=partial_taxonomy_alignment_fallback matched=0 unmatched=5
# [CLASSES] taxonomy-unmatched classes kept: ['kayısı_sag_lıklı_meyve_800', 'kayısıda_c_ic_ek_monilyası_meyve_40', 'kayısıda_s_arka_viru_su_meyve_230', 'kayısıda_s_eftali_karalekesi_meyve_232', 'kayısıda_yaprak_delen_c_il_hastalıg_ı_meyve_128']
# [ENGINE][OOD_CFG] {"ber_enabled": false, "ber_lambda_new": 0.1, "ber_lambda_old": 0.1, "ber_warmup_steps": 50, "conformal_alpha": 0.05, "conformal_enabled": true, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "energy_temperature": 1.0, "energy_temperature_mode": "auto", "energy_temperature_range": [0.5, 3.0], "energy_temperature_steps": 16, "enforce_oe_disjoint": true, "knn_backend": "auto", "knn_chunk_size": 2048, "oe_enabled": false, "oe_loss_weight": 0.1, "oe_root": "", "oe_target": "uniform", "primary_score_method": "auto", "radial_beta_range": [0.5, 2.0], "radial_beta_steps": 16, "radial_l2_enabled": true, "react_apply_during_calibration": true, "react_apply_during_inference": true, "react_enabled": false, "react_percentile": 0.99, "real_dev_selection_enabled": true, "real_dev_target_fpr": 0.05, "real_split_dev_fraction": 0.4, "real_split_enabled": true, "real_split_manifest_name": "ood_split_manifest.json", "real_split_min_per_slice": 2, "real_split_min_total": 30, "sure_confidence_percentile": 97.0, "sure_enabled": true, "sure_semantic_percentile": 90.0, "threshold_factor": 4.5}
# [ENGINE][OPT_CFG] loss=logitnorm tau=1.0 label_smoothing=0.1 mixed_precision=bf16
# [ENGINE] Initializing adapter (may download backbone)...
# Loading weights:   0%|          | 0/415 [00:00<?, ?it/s]
# [ENGINE] Hazir. trainable_params=12,001,545  classes=5
# [VERIFY][OOD][expected] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 4.5}
# [VERIFY][OOD][resolved] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 4.5}
# [VERIFY][OOD] OK: cozulmus OOD ayari istenen parametrelerle eslesiyor.
# [TRAIN] epochs=36 device=cuda batch_interval=12
# [TRAIN] epoch=1 batch=12/21 loss=0.0000 lr=0.000100 speed=228.9s/s elapsed=5s eta=336s
# [CKPT] epoch_end epoch=1 step=21
# [EPOCH] 1/36: train_loss=1.6218 val_loss=1.4990 val_acc=0.1571 macro_f1=0.0543 * BEST
# [TRAIN] epoch=2 batch=12/21 loss=0.0000 lr=0.000100 speed=228.9s/s elapsed=16s eta=343s
# [EPOCH] 2/36: train_loss=1.6080 val_loss=1.6992 val_acc=0.1679 macro_f1=0.0855
# [TRAIN] epoch=3 batch=12/21 loss=0.0000 lr=0.000099 speed=225.9s/s elapsed=21s eta=278s
# [CKPT] epoch_end epoch=3 step=63
# [EPOCH] 3/36: train_loss=1.5918 val_loss=1.4325 val_acc=0.4536 macro_f1=0.3278 * BEST
# [TRAIN] epoch=4 batch=12/21 loss=0.0000 lr=0.000098 speed=228.1s/s elapsed=30s eta=275s
# [CKPT] epoch_end epoch=4 step=84
# [EPOCH] 4/36: train_loss=1.4746 val_loss=1.0069 val_acc=0.6714 macro_f1=0.4912 * BEST
# [TRAIN] epoch=5 batch=12/21 loss=0.0000 lr=0.000096 speed=224.3s/s elapsed=39s eta=267s
# [CKPT] epoch_end epoch=5 step=105
# [EPOCH] 5/36: train_loss=1.2785 val_loss=0.6207 val_acc=0.8214 macro_f1=0.6267 * BEST
# [TRAIN] epoch=6 batch=12/21 loss=0.0000 lr=0.000094 speed=228.4s/s elapsed=47s eta=258s
# [CKPT] epoch_end epoch=6 step=126
# [EPOCH] 6/36: train_loss=1.1844 val_loss=0.4133 val_acc=0.8607 macro_f1=0.6688 * BEST
# [TRAIN] epoch=7 batch=12/21 loss=0.0000 lr=0.000092 speed=227.0s/s elapsed=56s eta=251s
# [EPOCH] 7/36: train_loss=1.1271 val_loss=0.4252 val_acc=0.8643 macro_f1=0.6754
# [TRAIN] epoch=8 batch=12/21 loss=0.0000 lr=0.000090 speed=228.1s/s elapsed=62s eta=231s
# [CKPT] epoch_end epoch=8 step=168
# [EPOCH] 8/36: train_loss=1.1102 val_loss=0.2879 val_acc=0.8893 macro_f1=0.7677 * BEST
# [TRAIN] epoch=9 batch=12/21 loss=0.0000 lr=0.000087 speed=228.2s/s elapsed=70s eta=225s
# [TRAIN] epoch=22 batch=12/21 loss=0.0000 lr=0.000035 speed=228.3s/s elapsed=161s eta=108s
# [CKPT] epoch_end epoch=22 step=462
# [EPOCH] 22/36: train_loss=0.9845 val_loss=0.2136 val_acc=0.9500 macro_f1=0.9147 * BEST
# [TRAIN] epoch=23 batch=12/21 loss=0.0000 lr=0.000031 speed=226.6s/s elapsed=169s eta=101s
# [EPOCH] 23/36: train_loss=0.9801 val_loss=0.2246 val_acc=0.9357 macro_f1=0.8920
# [TRAIN] epoch=24 batch=12/21 loss=0.0000 lr=0.000027 speed=225.3s/s elapsed=175s eta=92s
# [CKPT] batch_250 epoch=24 step=500
# [EPOCH] 24/36: train_loss=0.9713 val_loss=0.2182 val_acc=0.9393 macro_f1=0.9044
# [TRAIN] epoch=25 batch=12/21 loss=0.0000 lr=0.000024 speed=227.7s/s elapsed=182s eta=85s
# [EPOCH] 25/36: train_loss=0.9708 val_loss=0.2275 val_acc=0.9357 macro_f1=0.8980
# [TRAIN] epoch=26 batch=12/21 loss=0.0000 lr=0.000020 speed=226.4s/s elapsed=189s eta=77s
# [EPOCH] 26/36: train_loss=0.9690 val_loss=0.2216 val_acc=0.9357 macro_f1=0.8972
# [TRAIN] epoch=27 batch=12/21 loss=0.0000 lr=0.000017 speed=224.3s/s elapsed=195s eta=69s
# [EPOCH] 27/36: train_loss=0.9630 val_loss=0.2270 val_acc=0.9393 macro_f1=0.8952
# [TRAIN] epoch=28 batch=12/21 loss=0.0000 lr=0.000014 speed=227.9s/s elapsed=200s eta=61s
# [EPOCH] 28/36: train_loss=0.9594 val_loss=0.2175 val_acc=0.9393 macro_f1=0.8941
# [TRAIN] Complete. elapsed=202.9s stopped_early=True stopped_by_user=False cycles=1
# [OOD] Kalibrasyon tamamlandi. classes=5 version=1
# Cell 8: adapter save started
# Kaydedilen adapter klasoru: /content/bitirmeprojesi/outputs/colab_notebook_training/apricot/fruit/continual_sd_lora_adapter
#  - outputs/colab_notebook_training/apricot/fruit/continual_sd_lora_adapter/README.md
#  - outputs/colab_notebook_training/apricot/fruit/continual_sd_lora_adapter/adapter_config.json
#  - outputs/colab_notebook_training/apricot/fruit/continual_sd_lora_adapter/adapter_meta.json
#  - outputs/colab_notebook_training/apricot/fruit/continual_sd_lora_adapter/adapter_model.safetensors
#  - outputs/colab_notebook_training/apricot/fruit/continual_sd_lora_adapter/classifier.pth
#  - outputs/colab_notebook_training/apricot/fruit/continual_sd_lora_adapter/fusion.pth
# Telemetry adapter klasoru: /content/bitirmeprojesi/outputs/colab_notebook_training/telemetry_runtime/telemetry/apricot_fruit_2026-05-14_11-18-41/artifacts/adapter_export/apricot/fruit/continual_sd_lora_adapter
# Cell 8: adapter save completed
# [DOGRULAMA (referans)] ornek=280 sinif=5 accuracy=0.9393 ood_auroc=0.8870 sure_ds_f1=0.4937 conformal_cov=0.9536
# [TEST (ayrilmis)] ornek=280 sinif=5 accuracy=0.9500 ood_auroc=0.8892 sure_ds_f1=0.4694 conformal_cov=0.9571
# [OOD] kanit=real_ood_split durum=failed gecti=False
# [DONE] Dogrulama ve held-out test artefaktlari kaydedildi.
# /usr/local/lib/python3.12/dist-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k1__constant_value is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
# [RUNS] checkpoint_state -> /content/bitirmeprojesi/runs/apricot/fruit/apricot_fruit_2026-05-14_11-18-41/checkpoint_state
# [RUNS] outputs -> /content/bitirmeprojesi/runs/apricot/fruit/apricot_fruit_2026-05-14_11-18-41/outputs/colab_notebook_training
# [RUNS] telemetry -> /content/bitirmeprojesi/runs/apricot/fruit/apricot_fruit_2026-05-14_11-18-41/telemetry
# [RUNS] notebook -> /content/bitirmeprojesi/runs/apricot/fruit/apricot_fruit_2026-05-14_11-18-41/notebooks/6_train_all_continual_sd_lora_adapters.executed.ipynb
# [GIT] Local branch realigned to origin/master before secure run push.
# [SECURITY] scanned=145 redacted_files=62
# [GIT] Stage prepared for runs/apricot/fruit/apricot_fruit_2026-05-14_11-18-41: staged=351 skipped=3
# [GIT] Pushed 351 file(s) from runs/apricot/fruit/apricot_fruit_2026-05-14_11-18-41 to origin/master.
# [COLAB] completion checks -> {'evaluation_artifacts': True, 'production_readiness': True, 'telemetry_summary': True, 'repo_exports': True, 'executed_notebook_export': True}
# [COLAB] Auto-disconnect disabled.
#
# [NB6] Starting 3/8: strawberry__leaf
# [BOOTSTRAP] run_id=strawberry_leaf_2026-05-14_11-22-55 crop=strawberry part=leaf
# [ADAPTER_SELECTED] key=strawberry__leaf crop=strawberry part=leaf dataset=strawberry__leaf ood=data/prepared_runtime_datasets/strawberry__leaf/ood oe_enabled=True oe=data/prepared_runtime_datasets/strawberry__leaf/oe run_id=strawberry_leaf_2026-05-14_11-22-55
# [TRAINING_PLAN] epochs=24 batch=88 lr=0.00012 lora_r=24 allow_under_min=False validation_every=1
# [SONRAKI] Erisim kontrolu -> dataset validation -> engine init -> training -> calibration -> save/eval hucresini sirayla calistirin.
# [BAYES] rank=1 ile 10 parametre onerisi yuklendi.
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# [HF] Kimlik dogrulandi: Grizzmann
# [GIT] Auto-push on kontrolu gecti: GitHub token cozuldu.
# [CONFIG] source=notebook_cell crop=strawberry epochs=12 bs=96 lr=0.0002 resume=fresh ber=False loss=logitnorm tau=1.0 auto_disconnect=True auto_push=True bayes_opt=True
# [DATASET] runtime_root=data/prepared_runtime_datasets dataset_name=strawberry__leaf
# [OOD] ood_root=data/prepared_runtime_datasets/strawberry__leaf/ood ask_for_ood_root=False
# [OE] oe_root=data/prepared_runtime_datasets/strawberry__leaf/oe ask_for_oe_root=False enabled=True loss_weight=0.25
# [RUNTIME] defaults=notebook_cell mp=bf16 workers=12 prefetch=8 sched=cosine wd=0.01 accum=1 grad_clip=1.0 label_smooth=0.0 warmup=0.1 early_stop=5/0.0 val_every=1 cache_train=True aug=randaugment randaug=2/7
# [OOD] factor=3.0 sure=90.0/97.0 conformal=raps alpha=0.05 raps_lambda=0.2 raps_k=1
# [KONTROL] Repo guncel gorunuyor.
# [KONTROL] GitHub okuma erisimi public; clone/pull icin ekstra token gerekmiyor.
# [KONTROL] GitHub push icin kimlik bilgisi hazir.
# [KONTROL] Gerekli Hugging Face modelleri anonim erisimle aciliyor.
# [BOOTSTRAP] Fetching selected Notebook 2 dataset paths: ['data/prepared_runtime_datasets/strawberry__leaf', 'data/ood_dataset/final/strawberry__leaf_ood_final', 'data/oe_dataset/strawberry_leaf_oe_from_blossom_candidates', 'data/prepared_runtime_datasets/strawberry__leaf/ood', 'data/prepared_runtime_datasets/strawberry__leaf/oe']
# [OOD] explicit ood root=/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__leaf/ood
# [OE] explicit oe root=/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__leaf/oe
# [DATASET] runtime root=/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__leaf classes=4: ['healthy', 'strawberry_leaf_scorch_leaf', 'strawberry_leaf_spot_leaf', 'strawberry_powdery_mildew_leaf']
# [DATASET][CHECK] scale=small continual=1606 val=491 test=491 ood=37 classes=4
# [PARAMS] Manual overrides uygulandi: {'EPOCHS':
val_acc=0.9959 macro_f1=0.9951 * BEST
# [TRAIN] epoch=12 batch=12/18 loss=0.0000 lr=0.000063 speed=260.3s/s elapsed=144s eta=152s
# [CKPT] epoch_end epoch=12 step=216
# [EPOCH] 12/24: train_loss=0.7558 val_loss=0.0053 val_acc=0.9959 macro_f1=0.9951 * BEST
# [TRAIN] epoch=13 batch=12/18 loss=0.0000 lr=0.000055 speed=260.5s/s elapsed=156s eta=140s
# [EPOCH] 13/24: train_loss=0.7562 val_loss=0.0139 val_acc=0.9959 macro_f1=0.9951
# [TRAIN] epoch=14 batch=12/18 loss=0.0000 lr=0.000048 speed=260.4s/s elapsed=165s eta=125s
# [CKPT] batch_250 epoch=14 step=250
# [EPOCH] 14/24: train_loss=0.7554 val_loss=0.0082 val_acc=0.9959 macro_f1=0.9951
# [TRAIN] epoch=15 batch=12/18 loss=0.0000 lr=0.000040 speed=260.7s/s elapsed=176s eta=112s
# [EPOCH] 15/24: train_loss=0.7566 val_loss=0.0133 val_acc=0.9959 macro_f1=0.9951
# [TRAIN] epoch=16 batch=12/18 loss=0.0000 lr=0.000033 speed=260.4s/s elapsed=186s eta=99s
# [EPOCH] 16/24: train_loss=0.7556 val_loss=0.0228 val_acc=0.9939 macro_f1=0.9924
# [TRAIN] epoch=17 batch=12/18 loss=0.0000 lr=0.000026 speed=260.6s/s elapsed=195s eta=86s
# [EPOCH] 17/24: train_loss=0.7552 val_loss=0.0221 val_acc=0.9959 macro_f1=0.9951
# [TRAIN] Complete. elapsed=199.6s stopped_early=True stopped_by_user=False cycles=1
# [OOD] Kalibrasyon tamamlandi. classes=4 version=1
# Cell 8: adapter save started
# Kaydedilen adapter klasoru: /content/bitirmeprojesi/outputs/colab_notebook_training/strawberry/leaf/continual_sd_lora_adapter
#  - outputs/colab_notebook_training/strawberry/leaf/continual_sd_lora_adapter/README.md
#  - outputs/colab_notebook_training/strawberry/leaf/continual_sd_lora_adapter/adapter_config.json
#  - outputs/colab_notebook_training/strawberry/leaf/continual_sd_lora_adapter/adapter_meta.json
#  - outputs/colab_notebook_training/strawberry/leaf/continual_sd_lora_adapter/adapter_model.safetensors
#  - outputs/colab_notebook_training/strawberry/leaf/continual_sd_lora_adapter/classifier.pth
#  - outputs/colab_notebook_training/strawberry/leaf/continual_sd_lora_adapter/fusion.pth
# Telemetry adapter klasoru: /content/bitirmeprojesi/outputs/colab_notebook_training/telemetry_runtime/telemetry/strawberry_leaf_2026-05-14_11-22-55/artifacts/adapter_export/strawberry/leaf/continual_sd_lora_adapter
# Cell 8: adapter save completed
# [DOGRULAMA (referans)] ornek=491 sinif=4 accuracy=0.9959 ood_auroc=0.9636 sure_ds_f1=0.5335 conformal_cov=0.9959
# [TEST (ayrilmis)] ornek=491 sinif=4 accuracy=0.9980 ood_auroc=0.9576 sure_ds_f1=0.5255 conformal_cov=0.9980
# [OOD] kanit=real_ood_split durum=failed gecti=False
# [DONE] Dogrulama ve held-out test artefaktlari kaydedildi.
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
# [RUNS] checkpoint_state -> /content/bitirmeprojesi/runs/strawberry/leaf/strawberry_leaf_2026-05-14_11-22-55/checkpoint_state
# [RUNS] outputs -> /content/bitirmeprojesi/runs/strawberry/leaf/strawberry_leaf_2026-05-14_11-22-55/outputs/colab_notebook_training
# [RUNS] telemetry -> /content/bitirmeprojesi/runs/strawberry/leaf/strawberry_leaf_2026-05-14_11-22-55/telemetry
# [RUNS] notebook -> /content/bitirmeprojesi/runs/strawberry/leaf/strawberry_leaf_2026-05-14_11-22-55/notebooks/6_train_all_continual_sd_lora_adapters.executed.ipynb
# [GIT] Local branch realigned to origin/master before secure run push.
# [SECURITY] scanned=148 redacted_files=64
# [GIT] Stage prepared for runs/strawberry/leaf/strawberry_leaf_2026-05-14_11-22-55: staged=353 skipped=3
# [GIT] Pushed 353 file(s) from runs/strawberry/leaf/strawberry_leaf_2026-05-14_11-22-55 to origin/master.
# [COLAB] completion checks -> {'evaluation_artifacts': True, 'production_readiness': True, 'telemetry_summary': True, 'repo_exports': True, 'executed_notebook_export': True}
# [COLAB] Auto-disconnect disabled.
#
# [NB6] Starting 4/8: strawberry__fruit
# [BOOTSTRAP] run_id=strawberry_fruit_2026-05-14_11-27-26 crop=strawberry part=fruit
# [ADAPTER_SELECTED] key=strawberry__fruit crop=strawberry part=fruit dataset=strawberry__fruit ood=data/prepared_runtime_datasets/strawberry__fruit/ood oe_enabled=True oe=data/prepared_runtime_datasets/strawberry__fruit/oe run_id=strawberry_fruit_2026-05-14_11-27-26
# [TRAINING_PLAN] epochs=38 batch=40 lr=5e-05 lora_r=20 allow_under_min=True validation_every=1
# [SONRAKI] Erisim kontrolu -> dataset validation -> engine init -> training -> calibration -> save/eval hucresini sirayla calistirin.
# [BAYES] rank=1 ile 10 parametre onerisi yuklendi.
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# [HF] Kimlik dogrulandi: Grizzmann
# [GIT] Auto-push on kontrolu gecti: GitHub token cozuldu.
# [CONFIG] source=notebook_cell crop=strawberry epochs=12 bs=96 lr=0.0002 resume=fresh ber=False loss=logitnorm tau=1.0 auto_disconnect=True auto_push=True bayes_opt=True
# [DATASET] runtime_root=data/prepared_runtime_datasets dataset_name=strawberry__fruit
# [OOD] ood_root=data/prepared_runtime_datasets/strawberry__fruit/ood ask_for_ood_root=False
# [OE] oe_root=data/prepared_runtime_datasets/strawberry__fruit/oe ask_for_oe_root=False enabled=True loss_weight=0.12
# [RUNTIME] defaults=notebook_cell mp=bf16 workers=12 prefetch=8 sched=cosine wd=0.01 accum=1 grad_clip=1.0 label_smooth=0.0 warmup=0.1 early_stop=5/0.0 val_every=1 cache_train=True aug=randaugment randaug=2/7
# [OOD] factor=3.0 sure=90.0/97.0 conformal=raps alpha=0.05 raps_lambda=0.2 raps_k=1
# [KONTROL] Repo guncel gorunuyor.
# [KONTROL] GitHub okuma erisimi public; clone/pull icin ekstra token gerekmiyor.
# [KONTROL] GitHub push icin kimlik bilgisi hazir.
# [KONTROL] Gerekli Hugging Face modelleri anonim erisimle aciliyor.
# [BOOTSTRAP] Fetching selected Notebook 2 dataset paths: ['data/prepared_runtime_datasets/strawberry__fruit', 'data/ood_dataset/final/strawberry__fruit_ood_final', 'data/oe_dataset/strawberry_fruit_oe_candidates', 'data/prepared_runtime_datasets/strawberry__fruit/ood', 'data/prepared_runtime_datasets/strawberry__fruit/oe']
# [OOD] explicit ood root=/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__fruit/ood
# [OE] explicit oe root=/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__fruit/oe
# [DATASET] runtime root=/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__fruit classes=5: ['strawberry_anthracnose_fruit', 'strawberry_gray_mold_fruit', 'strawberry_healthy_fruit', 'strawberry_powdery_mildew_fruit', 'strawberry_unripe_fruit']
# [DATASET][CHECK] scale=small continual=688 val=223 test=223 ood=304 classes=5
# [DATASET][WARN] Manifest rows include 5 eval-quality-risk item(s); prefer cautious regularization.
# [DATASET][BLOCK] Supported classes remain below the production minimum of 100 images/class: strawberry_anthracnose_fruit=88. Enable ALLOW_UNDER_MIN_TRAINING manually only for a research-only run.
# [PARAMS] Manual overrides uygulandi: {'EPOCHS': 38, 'BATCH_SIZE': 40, 'LEARNING_RATE': 5e-05, 'LORA_R': 20, 'LORA_ALPHA': 26, 'LORA_DROPOUT': 0.13, 'OOD_FACTOR': 2.0, 'LABEL_SMOOTHING': 0.05, 'AUTO_DISCONNECT_RUNTIME': False, 'AUTO_PUSH_TO_GITHUB': True, 'WEIGHT_DECAY': 0.01, 'LOSS_NAME': 'logitnorm', 'LOGITNORM_TAU': 1.0, 'MIXED_PRECISION': 'bf16', 'GRAD_ACCUM_STEPS': 1, 'VALIDATION_EVERY_N_EPOCHS': 1, 'EARLY_STOPPING_PATIENCE': 6, 'RANDAUGMENT_NUM_OPS': 2, 'RANDAUGMENT_MAGNITUDE': 7, 'NUM_WORKERS': 12, 'PREFETCH': 8, 'CACHE_TRAIN_SPLIT': True, 'ENABLE_BAYESIAN_OPTIMIZATION': True}
# [PARAMS][FINAL] epochs=38 bs=40 lr=5e-05 lora=20/26 dropout=0.13 accum=1 workers=12 prefetch=8
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
# [OPT] No prior comparable run yet. Bootstrap run will use the visible notebook parameters.
# [OOD] selected ood root=/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__fruit/ood
# [OE] selected oe root=/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__fruit/oe
# [CLASSES] ['strawberry_anthracnose_fruit', 'strawberry_gray_mold_fruit', 'strawberry_healthy_fruit', 'strawberry_powdery_mildew_fruit', 'strawberry_unripe_fruit']
# [CLASSES] mode=dataset_fallback reason=partial_taxonomy_alignment_fallback matched=0 unmatched=5
# [CLASSES] taxonomy-unmatched classes kept: ['strawberry_anthracnose_fruit', 'strawberry_gray_mold_fruit', 'strawberry_healthy_fruit', 'strawberry_powdery_mildew_fruit', 'strawberry_unripe_fruit']
# [ENGINE][OOD_CFG] {"ber_enabled": false, "ber_lambda_new": 0.1, "ber_lambda_old": 0.1, "ber_warmup_steps": 50, "conformal_alpha": 0.05, "conformal_enabled": true, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "energy_temperature": 1.0, "energy_temperature_mode": "auto", "energy_temperature_range": [0.5, 3.0], "energy_temperature_steps": 16, "enforce_oe_disjoint": true, "knn_backend": "auto", "knn_chunk_size": 2048, "oe_enabled": true, "oe_loss_weight": 0.12, "oe_root": "/content/bitirmeprojesi/data/prepared_runtime_datasets/strawberry__fruit/oe", "oe_target": "uniform", "primary_score_method": "auto", "radial_beta_range": [0.5, 2.0], "radial_beta_steps": 16, "radial_l2_enabled": true, "react_apply_during_calibration": true, "react_apply_during_inference": true, "react_enabled": false, "react_percentile": 0.99, "real_dev_selection_enabled": true, "real_dev_target_fpr": 0.05, "real_split_dev_fraction": 0.4, "real_split_enabled": true, "real_split_manifest_name": "ood_split_manifest.json", "real_split_min_per_slice": 2, "real_split_min_total": 30, "sure_confidence_percentile": 97.0, "sure_enabled": true, "sure_semantic_percentile": 90.0, "threshold_factor": 2.0}
# [ENGINE][OPT_CFG] loss=logitnorm tau=1.0 label_smoothing=0.05 mixed_precision=bf16
# [ENGINE] Initializing adapter (may download backbone)...
# Loading weights:   0%|          | 0/415 [00:00<?, ?it/s]
# [ENGINE] Hazir. trainable_params=12,001,545  classes=5
# [VERIFY][OOD][expected] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 2.0}
# [VERIFY][OOD][resolved] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 2.0}
# [VERIFY][OOD] OK: cozulmus OOD ayari istenen parametrelerle eslesiyor.
# [TRAIN] epochs=38 device=cuda batch_interval=12
# [TRAIN] epoch=1 batch=12/17 loss=0.0000 lr=0.000050 speed=227.2s/s elapsed=5s eta=242s
# [CKPT] epoch_end epoch=1 step=17
# [EPOCH] 1/38: train_loss=1.6336 val_loss=1.6297 val_acc=0.1345 macro_f1=0.0474 * BEST
# [TRAIN] epoch=2 batch=12/17 loss=0.0000 lr=0.000050 speed=226.0s/s elapsed=15s eta=320s
# [EPOCH] 2/38: train_loss=1.6077 val_loss=1.6606 val_acc=0.1031 macro_f1=0.0374
# [TRAIN] epoch=3 batch=12/17 loss=0.0000 lr=0.000049 speed=226.7s/s elapsed=20s eta=267s
# [CKPT] epoch_end epoch=3 step=51
# [EPOCH] 3/38: train_loss=1.5900 val_loss=1.4910 val_acc=0.4933 macro_f1=0.2902 * BEST
# [TRAIN] epoch=4 batch=12/17 loss=0.0000 lr=0.000049 speed=227.1s/s elapsed=30s eta=274s
# [CKPT] epoch_end epoch=4 step=68
# [EPOCH] 4/38: train_loss=1.5702 val_loss=1.4462 val_acc=0.6502 macro_f1=0.4670 * BEST
# [TRAIN] epoch=5 batch=12/17 loss=0.0000 lr=0.000048 speed=226.7s/s elapsed=38s eta=270s
# [CKPT] epoch_end epoch=5 step=85
# [EPOCH] 5/38: train_loss=1.4650 val_loss=1.3944 val_acc=0.4888 macro_f1=0.4392 * BEST
# [TRAIN] epoch=6 batch=12/17 loss=0.0000 lr=0.000047 speed=227.2s/s elapsed=46s eta=261s
# [CKPT] epoch_end epoch=6 step=102
# [EPOCH] 6/38: train_loss=1.3466 val_loss=1.1715 val_acc=0.6547 macro_f1=0.4758 * BEST
# [TRAIN] epoch=7 batch=12/17 loss=0.0000 lr=0.000046 speed=226.6s/s elapsed=54s eta=254s
# [CKPT] epoch_end epoch=7 step=119
# [EPOCH] 7/38: train_loss=1.2822 val_loss=0.9734 val_acc=0.7578 macro_f1=0.6700 * BEST
# [TRAIN] epoch=8 batch=12/17 loss=0.0000 lr=0.000045 speed=227.0s/s elapsed=62s eta=246s
# [CKPT] epoch_end epoch=8 step=136
# [EPOCH] 8/38: train_loss=1.2287 val_loss=0.8505 val_acc=0.7578 macro_f1=0.6727 * BEST
# [TRAIN] epoch=9 batch=12/17 loss=0.0000 lr=0.000044 speed=225.6s/s elapsed=71s eta=238s
# [CKPT] epoch_end epoch=9 step=153
s/strawberry/fruit/strawberry_fruit_2026-05-14_11-27-26/notebooks/6_train_all_continual_sd_lora_adapters.executed.ipynb
# [GIT] Local branch realigned to origin/master before secure run push.
# [SECURITY] scanned=151 redacted_files=66
# [GIT] Stage prepared for runs/strawberry/fruit/strawberry_fruit_2026-05-14_11-27-26: staged=441 skipped=3
# [GIT] Pushed 441 file(s) from runs/strawberry/fruit/strawberry_fruit_2026-05-14_11-27-26 to origin/master.
# [COLAB] completion checks -> {'evaluation_artifacts': True, 'production_readiness': True, 'telemetry_summary': True, 'repo_exports': True, 'executed_notebook_export': True}
# [COLAB] Auto-disconnect disabled.
#
# [NB6] Starting 5/8: grape__leaf
# [BOOTSTRAP] run_id=grape_leaf_2026-05-14_11-30-59 crop=grape part=leaf
# [ADAPTER_SELECTED] key=grape__leaf crop=grape part=leaf dataset=grape__leaf ood=data/prepared_runtime_datasets/grape__leaf/ood oe_enabled=True oe=data/prepared_runtime_datasets/grape__leaf/oe run_id=grape_leaf_2026-05-14_11-30-59
# [TRAINING_PLAN] epochs=30 batch=56 lr=0.0001 lora_r=24 allow_under_min=False validation_every=1
# [SONRAKI] Erisim kontrolu -> dataset validation -> engine init -> training -> calibration -> save/eval hucresini sirayla calistirin.
# [BAYES] rank=1 ile 10 parametre onerisi yuklendi.
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# [HF] Kimlik dogrulandi: Grizzmann
# [GIT] Auto-push on kontrolu gecti: GitHub token cozuldu.
# [CONFIG] source=notebook_cell crop=grape epochs=12 bs=96 lr=0.0002 resume=fresh ber=False loss=logitnorm tau=1.0 auto_disconnect=True auto_push=True bayes_opt=True
# [DATASET] runtime_root=data/prepared_runtime_datasets dataset_name=grape__leaf
# [OOD] ood_root=data/prepared_runtime_datasets/grape__leaf/ood ask_for_ood_root=False
# [OE] oe_root=data/prepared_runtime_datasets/grape__leaf/oe ask_for_oe_root=False enabled=True loss_weight=0.24
# [RUNTIME] defaults=notebook_cell mp=bf16 workers=12 prefetch=8 sched=cosine wd=0.01 accum=1 grad_clip=1.0 label_smooth=0.0 warmup=0.1 early_stop=5/0.0 val_every=1 cache_train=True aug=randaugment randaug=2/7
# [OOD] factor=3.0 sure=90.0/97.0 conformal=raps alpha=0.05 raps_lambda=0.2 raps_k=1
# [KONTROL] Repo guncel gorunuyor.
# [KONTROL] GitHub okuma erisimi public; clone/pull icin ekstra token gerekmiyor.
# [KONTROL] GitHub push icin kimlik bilgisi hazir.
# [KONTROL] Gerekli Hugging Face modelleri anonim erisimle aciliyor.
# [BOOTSTRAP] Fetching selected Notebook 2 dataset paths: ['data/prepared_runtime_datasets/grape__leaf', 'data/ood_dataset/final/grape__leaf_ood_final', 'data/oe_dataset/grape_leaf_oe_unsupported_leaf_candidates', 'data/prepared_runtime_datasets/grape__leaf/ood', 'data/prepared_runtime_datasets/grape__leaf/oe']
# [OOD] explicit ood root=/content/bitirmeprojesi/data/prepared_runtime_datasets/grape__leaf/ood
# [OE] explicit oe root=/content/bitirmeprojesi/data/prepared_runtime_datasets/grape__leaf/oe
# [DATASET] runtime root=/content/bitirmeprojesi/data/prepared_runtime_datasets/grape__leaf classes=7: ['üzüm_antraknoz_yaprak', 'üzüm_kav_esca_yaprak', 'üzüm_külleme_yaprak', 'üzüm_leafroll_virüs_yaprak', 'üzüm_mildiyö_yaprak', 'üzüm_sağlıklı_yaprak', 'üzüm_yelpaze_virüsü_yaprak']
# [DATASET][CHECK] scale=small continual=1207 val=324 test=324 ood=422 classes=7
# [DATASET][WARN] Manifest rows include 182 eval-quality-risk item(s); prefer cautious regularization.
# [PARAMS] Manual overrides uygulandi: {'EPOCHS': 30, 'BATCH_SIZE': 56, 'LEARNING_RATE': 0.0001, 'LORA_R': 24, 'LORA_ALPHA': 24, 'LORA_DROPOUT': 0.14, 'OOD_FACTOR': 3.5, 'LABEL_SMOOTHING': 0.1, 'AUTO_DISCONNECT_RUNTIME': False, 'AUTO_PUSH_TO_GITHUB': True, 'WEIGHT_DECAY': 0.01, 'LOSS_NAME': 'logitnorm', 'LOGITNORM_TAU': 1.0, 'MIXED_PRECISION': 'bf16', 'GRAD_ACCUM_STEPS': 1, 'VALIDATION_EVERY_N_EPOCHS': 1, 'EARLY_STOPPING_PATIENCE': 6, 'RANDAUGMENT_NUM_OPS': 2, 'RANDAUGMENT_MAGNITUDE': 7, 'NUM_WORKERS': 12, 'PREFETCH': 8, 'CACHE_TRAIN_SPLIT': True, 'ENABLE_BAYESIAN_OPTIMIZATION': True}
# [PARAMS][FINAL] epochs=30 bs=56 lr=0.0001 lora=24/24 dropout=0.14 accum=1 workers=12 prefetch=8
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
# [OPT] No prior comparable run yet. Bootstrap run will use the visible notebook parameters.
# [OOD] selected ood root=/content/bitirmeprojesi/data/prepared_runtime_datasets/grape__leaf/ood
# [OE] selected oe root=/content/bitirmeprojesi/data/prepared_runtime_datasets/grape__leaf/oe
# [CLASSES] ['u_zu_m_antraknoz_yaprak', 'u_zu_m_kav_esca_yaprak', 'u_zu_m_ku_lleme_yaprak', 'u_zu_m_leafroll_viru_s_yaprak', 'u_zu_m_mildiyo_yaprak', 'u_zu_m_sag_lıklı_yaprak', 'u_zu_m_yelpaze_viru_su_yaprak']
# [CLASSES] mode=dataset_fallback reason=partial_taxonomy_alignment_fallback matched=0 unmatched=7
# [CLASSES] taxonomy-unmatched classes kept: ['u_zu_m_antraknoz_yaprak', 'u_zu_m_kav_esca_yaprak', 'u_zu_m_ku_lleme_yaprak', 'u_zu_m_leafroll_viru_s_yaprak', 'u_zu_m_mildiyo_yaprak', 'u_zu_m_sag_lıklı_yaprak', 'u_zu_m_yelpaze_viru_su_yaprak']
# [ENGINE][OOD_CFG] {"ber_enabled": false, "ber_lambda_new": 0.1, "ber_lambda_old": 0.1, "ber_warmup_steps": 50, "conformal_alpha": 0.05, "conformal_enabled": true, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "energy_temperature": 1.0, "energy_temperature_mode": "auto", "energy_temperature_range": [0.5, 3.0], "energy_temperature_steps": 16, "enforce_oe_disjoint": true, "knn_backend": "auto", "knn_chunk_size": 2048, "oe_enabled": true, "oe_loss_weight": 0.24, "oe_root": "/content/bitirmeprojesi/data/prepared_runtime_datasets/grape__leaf/oe", "oe_target": "uniform", "primary_score_method": "auto", "radial_beta_range": [0.5, 2.0], "radial_beta_steps": 16, "radial_l2_enabled": true, "react_apply_during_calibration": true, "react_apply_during_inference": true, "react_enabled": false, "react_percentile": 0.99, "real_dev_selection_enabled": true, "real_dev_target_fpr": 0.05, "real_split_dev_fraction": 0.4, "real_split_enabled": true, "real_split_manifest_name": "ood_split_manifest.json", "real_split_min_per_slice": 2, "real_split_min_total": 30, "sure_confidence_percentile": 97.0, "sure_enabled": true, "sure_semantic_percentile": 90.0, "threshold_factor": 3.5}
# [ENGINE][OPT_CFG] loss=logitnorm tau=1.0 label_smoothing=0.1 mixed_precision=bf16
# [ENGINE] Initializing adapter (may download backbone)...
# Loading weights:   0%|          | 0/415 [00:00<?, ?it/s]
# [ENGINE] Hazir. trainable_params=13,772,555  classes=7
# [VERIFY][OOD][expected] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 3.5}
# [VERIFY][OOD][resolved] {"conformal_alpha": 0.05, "conformal_method": "raps", "conformal_raps_k_reg": 1, "conformal_raps_lambda": 0.2, "sure_confidence_percentile": 97.0, "sure_semantic_percentile": 90.0, "threshold_factor": 3.5}
# [VERIFY][OOD] OK: cozulmus OOD ayari istenen parametrelerle eslesiyor.
# [TRAIN] epochs=30 device=cuda batch_interval=12
# [TRAIN] epoch=1 batch=12/21 loss=0.0000 lr=0.000100 speed=245.1s/s elapsed=5s eta=276s
# [CKPT] epoch_end epoch=1 step=21
# [EPOCH] 1/30: train_loss=1.9825 val_loss=1.8893 val_acc=0.1914 macro_f1=0.0735 * BEST
# [TRAIN] epoch=2 batch=12/21 loss=0.0000 lr=0.000099 speed=246.5s/s elapsed=19s eta=340s
# [EPOCH] 2/30: train_loss=1.9377 val_loss=1.9263 val_acc=0.1111 macro_f1=0.0725
# [TRAIN] epoch=3 batch=12/21 loss=0.0000 lr=0.000098 speed=245.4s/s elapsed=27s eta=286s
# [CKPT] epoch_end epoch=3 step=63
# [EPOCH] 3/30: train_loss=1.9134 val_loss=1.8776 val_acc=0.2623 macro_f1=0.2164 * BEST
# [TRAIN] epoch=4 batch=12/21 loss=0.0000 lr=0.000097 speed=246.9s/s elapsed=38s eta=284s
# [CKPT] epoch_end epoch=4 step=84
# [EPOCH] 4/30: train_loss=1.7660 val_loss=1.4448 val_acc=0.4537 macro_f1=0.4094 * BEST
# [TRAIN] epoch=5 batch=12/21 loss=0.0000 lr=0.000094 speed=244.6s/s elapsed=49s eta=274s
# [CKPT] epoch_end epoch=5 step=105
# [EPOCH] 5/30: train_loss=1.6519 val_loss=1.2277 val_acc=0.4907 macro_f1=0.4419 * BEST
# [TRAIN] epoch=6 batch=12/21 loss=0.0000 lr=0.000092 speed=246.7s/s elapsed=60s eta=262s
# [CKPT] epoch_end epoch=6 step=126
# [EPOCH] 6/30: train_loss=1.5614 val_loss=1.0506 val_acc=0.6080 macro_f1=0.5819 * BEST
# [TRAIN] epoch=7 batch=12/21 loss=0.0000 lr=0.000089 speed=245.3s/s elapsed=71s eta=252s
# [CKPT] epoch_end epoch=7 step=147
# [EPOCH] 7/30: train_loss=1.5194 val_loss=0.9427 val_acc=0.6574 macro_f1=0.6382 * BEST
# [TRAIN] epoch=8 batch=12/21 loss=0.0000 lr=0.000085 speed=244.2s/s elapsed=82s eta=242s
# [CKPT] epoch_end epoch=8 step=168
# [EPOCH] 8/30: train_loss=1.4590 val_loss=0.8677 val_acc=0.7191 macro_f1=0.6902 * BEST
# [TRAIN] epoch=9 batch=12/21 loss=0.0000 lr=0.000081 speed=244.9s/s elapsed=93s eta=233s
# [CKPT] epoch_end epoch=9 step=189
# [EPOCH] 9/30: train_loss=1.4564 val_loss=0.8562 val_acc=0.7531 macro_f1=0.7147 * BEST
# [TRAIN] epoch=10 batch=12/21 loss=0.0000 lr=0.000077 speed=246.0s/s elapsed=104s eta=221s
# [CKPT] epoch_end epoch=10 step=210
# [EPOCH] 10/30: train_loss=1.4200 val_loss=0.6941 val_acc=0.7716 macro_f1=0.7439 * BEST
# [TRAIN] epoch=23 batch=12/21 loss=0.0000 lr=0.000015 speed=245.3s/s elapsed=226s eta=74s
# [EPOCH] 23/30: train_loss=1.3259 val_loss=0.5491 val_acc=0.8333 macro_f1=0.8049
# [TRAIN] epoch=24 batch=12/21 loss=0.0000 lr=0.000012 speed=246.8s/s elapsed=234s eta=64s
# [CKPT] batch_250 epoch=24 step=500
# [CKPT] epoch_end epoch=24 step=504
# [EPOCH] 24/30: train_loss=1.3266 val_loss=0.5260 val_acc=0.8457 macro_f1=0.8171 * BEST
# [TRAIN] epoch=25 batch=12/21 loss=0.0000 lr=0.000009 speed=247.1s/s elapsed=249s eta=55s
# [CKPT] epoch_end epoch=25 step=525
# [EPOCH] 25/30: train_loss=1.3137 val_loss=0.5213 val_acc=0.8457 macro_f1=0.8145 * BEST
# [TRAIN] epoch=26 batch=12/21 loss=0.0000 lr=0.000006 speed=246.4s/s elapsed=262s eta=45s
# [EPOCH] 26/30: train_loss=1.3251 val_loss=0.5293 val_acc=0.8364 macro_f1=0.8056
# [TRAIN] epoch=27 batch=12/21 loss=0.0000 lr=0.000004 speed=244.5s/s elapsed=270s eta=35s
# [EPOCH] 27/30: train_loss=1.3150 val_loss=0.5263 val_acc=0.8488 macro_f1=0.8214
# [TRAIN] epoch=28 batch=12/21 loss=0.0000 lr=0.000003 speed=246.6s/s elapsed=277s eta=24s
# [EPOCH] 28/30: train_loss=1.3206 val_loss=0.5246 val_acc=0.8488 macro_f1=0.8204
# [TRAIN] epoch=29 batch=12/21 loss=0.0000 lr=0.000002 speed=245.8s/s elapsed=285s eta=14s
# [EPOCH] 29/30: train_loss=1.3206 val_loss=0.5256 val_acc=0.8457 macro_f1=0.8169
# [TRAIN] epoch=30 batch=12/21 loss=0.0000 lr=0.000001 speed=246.5s/s elapsed=292s eta=4s
# [CKPT] epoch_end epoch=30 step=630
# [EPOCH] 30/30: train_loss=1.3092 val_loss=0.5271 val_acc=0.8457 macro_f1=0.8166
# [TRAIN] Complete. elapsed=299.4s stopped_early=False stopped_by_user=False cycles=1
# [OOD] Kalibrasyon tamamlandi. classes=7 version=1
# Cell 8: adapter save started
# Kaydedilen adapter klasoru: /content/bitirmeprojesi/outputs/colab_notebook_training/grape/leaf/continual_sd_lora_adapter
#  - outputs/colab_notebook_training/grape/leaf/continual_sd_lora_adapter/README.md
#  - outputs/colab_notebook_training/grape/leaf/continual_sd_lora_adapter/adapter_config.json
#  - outputs/colab_notebook_training/grape/leaf/continual_sd_lora_adapter/adapter_meta.json
#  - outputs/colab_notebook_training/grape/leaf/continual_sd_lora_adapter/adapter_model.safetensors
#  - outputs/colab_notebook_training/grape/leaf/continual_sd_lora_adapter/classifier.pth
#  - outputs/colab_notebook_training/grape/leaf/continual_sd_lora_adapter/fusion.pth
# Telemetry adapter klasoru: /content/bitirmeprojesi/outputs/colab_notebook_training/telemetry_runtime/telemetry/grape_leaf_2026-05-14_11-30-59/artifacts/adapter_export/grape/leaf/continual_sd_lora_adapter
# Cell 8: adapter save completed
# [DOGRULAMA (referans)] ornek=324 sinif=7 accuracy=0.8457 ood_auroc=0.8371 sure_ds_f1=0.3062 conformal_cov=0.9537
# [TEST (ayrilmis)] ornek=324 sinif=7 accuracy=0.8765 ood_auroc=0.8312 sure_ds_f1=0.2824 conformal_cov=0.9753
# [OOD] kanit=real_ood_split durum=failed gecti=False
# [DONE] Dogrulama ve held-out test artefaktlari kaydedildi.
# [OPT] mode=continue status=bootstrap_pending eligible=0 frontier=0 executed=0
