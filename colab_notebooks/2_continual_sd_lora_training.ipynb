# %% [markdown]
# # Stage 2: Continual SD-LoRA Training
#
# Build the v6 continual trainer from `config/base.json` and optionally initialize the model engine.

# %%
from collections import deque
from pathlib import Path
import os
import subprocess
import sys

def is_repo_root(path: Path) -> bool:
    return (path / "scripts").is_dir() and (path / "colab_notebooks").is_dir()

def iter_candidate_dirs(scan_root: Path, max_depth: int = 8, max_dirs: int = 30000):
    if not scan_root.exists():
        return
    queue = deque([(scan_root, 0)])
    visited = set()
    try:
        visited.add(scan_root.resolve())
    except OSError:
        pass
    yielded = 0
    while queue and yielded < max_dirs:
        current, depth = queue.popleft()
        try:
            children = list(current.iterdir())
        except OSError:
            continue
        for child in children:
            if not child.is_dir():
                continue
            try:
                resolved = child.resolve()
            except OSError:
                continue
            if resolved in visited:
                continue
            visited.add(resolved)
            yield child
            yielded += 1
            if yielded >= max_dirs:
                return
            if depth < max_depth:
                queue.append((child, depth + 1))

def maybe_clone_repo():
    if os.environ.get("AADS_DISABLE_AUTO_CLONE") == "1":
        return None
    content_root = Path("/content")
    if not content_root.exists():
        return None
    clone_target = Path(os.environ.get("AADS_REPO_CLONE_TARGET", "/content/bitirmeprojesi")).expanduser()
    if is_repo_root(clone_target):
        return clone_target
    if clone_target.exists() and any(clone_target.iterdir()):
        return None
    repo_url = os.environ.get("AADS_REPO_URL", "https://github.com/EfeErim/bitirmeprojesi.git")
    clone_target.parent.mkdir(parents=True, exist_ok=True)
    try:
        completed = subprocess.run(
            ["git", "clone", "--depth", "1", repo_url, str(clone_target)],
            check=False,
            stdout=subprocess.PIPE,
            stderr=subprocess.STDOUT,
            text=True,
        )
    except OSError:
        return None
    if completed.returncode == 0 and is_repo_root(clone_target):
        print(f"Auto-cloned repository to: {clone_target}")
        return clone_target
    return None

def repo_root() -> Path:
    env_candidates = [os.environ.get("AADS_REPO_ROOT"), os.environ.get("REPO_ROOT")]
    for raw_candidate in env_candidates:
        if not raw_candidate:
            continue
        candidate = Path(raw_candidate).expanduser()
        if is_repo_root(candidate):
            return candidate
    cwd = Path.cwd().resolve()
    for candidate in [cwd, *cwd.parents]:
        if is_repo_root(candidate):
            return candidate
    candidates = [
        Path("/content/bitirme projesi"),
        Path("/content/bitirmeprojesi"),
        Path("/content/aads_ulora"),
        Path("/content/drive/MyDrive/bitirme projesi"),
        Path("/content/drive/MyDrive/bitirmeprojesi"),
        Path("/content/drive/MyDrive/aads_ulora"),
        Path("/content/drive/MyDrive/Colab Notebooks/bitirme projesi"),
        Path("/content/drive/MyDrive/Colab Notebooks/bitirmeprojesi"),
        Path("/content/drive/MyDrive/Colab Notebooks/aads_ulora"),
    ]
    for candidate in candidates:
        if is_repo_root(candidate):
            return candidate
    scan_roots = [
        Path("/content"),
        Path("/content/drive/MyDrive"),
        Path("/content/drive/MyDrive/Colab Notebooks"),
    ]
    for scan_root in scan_roots:
        for child in iter_candidate_dirs(scan_root, max_depth=8, max_dirs=30000):
            if is_repo_root(child):
                return child
    auto_cloned = maybe_clone_repo()
    if auto_cloned is not None:
        return auto_cloned
    raise FileNotFoundError(
        f"Repository root not found from cwd={cwd}. Run `%cd /content/<repo_name>` or set AADS_REPO_ROOT/AADS_REPO_CLONE_TARGET."
    )

ROOT = repo_root()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
print(f"Repository root: {ROOT}")

# %%
import json
from pprint import pprint

from src.training.continual_sd_lora import ContinualSDLoRAConfig, ContinualSDLoRATrainer

cfg_path = ROOT / "config" / "base.json"
payload = json.loads(cfg_path.read_text(encoding="utf-8"))
training_cfg = payload.get("training", {}).get("continual", {})

config = ContinualSDLoRAConfig.from_training_config(training_cfg)
print("Loaded continual training contract:")
pprint(config.as_contract_dict())

trainer = ContinualSDLoRATrainer(config)
print("Trainer created on device:", trainer.device)

# %%
RUN_ENGINE_INIT = False
CLASS_NAMES = ["healthy_example", "disease_example"]

if RUN_ENGINE_INIT:
    class_to_idx = {name: idx for idx, name in enumerate(CLASS_NAMES)}
    trainer.initialize_engine(class_to_idx=class_to_idx)
    trainer.setup_optimizer()
    print("Engine initialized. Target modules:", len(trainer.target_modules_resolved))
else:
    print("Skipping engine initialization to avoid heavyweight model download.")
    print("Set RUN_ENGINE_INIT=True when runtime is ready.")

# %%
SAVE_ADAPTER = False
OUTPUT_DIR = ROOT / "outputs" / "colab"

if SAVE_ADAPTER:
    OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
    adapter_path = trainer.save_adapter(str(OUTPUT_DIR))
    print("Adapter saved to:", adapter_path)
else:
    print("Skipping adapter save. Initialize engine first and set SAVE_ADAPTER=True.")
